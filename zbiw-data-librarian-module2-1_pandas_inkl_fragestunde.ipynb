# %% [markdown]
# # ZBIW-Zertifikatskurs "Data Librarian"
# # Modul 2.1: Strukturierte Daten und Metadaten – Pandas Tutorial
# Pandas ist ein flexibles und einfach zu bedienendes Open-Source Werkzeug zur Datenanalyse und -manipulation, das auf der Programmiersprache Python aufbaut.
# Es vereinfacht das Arbeiten mit tabellarischen Daten, vor allem durch Methoden zum Import und Export einer Reihe von Dateiformaten, Übersichtlichkeit und integrierte Funktionalitäten zur Datenvisualisierung.

# %% [markdown]
# ## Import von Pandas

# %%
# Pandas wird meist unter dem alias "pd" importiert
import pandas as pd

# %%
# Wenn pandas nicht installiert ist, kann es mit pip bzw. conda installiert werden
# !pip install pandas

# Abhängig vom verwendeten Betriebssystem muss pip3 spezifiziert oder eine andere Formulierung genutz werden. 
# Mehr Informationen zur Installation unter https://pandas.pydata.org/docs/getting_started/install.html.
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (1.23.4)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2022.5)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# ## Dateiformate in Pandas – Series und DataFrame Objekte
# Pandas verfügt über zwei grundlegende Objekttypen. Das erste ist das Series Objekt, das im Grunde wie eine Liste (Eselsbrücke: "Eine Serie von Einträgen") mit Indices funktioniert. Ein DataFrame aggregiert eine beliebige Anzahl von Series Objekten zu einer tabellarischen Struktur. Die Series Objekte stellen dabei die Spalten der Tabelle da.

# %% [markdown]
# ### Series Objekte

# %%
list_of_strings = ["Value 1", "Value 2", "Value 3", "Value 4"]
list_of_integers = [1, 3, 6, 7]

# %%
series_of_strings = pd.Series(list_of_strings)

# %%
print(series_of_strings)
# Out:
# 0    Value 1
# 1    Value 2
# 2    Value 3
# 3    Value 4
# dtype: object

# %% [markdown]
# Ein Series Objekt kann, im Gegensatz zu einer einfachen Liste, auch labels haben:

# %%
labeled_series = pd.Series(list_of_integers, index = list_of_strings)

# %%
print(labeled_series)
# Out:
# Value 1    1
# Value 2    3
# Value 3    6
# Value 4    7
# dtype: int64

# %% [markdown]
# Entsprechend kann auch über ein dictionary ein Series Objekt erzeugt werden:

# %%
verkaeufe = {"Tag 1": 120, "Tag 2": 330, "Tag 3": 250, "Tag 4": 270}

series_verkäufe = pd.Series(verkaeufe)

print(series_verkäufe)
# Out:
# Tag 1    120
# Tag 2    330
# Tag 3    250
# Tag 4    270
# dtype: int64

# %%
# Zugriff auf Values über index Name
series_verkäufe["Tag 2"]
# Out:
# 330

# %%
# Zugriff auf Values über index Position
series_verkäufe[1]
# Out:
# 330

# %%
# Unterschied zu Dictionary: Ordered List
verkaeufe[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [11], line 2
#       1 # Unterschied zu Dictionary: Ordered List
# ----> 2 verkaeufe[1]
#
# KeyError: 1

# %% [markdown]
# Auf die Werte eines Series Objektes kann auf verschiedene Weisen zugegriffen werden:

# %%
# die "to_list()" Funktion liefert die Elemente eines Series Objektes als Liste:
series_verkäufe.to_list()
# Out:
# [120, 330, 250, 270]

# %%
# Series Objekte sind iterierbar
for value in series_verkäufe:
    print(value)
# Out:
# 120
# 330
# 250
# 270

# %% [markdown]
# ### DataFrame Objekte
#
# #### Erstellung aus Listen

# %%
data1 = {
  "list1": [420, 380, 390],
  "list2": [50, 40, 45]
}

df_1 = pd.DataFrame(data1)


df_1
# Out:
#    list1  list2
# 0    420     50
# 1    380     40
# 2    390     45

# %% [markdown]
# Listen müssen die selbe Länge haben! (Arrays sind eine besondere Form von Listen, die das NumPy Modul nutzt, das von Pandas genutzt wird)

# %%
data2 = {
  "list1": [420, 380, 390],
  "list2": [50, 40, 45],
  "list3": [1, 2, 3, 4, 5 , 6, 7]
}

df_2 = pd.DataFrame(data2)


df_2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [15], line 7
#       1 data2 = {
#       2   "list1": [420, 380, 390],
#       3   "list2": [50, 40, 45],
#       4   "list3": [1, 2, 3, 4, 5 , 6, 7]
#       5 }
# ----> 7 df_2 = pd.DataFrame(data2)
#      10 df_2
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:662, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     656     mgr = self._init_mgr(
#     657         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     658     )
#     660 elif isinstance(data, dict):
#     661     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 662     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     663 elif isinstance(data, ma.MaskedArray):
#     664     import numpy.ma.mrecords as mrecords
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/internals/construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/internals/construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/internals/construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# #### Erstellung aus Dictionaries

# %% [markdown]
# Listen müssen von selber länge sein, Einzelwerte werden für alle Einträge des Dictionaries eingetragen.

# %%
data_dict = {
 "date" : "31.01.2022",
 "time" : ["08:22", "08:55", "09:21", "10:40", "11:30"],
 "value" : [12, 23, 3, 12, 3]    
}

df_3 = pd.DataFrame(data_dict)

# %%
df_3
# Out:
#          date   time  value
# 0  31.01.2022  08:22     12
# 1  31.01.2022  08:55     23
# 2  31.01.2022  09:21      3
# 3  31.01.2022  10:40     12
# 4  31.01.2022  11:30      3

# %% [markdown]
# DataFrames können auch aus mehreren Dictionaries erstellt werden. Dann ist es auch möglich, Dictionaries unterschiedlicher Längen zusammenzuführen.

# %%
merlin = {"Name": "Merlin", "Tierart": "Katze", "Alter" : 3, "Farbe": "schwarz"}
otto = {"Name": "Otto", "Tierart": "Hund", "Alter" : 5, "Farbe": "braun"}
renate = {"Name": "Renate", "Tierart": "Fisch", "Alter" : 2, "Farbe": "rot"}

# %%
df_tiere = pd.DataFrame([merlin, otto, renate])

# %%
df_tiere
# Out:
#      Name Tierart  Alter    Farbe
# 0  Merlin   Katze      3  schwarz
# 1    Otto    Hund      5    braun
# 2  Renate   Fisch      2      rot

# %%
verkaeufe = {"Tag 1": 120, "Tag 2": 330, "Tag 3": 250, "Tag 4": 270}
einnahmen = {"Tag 1": 450, "Tag 2": 1210, "Tag 3": 760, "Tag 4": 950, "Tag 5": 350}

# erstellen aus Liste von dictionaries:
df_4 = pd.DataFrame([verkaeufe, einnahmen], index = ["verkäufe", "einnahmen"])

# %%
df_4
# Out:
#            Tag 1  Tag 2  Tag 3  Tag 4  Tag 5
# verkäufe     120    330    250    270    NaN
# einnahmen    450   1210    760    950  350.0

# %% [markdown]
# Das DataFrame wird mit "NaN", not a number aufgefüllt. Dieser wert ist ein float, also eine Kommazahl.

# %%
df_4_transposed = df_4.T

# %%
df_4_transposed
# Out:
#        verkäufe  einnahmen
# Tag 1     120.0      450.0
# Tag 2     330.0     1210.0
# Tag 3     250.0      760.0
# Tag 4     270.0      950.0
# Tag 5       NaN      350.0

# %% [markdown]
# Über .info() und .describe() lassen sich einfach Informationen über DataFrames abrufen:

# %%
df_4_transposed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Tag 1 to Tag 5
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   verkäufe   4 non-null      float64
#  1   einnahmen  5 non-null      float64
# dtypes: float64(2)
# memory usage: 292.0+ bytes

# %%
df_4_transposed.describe()
# Out:
#         verkäufe    einnahmen
# count    4.00000     5.000000
# mean   242.50000   744.000000
# std     88.45903   354.090384
# min    120.00000   350.000000
# 25%    217.50000   450.000000
# 50%    260.00000   760.000000
# 75%    285.00000   950.000000
# max    330.00000  1210.000000

# %% [markdown]
# ### Wie DataFrames und Series Objekte zusammenhängen
# Wie schon erwähnt, sind Dataframes "zusammengefügte" Series Objekte. Auf diese kann über den Namen der Spalte zugegriffen werden.

# %%
df_4_transposed.verkäufe
# Out:
# Tag 1    120.0
# Tag 2    330.0
# Tag 3    250.0
# Tag 4    270.0
# Tag 5      NaN
# Name: verkäufe, dtype: float64

# %%
df_4_transposed["verkäufe"]
# Out:
# Tag 1    120.0
# Tag 2    330.0
# Tag 3    250.0
# Tag 4    270.0
# Tag 5      NaN
# Name: verkäufe, dtype: float64

# %% [markdown]
# Die Spalten sind Series Objekte:

# %%
type(df_4_transposed.verkäufe)
# Out:
# pandas.core.series.Series

# %%
type(df_4_transposed["verkäufe"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Zugriff auf Spalten- und Zeilennamen (Indices) eines Dataframes

# %%
# Zugriff auf die Namen aller Spalten:
df_4_transposed.columns
# Out:
# Index(['verkäufe', 'einnahmen'], dtype='object')

# %%
# auch hier lässt sich "to_list()" verwenden: 
df_4_transposed.columns.to_list()
# Out:
# ['verkäufe', 'einnahmen']

# %%
# Ähnlich lassen sich die Indices abrufen:
df_4_transposed.index
# Out:
# Index(['Tag 1', 'Tag 2', 'Tag 3', 'Tag 4', 'Tag 5'], dtype='object')

# %%
df_4_transposed.index.to_list()
# Out:
# ['Tag 1', 'Tag 2', 'Tag 3', 'Tag 4', 'Tag 5']

# %% [markdown]
# ## Einlesen von Dateien mit "read"
# Pandas stellt eine Reihe von Methoden zur Verfügung, mit denen ohne Probleme eine Vielzahl verschiedener Datentypen eingelesen werden können.

# %% [markdown]
# ### CSV einlesen

# %%
df = pd.read_csv("data/nyt_bestsellers.csv")

# %%
df[:10]
# Out:
#     1        I Love Dad with The Very Hungry Caterpillar  children
# 0   2                   The Wonderful Things You Will Be  children
# 1   3     Dr. Seuss's I Love Pop!: A Celebration of Dads  children
# 2   4                                 Dragons Love Tacos  children
# 3   5                           How to Babysit a Grandpa  children
# 4   6                                    I Wish You More  children
# 5   7                                      Grumpy Monkey  children
# 6   8                           The Day the Crayons Quit  children
# 7   9                                         Dear Girl,  children
# 8  10  Rosie Revere, Engineer (Questioneers Collectio...  children
# 9  11              Brawl of the Wild (Dog Man Series #6)  children

# %% [markdown]
# #### Spaltennamen und Indexspalte
# In der [Dokumentation](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) ist nachlesbar, welche Optionen es beim Einlesen gibt.

# %%
# names und index_col nutzen
df = pd.read_csv("data/nyt_bestsellers.csv", names = ["index_number", "title", "category"], index_col=0)
df
# Out:
#                                                           title  category
# index_number
# 1                   I Love Dad with The Very Hungry Caterpillar  children
# 2                              The Wonderful Things You Will Be  children
# 3                Dr. Seuss's I Love Pop!: A Celebration of Dads  children
# 4                                            Dragons Love Tacos  children
# 5                                      How to Babysit a Grandpa  children
# ...                                                         ...       ...
# 96                      Everything Is F*cked: A Book about Hope      misc
# 97            Girl, Stop Apologizing: A Shame-Free Plan for ...      misc
# 98            You Are a Badass: How to Stop Doubting Your Gr...      misc
# 99            Dare to Lead: Brave Work. Tough Conversations....      misc
# 100           Medical Medium Celery Juice: The Most Powerful...      misc
#
# [100 rows x 2 columns]

# %%
# !head -1 data/search_Bibliothek.csv
# Out:
# BibliographyType,ISBN,Identifier,Author,Title,Journal,Volume,Number,Month,Pages,Year,Address,Note,URL,Booktitle,Chapter,Edition,Series,Editor,Publisher,ReportType,Howpublished,Institution,Organizations,School,Annote,Custom1,Custom2,Custom3,Custom4,Custom5

# %% [markdown]
# Vorsicht mit Separatoren: Pandas ist oft, vor allem wenn Kommata als Trennzeichen genutzt werden, nicht in der Lage, CSV Dateien korrekt einzulesen:

# %%
path = 'data/search_Bibliothek.csv'
df = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In [39], line 2
#       1 path = 'data/search_Bibliothek.csv'
# ----> 2 df = pd.read_csv(path)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1778, in TextFileReader.read(self, nrows)
#    1771 nrows = validate_integer("nrows", nrows)
#    1772 try:
#    1773     # error: "ParserBase" has no attribute "read"
#    1774     (
#    1775         index,
#    1776         columns,
#    1777         col_dict,
# -> 1778     ) = self._engine.read(  # type: ignore[attr-defined]
#    1779         nrows
#    1780     )
#    1781 except Exception:
#    1782     self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     228 try:
#     229     if self.low_memory:
# --> 230         chunks = self._reader.read_low_memory(nrows)
#     231         # destructive to chunks
#     232         data = _concatenate_chunks(chunks)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:866, in pandas._libs.parsers.TextReader._read_rows()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1973, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 31 fields in line 21, saw 34

# %% [markdown]
# In Zeile 21 sind im Text Kommata enthalten, was zu einer falschen Anzal erkannter Spalten führt.

# %%
# !head -20 data/search_Bibliothek.csv | tail +20
# Out:
# 7,"","ernst_unwahrscheinlichkeit_2018","Ernst, Wolfgang","Die Unwahrscheinlichkeit von Wissenstradition und die Beharrlichkeit der Bibliothek","Bibliothek Forschung und Praxis",42,2,"","379--386",2018,"","","https://www.degruyter.com/view/j/bfup.2018.42.issue-2/bfp-2018-0038/bfp-2018-0038.xml","","","","","","","","","","","","","Mit dem Wandel der Leitmedien von der Buchform zur Zeitform ändert sich der Auftrag der Bibliothek oder lässt diesen zumindest deutlicher erscheinen: Sie hat ihre Rolle im kybernetischen Denken der Wissenszirkulation zu aktualisieren als Zeitkanal zwischen materieller Entropie und ordnungsbewahrender Negentropie. Zwar ist der Hypertext eine aktuelle Alternative zum raumbezogenen Gedächtnis und eröffnet neue Optionen der Wissensnavigation, doch angesichts der Zerstreuung in Netzarchitekturen bedarf es der Bibliothek, um dem Verlust der Nachhaltigkeit von Online-Wissen katechontisch (verzögernd) entgegenzuwirken.","","bibliotheken","",""

# %%
# Kommas als Seperatoren schwierig wenn Zellen Kommas enthalten
# !head -20 data/search_Bibliothek.csv | tail +20 | tr -cd ',' | wc -c
# Out:
#       33

# %% [markdown]
# Es gibt zwar Möglichkeiten, das Problem zu umgehen (z.B. über die Verwendung von "quotechar"), jedoch bietet es sich an, auf hierarchische Dateiformate wie JSON zurückzugreifen, wenn diese Verfügbar sind.

# %% [markdown]
# ### JSON einlesen

# %%
# Einlesen einer JSON datei:
df_nyt = pd.read_json("data/nyt_bestseller.json")

# %%
df_nyt
# Out:
#                                      _id  \
# 0   {'$oid': '5b4aa4ead3089013507db18b'}
# 1   {'$oid': '5b4aa4ead3089013507db18c'}
# 2   {'$oid': '5b4aa4ead3089013507db18d'}
# 3   {'$oid': '5b4aa4ead3089013507db18e'}
# 4   {'$oid': '5b4aa4ead3089013507db18f'}
# ..                                   ...
# 95  {'$oid': '5b4aa4ead3089013507db1ea'}
# 96  {'$oid': '5b4aa4ead3089013507db1eb'}
# 97  {'$oid': '5b4aa4ead3089013507db1ec'}
# 98  {'$oid': '5b4aa4ead3089013507db1ed'}
# 99  {'$oid': '5b4aa4ead3089013507db1ee'}
#
#                                bestsellers_date  \
# 0   {'$date': {'$numberLong': '1211587200000'}}
# 1   {'$date': {'$numberLong': '1211587200000'}}
# 2   {'$date': {'$numberLong': '1211587200000'}}
# 3   {'$date': {'$numberLong': '1211587200000'}}
# 4   {'$date': {'$numberLong': '1211587200000'}}
# ..                                          ...
# 95  {'$date': {'$numberLong': '1214006400000'}}
# 96  {'$date': {'$numberLong': '1214006400000'}}
# 97  {'$date': {'$numberLong': '1214006400000'}}
# 98  {'$date': {'$numberLong': '1214006400000'}}
# 99  {'$date': {'$numberLong': '1214006400000'}}
#
#                                  published_date  \
# 0   {'$date': {'$numberLong': '1212883200000'}}
# 1   {'$date': {'$numberLong': '1212883200000'}}
# 2   {'$date': {'$numberLong': '1212883200000'}}
# 3   {'$date': {'$numberLong': '1212883200000'}}
# 4   {'$date': {'$numberLong': '1212883200000'}}
# ..                                          ...
# 95  {'$date': {'$numberLong': '1215302400000'}}
# 96  {'$date': {'$numberLong': '1215302400000'}}
# 97  {'$date': {'$numberLong': '1215302400000'}}
# 98  {'$date': {'$numberLong': '1215302400000'}}
# 99  {'$date': {'$numberLong': '1215302400000'}}
#
#                                    amazon_product_url  \
# 0   http://www.amazon.com/Odd-Hours-Dean-Koontz/dp...
# 1   http://www.amazon.com/The-Host-Novel-Stephenie...
# 2   http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 3   http://www.amazon.com/The-Front-Garano-Patrici...
# 4   http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# ..                                                ...
# 95  http://www.amazon.com/Blood-Anita-Blake-Vampir...
# 96  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 97  http://www.amazon.com/Death-Honor-Bound-Book/d...
# 98  http://www.amazon.com/The-Spies-Warsaw-A-Novel...
# 99  http://www.amazon.com/Phantom-Prey-John-Sandfo...
#
#                                         author  \
# 0                                Dean R Koontz
# 1                              Stephenie Meyer
# 2                                 Emily Giffin
# 3                            Patricia Cornwell
# 4                              Chuck Palahniuk
# ..                                         ...
# 95                          Laurell K Hamilton
# 96                             Chuck Palahniuk
# 97  W E B Griffin and William E Butterworth IV
# 98                                  Alan Furst
# 99                               John Sandford
#
#                                           description  \
# 0   Odd Thomas, who can communicate with the dead,...
# 1   Aliens have taken control of the minds and bod...
# 2   A woman's happy marriage is shaken when she en...
# 3   A Massachusetts state investigator and his tea...
# 4   An aging porn queens aims to cap her career by...
# ..                                                ...
# 95  The vampire hunter Anita Blake is involved in ...
# 96  An aging porn queens aims to cap her career by...
# 97  A Marine pilot spies in  Argentina in 1943; th...
# 98       Intrigue in Poland just before World War II.
# 99  The Minneapolis detective Lucas Davenport inve...
#
#                          price      publisher                     title  \
# 0         {'$numberInt': '27'}         Bantam                 ODD HOURS
# 1   {'$numberDouble': '25.99'}  Little, Brown                  THE HOST
# 2   {'$numberDouble': '24.95'}   St. Martin's  LOVE THE ONE YOU'RE WITH
# 3   {'$numberDouble': '22.95'}         Putnam                 THE FRONT
# 4   {'$numberDouble': '24.95'}      Doubleday                     SNUFF
# ..                         ...            ...                       ...
# 95  {'$numberDouble': '25.95'}        Berkley                BLOOD NOIR
# 96         {'$numberInt': '0'}      Doubleday                     SNUFF
# 97         {'$numberInt': '0'}         Putnam           DEATH AND HONOR
# 98         {'$numberInt': '0'}   Random House       THE SPIES OF WARSAW
# 99         {'$numberInt': '0'}         Putnam              PHANTOM PREY
#
#                     rank        rank_last_week        weeks_on_list
# 0    {'$numberInt': '1'}   {'$numberInt': '0'}  {'$numberInt': '1'}
# 1    {'$numberInt': '2'}   {'$numberInt': '1'}  {'$numberInt': '3'}
# 2    {'$numberInt': '3'}   {'$numberInt': '2'}  {'$numberInt': '2'}
# 3    {'$numberInt': '4'}   {'$numberInt': '0'}  {'$numberInt': '1'}
# 4    {'$numberInt': '5'}   {'$numberInt': '0'}  {'$numberInt': '1'}
# ..                   ...                   ...                  ...
# 95  {'$numberInt': '16'}  {'$numberInt': '12'}  {'$numberInt': '4'}
# 96  {'$numberInt': '17'}   {'$numberInt': '0'}  {'$numberInt': '0'}
# 97  {'$numberInt': '18'}   {'$numberInt': '0'}  {'$numberInt': '0'}
# 98  {'$numberInt': '19'}   {'$numberInt': '0'}  {'$numberInt': '0'}
# 99  {'$numberInt': '20'}   {'$numberInt': '0'}  {'$numberInt': '0'}
#
# [100 rows x 12 columns]

# %%
df_nyt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   _id                 100 non-null    object
#  1   bestsellers_date    100 non-null    object
#  2   published_date      100 non-null    object
#  3   amazon_product_url  100 non-null    object
#  4   author              100 non-null    object
#  5   description         100 non-null    object
#  6   price               100 non-null    object
#  7   publisher           100 non-null    object
#  8   title               100 non-null    object
#  9   rank                100 non-null    object
#  10  rank_last_week      100 non-null    object
#  11  weeks_on_list       100 non-null    object
# dtypes: object(12)
# memory usage: 9.5+ KB

# %% [markdown]
# Wir können noch keine Aussage über Datentypen treffen.

# %%
df_nyt.bestsellers_date[3]
# Out:
# {'$date': {'$numberLong': '1211587200000'}}

# %%
type(df_nyt.bestsellers_date[3])
# Out:
# dict

# %% [markdown]
# #### Bibliografische Informationen von Bibsonomy
# Als nächstes betrachten wir einen typischen Fall für den Import von bibliografischen Informationen. Wir lesen das Ergebnis einer Literatursuche bei Bibsonomy über das requests Modul ein.

# %%
# einlesen von Daten aus Bibsonomy
import requests
url = "https://www.bibsonomy.org/json/search/Bibliothek?items=1000"
result = requests.get(url) # result ist ein requests.models.Response Objekt
data = result.json() # das Response-Objekt bietet diese nützliche Methode an

# %% [markdown]
# Wie zuvor haben wir hier ein Dictionary, das drei Listen von Dictionaries enthält. Wir interessieren uns für den Wert des Keys "items", der die Suchergebnisse enthält:

# %%
data.keys()
# Out:
# dict_keys(['types', 'properties', 'items'])

# %%
type(data["items"])
# Out:
# list

# %%
# Hier zum Beispiel der 6. Eintrag: 
data["items"][5]
# Out:
# {'type': 'Bookmark',
#  'id': 'https://www.bibsonomy.org/url/57a6c84d63a662d6fdda4b1b1155d68f/schneeschmelze',
#  'tags': ['bibliothek'],
#  'intraHash': '57a6c84d63a662d6fdda4b1b1155d68f',
#  'label': 'Oodi-Bibliothek in Helsinki: Bollwerk gegen Populismus - taz.de',
#  'user': 'schneeschmelze',
#  'description': 'Der Common Ground in der modernen demokratischen Stadtgesellschaft: Die Finnen bauen die Bibliothek der Zukunft, digital und analog zugleich.',
#  'date': '2018-12-17 21:06:43',
#  'changeDate': '2018-12-17 21:06:43',
#  'count': 1,
#  'url': 'https://www.taz.de/Oodi-Bibliothek-in-Helsinki/!5556260/'}

# %% [markdown]
# Da es sich hier um eine Liste von Dictionaries handelt, können wir diese ganz einfach direkt mit Pandas als DataFrame einlesen.

# %%
df_bibsonomy = pd.DataFrame(data["items"])

# %%
df_bibsonomy
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/8dccb0fb43c1baa0...
# 1        Bookmark  https://www.bibsonomy.org/url/6e4d27522857a23d...
# 2        Bookmark  https://www.bibsonomy.org/url/74a579dd9b58dd57...
# 3        Bookmark  https://www.bibsonomy.org/url/561cc0370c975e9d...
# 4        Bookmark  https://www.bibsonomy.org/url/d062f38f9cf0a22e...
# ...           ...                                                ...
# 1995  Publication  https://www.bibsonomy.org/bibtex/2dfcd29f356bf...
# 1996  Publication  https://www.bibsonomy.org/bibtex/256297a0508dc...
# 1997  Publication  https://www.bibsonomy.org/bibtex/29dc9c4198441...
# 1998  Publication  https://www.bibsonomy.org/bibtex/211e72bc7f6ca...
# 1999  Publication  https://www.bibsonomy.org/bibtex/2ec15138d0a36...
#
#                                                    tags  \
# 0                              [bibliothek, treffpunkt]
# 1                                          [Bibliothek]
# 2         [bibliothek, library, lang:de, referendariat]
# 3     [bibliothek, wirtschaftswissenschaften, inform...
# 4                                  [Bibliothek, BibNZZ]
# ...                                                 ...
# 1995                         [Nationalismus;Geschichte]
# 1996                                            [Islam]
# 1997   [Clausewitz, Krieg, Politik, Strategie, Frieden]
# 1998                              [Philosophie,, Essay]
# 1999                                         [imported]
#
#                              intraHash  \
# 0     8dccb0fb43c1baa049c04533af10c807
# 1     6e4d27522857a23d27d0fc781601e288
# 2     74a579dd9b58dd57e61cbc58f2b354f2
# 3     561cc0370c975e9d9143e81e9d901138
# 4     d062f38f9cf0a22e25bffb32fb25e4ad
# ...                                ...
# 1995  dfcd29f356bf6b6ed4d63a8553b5673f
# 1996  56297a0508dc447f9a634e9d5b74cfca
# 1997  9dc9c41984410298c1dcab55604df800
# 1998  11e72bc7f6ca799639e10ba422bb87c3
# 1999  ec15138d0a365378b948b9a7362f1652
#
#                                                   label          user  \
# 0                     Bibliothek: Treffpunkt Bibliothek         hotho
# 1                                            Bibliothek   stadlmairma
# 2                                            Bibliothek       lambert
# 3                             Bibliothek - Fit4Research         wdees
# 4                                 Die dritte Bibliothek        szylla
# ...                                                 ...           ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...  giedenbacher
# 1996                         Der Islam: Eine Einführung       antenor
# 1997                                Vom Kriege: Auswahl       antenor
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...          toss
# 1999                                 Zum ewigen Frieden          toss
#
#                                        description                 date  \
# 0     Treffpunkt Bibliothek 24. - 31. Oktober 2010  2010-07-18 21:30:25
# 1                                                   2020-09-22 15:08:13
# 2                                                   2005-06-22 15:33:30
# 3                                                   2016-05-09 12:23:32
# 4                 Bibliothek von Mircea Cartarescu  2007-12-03 10:43:42
# ...                                            ...                  ...
# 1995                                                2014-08-12 16:44:19
# 1996                                                2016-01-03 20:36:07
# 1997                                                2016-01-03 20:36:07
# 1998                                                2009-09-06 22:34:56
# 1999                                                2015-11-06 19:08:44
#
#                changeDate  count  ... imtm-signatur imtm-inventarnummer  \
# 0     2010-07-18 21:30:25      1  ...           NaN                 NaN
# 1     2020-10-04 17:04:00      1  ...           NaN                 NaN
# 2     2007-04-17 15:07:27      1  ...           NaN                 NaN
# 3     2016-05-09 12:23:32      2  ...           NaN                 NaN
# 4     2010-08-01 10:23:57      1  ...           NaN                 NaN
# ...                   ...    ...  ...           ...                 ...
# 1995  2014-08-12 16:44:19      1  ...           NaN                 NaN
# 1996  2016-01-03 20:36:07      1  ...           NaN                 NaN
# 1997  2016-01-03 20:36:07      1  ...           NaN                 NaN
# 1998  2015-11-06 19:12:37      1  ...           NaN                 NaN
# 1999  2015-11-06 19:12:37      1  ...           NaN                 NaN
#
#      eventtitle venue hdsurl originalyear booktitleaddon origdate gender  \
# 0           NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 1           NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 2           NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 3           NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 4           NaN   NaN    NaN          NaN            NaN      NaN    NaN
# ...         ...   ...    ...          ...            ...      ...    ...
# 1995        NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 1996        NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 1997        NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 1998        NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 1999        NaN   NaN    NaN          NaN            NaN      NaN    NaN
#
#      titleaddon
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1995        NaN
# 1996        NaN
# 1997        NaN
# 1998        NaN
# 1999        NaN
#
# [2000 rows x 94 columns]

# %% [markdown]
# ### Andere Dateiformate

# %% [markdown]
# Beispielsweise mit read_excel() und read_xml() lassen sich noch andere Dateiformate als DataFrame lesen. Eine vollständige Übersicht findet sich [hier](https://pandas.pydata.org/docs/reference/io.html).

# %% [markdown]
# ## Daten mit Pandas Auswählen und Bereinigen
# Im folgenden betrachten wir einige Möglichkeiten, Daten Auszuwählen und zu Filtern.

# %% [markdown]
# ### Spalten auswählen

# %%
# Wir betrachten die Spaltennamen:
df_bibsonomy.columns
# Out:
# Index(['type', 'id', 'tags', 'intraHash', 'label', 'user', 'description',
#        'date', 'changeDate', 'count', 'url', 'interHash', 'pub-type', 'year',
#        'author', 'authors', 'note', 'language', 'bibtexKey', 'publisher',
#        'address', 'shorttitle', 'lccn', 'journal', 'volume', 'number', 'pages',
#        'abstract', 'booktitle', 'series', 'editor', 'editors', 'doi', 'issn',
#        'isbn', 'refid', 'file', 'urldate', 'eissn', 'subtitle', 'pagetotal',
#        'ppn_gvk', 'location', 'ee', 'library', 'citeulike-article-id',
#        'priority', 'comment', 'copyright', 'dnbtitleid', 'posted-at', 'tech',
#        'ty', 'date-added', 'date-modified', 'title1', 'totalpages', 'ISBN',
#        'pubs', 'hyphenation', 'booksubtitle', 'vgwortseiten', 'owner',
#        'timestamp', 'username', 'intrahash', 'interhash', 'groups', 'price',
#        'collaborator', 'size', 'holdings', 'collection', 'bdsk-url-1',
#        'partauthors', 'uniqueid', 'shortsubtitle', 'format', 'titlestatement',
#        'citeulike-linkout-0', 'status', 'translator', 'imtm-standort',
#        'keywords', 'imtm-signatur', 'imtm-inventarnummer', 'eventtitle',
#        'venue', 'hdsurl', 'originalyear', 'booktitleaddon', 'origdate',
#        'gender', 'titleaddon'],
#       dtype='object')

# %%
# Die Spalte "author" enthält anscheinend in vielen Zeilen keine Angabe:
df_bibsonomy.author
# Out:
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#                     ...
# 1995     [Benedict R. O'G. Anderson]
# 1996            [Annemarie Schimmel]
# 1997           [Carl von Clausewitz]
# 1998    [Theodor Wiesengrund Adorno]
# 1999                 [Immanuel Kant]
# Name: author, Length: 2000, dtype: object

# %%
# Ebenso die Spalte "year":
df_bibsonomy.year
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 1995    2005
# 1996    1997
# 1997    1995
# 1998    1951
# 1999    1992
# Name: year, Length: 2000, dtype: object

# %%
# Die Spalte Label enthält die Titel der Veröffentlichungen:
df_bibsonomy.label
# Out:
# 0                       Bibliothek: Treffpunkt Bibliothek
# 1                                              Bibliothek
# 2                                              Bibliothek
# 3                               Bibliothek - Fit4Research
# 4                                   Die dritte Bibliothek
#                               ...
# 1995    Die Erfindung der Nation: zur Karriere eines f...
# 1996                           Der Islam: Eine Einführung
# 1997                                  Vom Kriege: Auswahl
# 1998    Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                   Zum ewigen Frieden
# Name: label, Length: 2000, dtype: object

# %% [markdown]
# Über das Format
# ```
# DataFrame[["v1", "v2", "v3", "v4"]]
# ```
# Lässt sich eine Ansicht, also eine art Kopie des DataFrames ausgeben, das nur die angegebenen Spalten enthält.

# %%
df_bibsonomy[["label", "author", "year", "type"]]
# Out:
#                                                   label  \
# 0                     Bibliothek: Treffpunkt Bibliothek
# 1                                            Bibliothek
# 2                                            Bibliothek
# 3                             Bibliothek - Fit4Research
# 4                                 Die dritte Bibliothek
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                             author  year         type
# 0                              NaN   NaN     Bookmark
# 1                              NaN   NaN     Bookmark
# 2                              NaN   NaN     Bookmark
# 3                              NaN   NaN     Bookmark
# 4                              NaN   NaN     Bookmark
# ...                            ...   ...          ...
# 1995   [Benedict R. O'G. Anderson]  2005  Publication
# 1996          [Annemarie Schimmel]  1997  Publication
# 1997         [Carl von Clausewitz]  1995  Publication
# 1998  [Theodor Wiesengrund Adorno]  1951  Publication
# 1999               [Immanuel Kant]  1992  Publication
#
# [2000 rows x 4 columns]

# %% [markdown]
# Dabei wird aber NICHT das ursprüngliche DataFrame überschrieben:

# %%
df_bibsonomy
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/8dccb0fb43c1baa0...
# 1        Bookmark  https://www.bibsonomy.org/url/6e4d27522857a23d...
# 2        Bookmark  https://www.bibsonomy.org/url/74a579dd9b58dd57...
# 3        Bookmark  https://www.bibsonomy.org/url/561cc0370c975e9d...
# 4        Bookmark  https://www.bibsonomy.org/url/d062f38f9cf0a22e...
# ...           ...                                                ...
# 1995  Publication  https://www.bibsonomy.org/bibtex/2dfcd29f356bf...
# 1996  Publication  https://www.bibsonomy.org/bibtex/256297a0508dc...
# 1997  Publication  https://www.bibsonomy.org/bibtex/29dc9c4198441...
# 1998  Publication  https://www.bibsonomy.org/bibtex/211e72bc7f6ca...
# 1999  Publication  https://www.bibsonomy.org/bibtex/2ec15138d0a36...
#
#                                                    tags  \
# 0                              [bibliothek, treffpunkt]
# 1                                          [Bibliothek]
# 2         [bibliothek, library, lang:de, referendariat]
# 3     [bibliothek, wirtschaftswissenschaften, inform...
# 4                                  [Bibliothek, BibNZZ]
# ...                                                 ...
# 1995                         [Nationalismus;Geschichte]
# 1996                                            [Islam]
# 1997   [Clausewitz, Krieg, Politik, Strategie, Frieden]
# 1998                              [Philosophie,, Essay]
# 1999                                         [imported]
#
#                              intraHash  \
# 0     8dccb0fb43c1baa049c04533af10c807
# 1     6e4d27522857a23d27d0fc781601e288
# 2     74a579dd9b58dd57e61cbc58f2b354f2
# 3     561cc0370c975e9d9143e81e9d901138
# 4     d062f38f9cf0a22e25bffb32fb25e4ad
# ...                                ...
# 1995  dfcd29f356bf6b6ed4d63a8553b5673f
# 1996  56297a0508dc447f9a634e9d5b74cfca
# 1997  9dc9c41984410298c1dcab55604df800
# 1998  11e72bc7f6ca799639e10ba422bb87c3
# 1999  ec15138d0a365378b948b9a7362f1652
#
#                                                   label          user  \
# 0                     Bibliothek: Treffpunkt Bibliothek         hotho
# 1                                            Bibliothek   stadlmairma
# 2                                            Bibliothek       lambert
# 3                             Bibliothek - Fit4Research         wdees
# 4                                 Die dritte Bibliothek        szylla
# ...                                                 ...           ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...  giedenbacher
# 1996                         Der Islam: Eine Einführung       antenor
# 1997                                Vom Kriege: Auswahl       antenor
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...          toss
# 1999                                 Zum ewigen Frieden          toss
#
#                                        description                 date  \
# 0     Treffpunkt Bibliothek 24. - 31. Oktober 2010  2010-07-18 21:30:25
# 1                                                   2020-09-22 15:08:13
# 2                                                   2005-06-22 15:33:30
# 3                                                   2016-05-09 12:23:32
# 4                 Bibliothek von Mircea Cartarescu  2007-12-03 10:43:42
# ...                                            ...                  ...
# 1995                                                2014-08-12 16:44:19
# 1996                                                2016-01-03 20:36:07
# 1997                                                2016-01-03 20:36:07
# 1998                                                2009-09-06 22:34:56
# 1999                                                2015-11-06 19:08:44
#
#                changeDate  count  ... imtm-signatur imtm-inventarnummer  \
# 0     2010-07-18 21:30:25      1  ...           NaN                 NaN
# 1     2020-10-04 17:04:00      1  ...           NaN                 NaN
# 2     2007-04-17 15:07:27      1  ...           NaN                 NaN
# 3     2016-05-09 12:23:32      2  ...           NaN                 NaN
# 4     2010-08-01 10:23:57      1  ...           NaN                 NaN
# ...                   ...    ...  ...           ...                 ...
# 1995  2014-08-12 16:44:19      1  ...           NaN                 NaN
# 1996  2016-01-03 20:36:07      1  ...           NaN                 NaN
# 1997  2016-01-03 20:36:07      1  ...           NaN                 NaN
# 1998  2015-11-06 19:12:37      1  ...           NaN                 NaN
# 1999  2015-11-06 19:12:37      1  ...           NaN                 NaN
#
#      eventtitle venue hdsurl originalyear booktitleaddon origdate gender  \
# 0           NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 1           NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 2           NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 3           NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 4           NaN   NaN    NaN          NaN            NaN      NaN    NaN
# ...         ...   ...    ...          ...            ...      ...    ...
# 1995        NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 1996        NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 1997        NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 1998        NaN   NaN    NaN          NaN            NaN      NaN    NaN
# 1999        NaN   NaN    NaN          NaN            NaN      NaN    NaN
#
#      titleaddon
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1995        NaN
# 1996        NaN
# 1997        NaN
# 1998        NaN
# 1999        NaN
#
# [2000 rows x 94 columns]

# %% [markdown]
# Im folgenden überschreiben wir df_bibsonomy_selection mit der erzeugten Ansicht:

# %%
df_bibsonomy_selection = df_bibsonomy[["label", "author", "year", "type"]]

# %%
df_bibsonomy_selection
# Out:
#                                                   label  \
# 0                     Bibliothek: Treffpunkt Bibliothek
# 1                                            Bibliothek
# 2                                            Bibliothek
# 3                             Bibliothek - Fit4Research
# 4                                 Die dritte Bibliothek
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                             author  year         type
# 0                              NaN   NaN     Bookmark
# 1                              NaN   NaN     Bookmark
# 2                              NaN   NaN     Bookmark
# 3                              NaN   NaN     Bookmark
# 4                              NaN   NaN     Bookmark
# ...                            ...   ...          ...
# 1995   [Benedict R. O'G. Anderson]  2005  Publication
# 1996          [Annemarie Schimmel]  1997  Publication
# 1997         [Carl von Clausewitz]  1995  Publication
# 1998  [Theodor Wiesengrund Adorno]  1951  Publication
# 1999               [Immanuel Kant]  1992  Publication
#
# [2000 rows x 4 columns]

# %% [markdown]
# ### Daten Filtern

# %% [markdown]
# Unser DataFrame enthält noch viele Zeilen, die wir herausfiltern möchten. .loc (locate) hilft, das DataFrame nach Kriterien zu Filtern.

# %%
# Daten auswählen, wo in Spalte "author" ein Wert eingetragen ist
df_bibsonomy_selection = df_bibsonomy_selection.loc[df_bibsonomy_selection["author"].isnull() == False]

# %%
df_bibsonomy_selection
# Out:
#                                                   label  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                                author  year         type
# 1000     [ Berufsverband Information Bibliothek e.V.]  2021  Publication
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]  2007  Publication
# 1002                                 [Manuela Schulz]  2010  Publication
# 1003                                   [Beate Tröger]  2000  Publication
# 1004               [Patrick Danowski, Lambert Heller]  2007  Publication
# ...                                               ...   ...          ...
# 1995                      [Benedict R. O'G. Anderson]  2005  Publication
# 1996                             [Annemarie Schimmel]  1997  Publication
# 1997                            [Carl von Clausewitz]  1995  Publication
# 1998                     [Theodor Wiesengrund Adorno]  1951  Publication
# 1999                                  [Immanuel Kant]  1992  Publication
#
# [900 rows x 4 columns]

# %%
# Daten auswählen, wo in Spalte "type" der Wert "Publication" ist
df_bibsonomy_selection.loc[df_bibsonomy_selection.type == "Publication"]
# Out:
#                                                   label  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                                author  year         type
# 1000     [ Berufsverband Information Bibliothek e.V.]  2021  Publication
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]  2007  Publication
# 1002                                 [Manuela Schulz]  2010  Publication
# 1003                                   [Beate Tröger]  2000  Publication
# 1004               [Patrick Danowski, Lambert Heller]  2007  Publication
# ...                                               ...   ...          ...
# 1995                      [Benedict R. O'G. Anderson]  2005  Publication
# 1996                             [Annemarie Schimmel]  1997  Publication
# 1997                            [Carl von Clausewitz]  1995  Publication
# 1998                     [Theodor Wiesengrund Adorno]  1951  Publication
# 1999                                  [Immanuel Kant]  1992  Publication
#
# [900 rows x 4 columns]

# %% [markdown]
# Über ".drop_duplicates" lassen sich doppelte Einträge entfernen. [Dokumentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html)

# %% [markdown]
# ```
# keep = "first"
# ```
# lässt uns jeweils die erste Zeile der Zeilen, die mehrfach vorkommen behalten.

# %%
# Entfernen von allen Duplikaten in der Spalte "label". 
df_bibsonomy_selection = df_bibsonomy_selection.drop_duplicates(subset = "label", keep = "first")

# %%
df_bibsonomy_selection
# Out:
#                                                   label  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                                author  year         type
# 1000     [ Berufsverband Information Bibliothek e.V.]  2021  Publication
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]  2007  Publication
# 1002                                 [Manuela Schulz]  2010  Publication
# 1003                                   [Beate Tröger]  2000  Publication
# 1004               [Patrick Danowski, Lambert Heller]  2007  Publication
# ...                                               ...   ...          ...
# 1995                      [Benedict R. O'G. Anderson]  2005  Publication
# 1996                             [Annemarie Schimmel]  1997  Publication
# 1997                            [Carl von Clausewitz]  1995  Publication
# 1998                     [Theodor Wiesengrund Adorno]  1951  Publication
# 1999                                  [Immanuel Kant]  1992  Publication
#
# [841 rows x 4 columns]

# %% [markdown]
# ### Daten säubern
#
# Im Folgenden sehen wir ein Beispiel dafür, wie wir mit Problemen umgehen können, die auf unsaubere Daten zurückzuführen sind:

# %%
# Filtern nach einem bestimmten Wert in der Spalte "year"
df_bibsonomy_selection.loc[df_bibsonomy_selection["year"] > 2010]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [66], line 2
#       1 # Filtern nach einem bestimmten Wert in der Spalte "year"
# ----> 2 df_bibsonomy_selection.loc[df_bibsonomy_selection["year"] > 2010]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/arraylike.py:58, in OpsMixin.__gt__(self, other)
#      56 @unpack_zerodim_and_defer("__gt__")
#      57 def __gt__(self, other):
# ---> 58     return self._cmp_method(other, operator.gt)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# -> 6243     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6245 return self._construct_result(res_values, name=res_name)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:287, in comparison_op(left, right, op)
#     284     return invalid_comparison(lvalues, rvalues, op)
#     286 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 287     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     289 else:
#     290     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:75, in comp_method_OBJECT_ARRAY(op, x, y)
#      73     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      74 else:
# ---> 75     result = libops.scalar_compare(x.ravel(), y, op)
#      76 return result.reshape(x.shape)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# Problem: Datentyp falsch erkannt: hier: String!

# %%
# .unique() gibt alle paarweise verschiedenen Werte (alle Werte) eines Series Objektes aus
df_bibsonomy_selection["year"].unique()
# Out:
# array(['2021', '2007', '2010', '2000', '2006', '2019', '2018', '2015',
#        '2020', '2013', '2008', '2011', '2022', '2005', '2016', '1988',
#        '1995', '2009', '1990', '2002', '1983', '1996', ' 2006 ', '1974',
#        '2003', '2014', '2001', '2012', '2017', '1981', '1989', '1780',
#        '1997', '1987', '1994', '1999', '1953', '1991', '1998', '1973',
#        '1993', '1992', '1966', '1964', '1978', '2004', '1931', '1939',
#        '1928', '1829', '1808', '1975', '1963', '1895', '1930', 'n/a',
#        '1984', '1979', '1926', '1922', '1935', '1986', '1933', '1961',
#        '1937', '1927', '1783', '1914', 'March 2010', '1925', '1959',
#        '1941', '2015 ', '1924', '1967', '1969', '1970', '1980', '1982',
#        '1612', '1913', '1952', '1550', '1976', '1918', '1965', '1972',
#        '1977', '1971', '1968', '19971998', '1957', '1929', '1985', '1910',
#        '1955', '1958', '1943', '1954', '1960', '1947 [EA 1785]', '1956',
#        '1909', '1923', '1997 (EA 1655)', '24.04.2005', '1950', '1962',
#        '1951'], dtype=object)

# %% [markdown]
# Wir sehen, dass hier nicht nur Zahlen als String enthalten sind, sondern mit z.B. '1997 (EA 1655)' oder 'March 2010' auch ganze Strings enthalten sind.

# %% [markdown]
# Über .apply kann eine Funktion auf jeden Wert einer Spalte angewendet werden. "axis=1" beschreibt, dass Zeilenweise vorgegangen werden soll und "lambda row:", dass row hier jede iteration, in diesem Fall jede Zeile beschreibt.
#
# Wir schreiben eine neue Spalte "year_correct", in der über row.year.isdigit() überprüft wird, ob es der eintrag in "year" Zahl ist bzw. in eine Ganzzahl umgewandelt werden kann.

# %%
df_bibsonomy_selection["year_correct"] = df_bibsonomy_selection.apply(lambda row: row.year.isdigit(), axis=1)
# Out:
# /var/folders/np/k1z3zp213l3cr57_g6n4bth80000gn/T/ipykernel_71345/2263534620.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bibsonomy_selection["year_correct"] = df_bibsonomy_selection.apply(lambda row: row.year.isdigit(), axis=1)

# %% [markdown]
# Die Warnung kann an dieser stelle ignoriert werden.
#
# über "axis=1" sagen wir hier, dass wir über Zeilen gehen müchten und mit "lambda row:" sagen wir, dass wir diese als "row" bezeichnen.
#
# Jetzt schmeißen wir alle Zeilen aus dem Datensatz, deren "year" Eintrag keine Zahl ist:

# %%
df_bibsonomy_selection.loc[df_bibsonomy_selection.year_correct == False]
# Out:
#                                                   label  \
# 1085  Googles Herausforderung, für eine europäische ...
# 1337  Die spezifischen Probleme einer kleinen Biblio...
# 1428  Der Standort des elektronischen Leseplatzes un...
# 1495  Library Life: Werkstätten kulturwissenschaftli...
# 1924              Grundlegung zur Metaphysik der Sitten
# 1959             Elemente der Philosophie I: Der Körper
# 1962  ULB Bonn - AG Informationskompetenz - Schulung...
#
#                                                  author            year  \
# 1085                              [Jean-Noël Jeanneney]           2006
# 1337                                   [Antonius Gusik]             n/a
# 1428                               [Eric W. Steinhauer]      March 2010
# 1495  [Friedolin Krentel, Katja Barthel, Sebastian B...           2015
# 1924                                    [Immanuel Kant]  1947 [EA 1785]
# 1959                                    [Thomas Hobbes]  1997 (EA 1655)
# 1962   [ Arbeitsgemeinschaft Informationskompetenz NRW]      24.04.2005
#
#              type  year_correct
# 1085  Publication         False
# 1337  Publication         False
# 1428  Publication         False
# 1495  Publication         False
# 1924  Publication         False
# 1959  Publication         False
# 1962  Publication         False

# %%
df_bibsonomy_selection = df_bibsonomy_selection.loc[df_bibsonomy_selection.year_correct == True]

# %%
df_bibsonomy_selection
# Out:
#                                                   label  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                                author  year         type  \
# 1000     [ Berufsverband Information Bibliothek e.V.]  2021  Publication
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]  2007  Publication
# 1002                                 [Manuela Schulz]  2010  Publication
# 1003                                   [Beate Tröger]  2000  Publication
# 1004               [Patrick Danowski, Lambert Heller]  2007  Publication
# ...                                               ...   ...          ...
# 1995                      [Benedict R. O'G. Anderson]  2005  Publication
# 1996                             [Annemarie Schimmel]  1997  Publication
# 1997                            [Carl von Clausewitz]  1995  Publication
# 1998                     [Theodor Wiesengrund Adorno]  1951  Publication
# 1999                                  [Immanuel Kant]  1992  Publication
#
#       year_correct
# 1000          True
# 1001          True
# 1002          True
# 1003          True
# 1004          True
# ...            ...
# 1995          True
# 1996          True
# 1997          True
# 1998          True
# 1999          True
#
# [834 rows x 5 columns]

# %% [markdown]
# Wir können jetzt auch die Zahl in in der Spalte "year" über "astype" in einen Integer, einen Ganzzahlenwertt umwandel und in "year_number" speichern.

# %%
df_bibsonomy_selection["year_number"] = df_bibsonomy_selection["year"].astype(int)
# Out:
# /var/folders/np/k1z3zp213l3cr57_g6n4bth80000gn/T/ipykernel_71345/974826408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bibsonomy_selection["year_number"] = df_bibsonomy_selection["year"].astype(int)

# %%
# die Neue Spalte besteht aus Integer Werten
df_bibsonomy_selection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 834 entries, 1000 to 1999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   label         834 non-null    object
#  1   author        834 non-null    object
#  2   year          834 non-null    object
#  3   type          834 non-null    object
#  4   year_correct  834 non-null    bool
#  5   year_number   834 non-null    int64
# dtypes: bool(1), int64(1), object(4)
# memory usage: 39.9+ KB

# %% [markdown]
# Jetzt können wir nach Publikationen Filtern, die nach 2010 erschienen sind:

# %%
df_bibsonomy_selection_recent = df_bibsonomy_selection.loc[df_bibsonomy_selection.year_number >=2010]

# %%
df_bibsonomy_selection_recent
# Out:
#                                                   label  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1011  Akademische Soziale Netzwerke und ihre Auswirk...
# 1012              Netzwerk „Grüne Bibliothek“ gegründet
# 1013  Und wo sind hier die Bücher? Bibliothek der Zu...
# ...                                                 ...
# 1823  Das Leitbild der Zentralbibliothek der Sportwi...
# 1832         allegro-C : eine Software im Epochenwandel
# 1833  Pro smartphone cross-platform development - iP...
# 1862  Der Beschäftigungszuschuss. Quantitative und q...
# 1953                              Technik in der Antike
#
#                                             author  year         type  \
# 1000  [ Berufsverband Information Bibliothek e.V.]  2021  Publication
# 1002                              [Manuela Schulz]  2010  Publication
# 1011                           [Thomas Nachreiner]  2019  Publication
# 1012                            [Berthold Schmitt]  2018  Publication
# 1013                               [Simon Strauss]  2015  Publication
# ...                                            ...   ...          ...
# 1823           [Rudolf Brockhaus, Sebastian Lange]  2013  Publication
# 1832                          [Bernhard Eversberg]  2012  Publication
# 1833  [Lee Lundrigan, Vidal Graupera, Sarah Allen]  2010  Publication
# 1862                               [Philipp Fuchs]  2013  Publication
# 1953                               [Brigitte Cech]  2010  Publication
#
#       year_correct  year_number
# 1000          True         2021
# 1002          True         2010
# 1011          True         2019
# 1012          True         2018
# 1013          True         2015
# ...            ...          ...
# 1823          True         2013
# 1832          True         2012
# 1833          True         2010
# 1862          True         2013
# 1953          True         2010
#
# [210 rows x 6 columns]

# %% [markdown]
# BONUS:
#
# Einfache Möglichkeit, alle Zeilen mit NaN Einträgen zu löschen:

# %%
df_bibsonomy_selection_no_nan = df_bibsonomy_selection.dropna()

# %%
df_bibsonomy_selection_no_nan
# Out:
#                                                   label  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                                author  year         type  \
# 1000     [ Berufsverband Information Bibliothek e.V.]  2021  Publication
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]  2007  Publication
# 1002                                 [Manuela Schulz]  2010  Publication
# 1003                                   [Beate Tröger]  2000  Publication
# 1004               [Patrick Danowski, Lambert Heller]  2007  Publication
# ...                                               ...   ...          ...
# 1995                      [Benedict R. O'G. Anderson]  2005  Publication
# 1996                             [Annemarie Schimmel]  1997  Publication
# 1997                            [Carl von Clausewitz]  1995  Publication
# 1998                     [Theodor Wiesengrund Adorno]  1951  Publication
# 1999                                  [Immanuel Kant]  1992  Publication
#
#       year_correct  year_number
# 1000          True         2021
# 1001          True         2007
# 1002          True         2010
# 1003          True         2000
# 1004          True         2007
# ...            ...          ...
# 1995          True         2005
# 1996          True         1997
# 1997          True         1995
# 1998          True         1951
# 1999          True         1992
#
# [834 rows x 6 columns]

# %% [markdown]
# ### Daten Verändern und Hinzufügen
# Neben der gerade kennengelernten Methode zum schreiben einer Spalte gibt es noch andere Möglichkeiten, wie Daten in ein DataFrame geschrieben werden können.

# %%
# Spalten umbenennen 
df_bibsonomy_selection = df_bibsonomy_selection.rename(columns={"label": "title", "author": "authors"})
df_bibsonomy_selection
# Out:
#                                                   title  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                               authors  year         type  \
# 1000     [ Berufsverband Information Bibliothek e.V.]  2021  Publication
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]  2007  Publication
# 1002                                 [Manuela Schulz]  2010  Publication
# 1003                                   [Beate Tröger]  2000  Publication
# 1004               [Patrick Danowski, Lambert Heller]  2007  Publication
# ...                                               ...   ...          ...
# 1995                      [Benedict R. O'G. Anderson]  2005  Publication
# 1996                             [Annemarie Schimmel]  1997  Publication
# 1997                            [Carl von Clausewitz]  1995  Publication
# 1998                     [Theodor Wiesengrund Adorno]  1951  Publication
# 1999                                  [Immanuel Kant]  1992  Publication
#
#       year_correct  year_number
# 1000          True         2021
# 1001          True         2007
# 1002          True         2010
# 1003          True         2000
# 1004          True         2007
# ...            ...          ...
# 1995          True         2005
# 1996          True         1997
# 1997          True         1995
# 1998          True         1951
# 1999          True         1992
#
# [834 rows x 6 columns]

# %%
# Schreiben einen Wertes in alle Zeilen einer Spalte
df_bibsonomy_selection["collected_by"] = "Fabian"
df_bibsonomy_selection
# Out:
#                                                   title  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                               authors  year         type  \
# 1000     [ Berufsverband Information Bibliothek e.V.]  2021  Publication
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]  2007  Publication
# 1002                                 [Manuela Schulz]  2010  Publication
# 1003                                   [Beate Tröger]  2000  Publication
# 1004               [Patrick Danowski, Lambert Heller]  2007  Publication
# ...                                               ...   ...          ...
# 1995                      [Benedict R. O'G. Anderson]  2005  Publication
# 1996                             [Annemarie Schimmel]  1997  Publication
# 1997                            [Carl von Clausewitz]  1995  Publication
# 1998                     [Theodor Wiesengrund Adorno]  1951  Publication
# 1999                                  [Immanuel Kant]  1992  Publication
#
#       year_correct  year_number collected_by
# 1000          True         2021       Fabian
# 1001          True         2007       Fabian
# 1002          True         2010       Fabian
# 1003          True         2000       Fabian
# 1004          True         2007       Fabian
# ...            ...          ...          ...
# 1995          True         2005       Fabian
# 1996          True         1997       Fabian
# 1997          True         1995       Fabian
# 1998          True         1951       Fabian
# 1999          True         1992       Fabian
#
# [834 rows x 7 columns]

# %%
# Spalten löschen
df_bibsonomy_selection = df_bibsonomy_selection.drop(columns=['year'])
df_bibsonomy_selection
# Out:
#                                                   title  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                               authors         type  \
# 1000     [ Berufsverband Information Bibliothek e.V.]  Publication
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]  Publication
# 1002                                 [Manuela Schulz]  Publication
# 1003                                   [Beate Tröger]  Publication
# 1004               [Patrick Danowski, Lambert Heller]  Publication
# ...                                               ...          ...
# 1995                      [Benedict R. O'G. Anderson]  Publication
# 1996                             [Annemarie Schimmel]  Publication
# 1997                            [Carl von Clausewitz]  Publication
# 1998                     [Theodor Wiesengrund Adorno]  Publication
# 1999                                  [Immanuel Kant]  Publication
#
#       year_correct  year_number collected_by
# 1000          True         2021       Fabian
# 1001          True         2007       Fabian
# 1002          True         2010       Fabian
# 1003          True         2000       Fabian
# 1004          True         2007       Fabian
# ...            ...          ...          ...
# 1995          True         2005       Fabian
# 1996          True         1997       Fabian
# 1997          True         1995       Fabian
# 1998          True         1951       Fabian
# 1999          True         1992       Fabian
#
# [834 rows x 6 columns]

# %% [markdown]
# Wir ermitteln mit apply, wie viele Autoren in "authors" eingetragen sind:

# %%
# Benutzen von .apply() um eine Funktion auf Teile der Daten anzuwenden (und hier, um das Ergebnis in einer neuen Spalte einzutragen)
df_bibsonomy_selection["number_authors"] = df_bibsonomy_selection.apply( lambda row: len(row.authors), axis=1)
df_bibsonomy_selection
# Out:
#                                                   title  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                               authors         type  \
# 1000     [ Berufsverband Information Bibliothek e.V.]  Publication
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]  Publication
# 1002                                 [Manuela Schulz]  Publication
# 1003                                   [Beate Tröger]  Publication
# 1004               [Patrick Danowski, Lambert Heller]  Publication
# ...                                               ...          ...
# 1995                      [Benedict R. O'G. Anderson]  Publication
# 1996                             [Annemarie Schimmel]  Publication
# 1997                            [Carl von Clausewitz]  Publication
# 1998                     [Theodor Wiesengrund Adorno]  Publication
# 1999                                  [Immanuel Kant]  Publication
#
#       year_correct  year_number collected_by  number_authors
# 1000          True         2021       Fabian               1
# 1001          True         2007       Fabian               2
# 1002          True         2010       Fabian               1
# 1003          True         2000       Fabian               1
# 1004          True         2007       Fabian               2
# ...            ...          ...          ...             ...
# 1995          True         2005       Fabian               1
# 1996          True         1997       Fabian               1
# 1997          True         1995       Fabian               1
# 1998          True         1951       Fabian               1
# 1999          True         1992       Fabian               1
#
# [834 rows x 7 columns]

# %% [markdown]
# ### Daten Analysieren

# %%
# groupby() nutzen, um Zeilen zu gruppieren und Methoden darauf anzuwenden
# count zählt Anzahl der Zeilen pro gruppe
df_bibsonomy_selection_recent.groupby("year_number").count().label
# Out:
# year_number
# 2010        22
# 2011        12
# 2012        14
# 2013        29
# 2014        14
# 2015        23
# 2016        16
# 2017        10
# 2018         8
# 2019        18
# 2020        15
# 2021        17
# 2022        11
# 19971998     1
# Name: label, dtype: int64

# %% [markdown]
# der Wert "19971998" wurde in eine Zahl umgewandelt, ist hier aber sicher falsch. Wir möchten diesen Eintrag jetzt entfernen.
# TIPP:
# Man könnte in etwa so vorgehen, wie wir nach Veröffentlichungen nach 2010 gefiltert haben:
# ```
# df_bibsonomy_selection_recent = df_bibsonomy_selection.loc[df_bibsonomy_selection.year_number >=2010]
# ```

# %% [markdown]
# ### Daten Zusammenführen
# Wir können mit Pandas auch relativ leicht mehrere Datensätze zusammenführen.

# %%
import json
# (Bibsonomy) JSON Daten einlesen
data1 = json.load(open("data/search_Cologne.json"))
data2 = json.load(open("data/search_Media_Bias.json"))

# %%
# Wieder das Problem, dass unsere Daten in "items" liegen
data1.keys()
# Out:
# dict_keys(['types', 'properties', 'items'])

# %%
# Erstellen der DataFrames aus den Listen der Dictionaries, die die Dateneinträge der Bibsonomy Suche darstellen
df_search1 = pd.DataFrame(data1["items"])
df_search2 = pd.DataFrame(data2["items"])

# %%
df_search1
# Out:
#             type                                                 id  \
# 0       Bookmark  https://www.bibsonomy.org/url/9a261c8872ecb14c...
# 1       Bookmark  https://www.bibsonomy.org/url/a16672be36fd00b3...
# 2       Bookmark  https://www.bibsonomy.org/url/b0b96f3140af77e8...
# 3       Bookmark  https://www.bibsonomy.org/url/a16f6b2e28923bb4...
# 4       Bookmark  https://www.bibsonomy.org/url/46c0d406f2483fe1...
# ..           ...                                                ...
# 195  Publication  https://www.bibsonomy.org/bibtex/20b19659687c1...
# 196  Publication  https://www.bibsonomy.org/bibtex/2e2b970a28b61...
# 197  Publication  https://www.bibsonomy.org/bibtex/2b27d82a4a7ba...
# 198  Publication  https://www.bibsonomy.org/bibtex/255d71a5590ef...
# 199  Publication  https://www.bibsonomy.org/bibtex/2507cbfcdc0af...
#
#                                                   tags  \
# 0                           [cologne, theater, cinema]
# 1                    [de, jobs, cologne, selbstaendig]
# 2                                 [coworking, cologne]
# 3    [GErmany, Dom, Kirche, landmark, church, yovis...
# 4                   [schmap, julianausserhofer, photo]
# ..                                                 ...
# 195                                         [oldsaxon]
# 196                                             [dblp]
# 197  [fragrances, beauty, cologne, cosmetics, perfu...
# 198  [fragrances, fashion, beauty, cologne, cosmeti...
# 199  [fragrances, fashion, beauty, cologne, cosmeti...
#
#                             intraHash  \
# 0    9a261c8872ecb14c92fbe783c8e13710
# 1    a16672be36fd00b3dadb76f773711961
# 2    b0b96f3140af77e8a421023136c35a65
# 3    a16f6b2e28923bb455110f4945815381
# 4    46c0d406f2483fe1cc89b8ef61c31798
# ..                                ...
# 195  0b19659687c14feede575239005667b3
# 196  e2b970a28b61dda9ce5920e0da7f00f7
# 197  b27d82a4a7bad66dae4a16e4272269a6
# 198  55d71a5590ef68a8c46242690efd83df
# 199  507cbfcdc0afac234b36408120456211
#
#                                                  label               user  \
# 0                                      Choices cologne             sorkin
# 1                                      coLabor Cologne             fsteeg
# 2                                    Coworking Cologne             fsteeg
# 3    The Cologne Cathedral - More than 600 Years of...         lysander07
# 4                        Cologne - Schmap Travel Guide  julianausserhofer
# ..                                                 ...                ...
# 195                          Altsächsisches Wörterbuch        searocraeft
# 196  Proceedings of the 8th International Workshop ...               dblp
# 197               Best Baby Perfumes For Your New Born        colognelove
# 198  Our Latest Collection Of Best Smelling YSL Col...        colognelove
# 199  7 Best Vanilla Perfumes That Will Make Your He...        colognelove
#
#                                            description                 date  \
# 0                   cologne Cinema and Theater program  2006-06-27 14:13:55
# 1    coLabor is a coworking space to be set up some...  2007-03-28 00:22:19
# 2    Coworking Cologne. Kleines Coworking Space in ...  2013-09-15 15:39:14
# 3    On August 14, 1880, after more than 600 years ...  2013-08-14 19:43:10
# 4    I was delighted to hear that two of my photos ...  2007-12-02 23:10:39
# ..                                                 ...                  ...
# 195                                                     2012-12-25 04:17:33
# 196                                                     2020-02-12 00:00:00
# 197                                                     2022-02-28 12:29:34
# 198                                                     2022-02-28 10:36:38
# 199                                                     2022-02-28 12:34:26
#
#               changeDate  count  ... unique-id  doi date-modified date-added  \
# 0    2006-06-27 14:13:55      1  ...       NaN  NaN           NaN        NaN
# 1    2009-04-30 14:23:47      1  ...       NaN  NaN           NaN        NaN
# 2    2013-09-15 15:39:14      1  ...       NaN  NaN           NaN        NaN
# 3    2013-08-14 19:43:10      1  ...       NaN  NaN           NaN        NaN
# 4    2008-04-16 18:56:44      1  ...       NaN  NaN           NaN        NaN
# ..                   ...    ...  ...       ...  ...           ...        ...
# 195  2015-03-07 02:59:43      1  ...       NaN  NaN           NaN        NaN
# 196  2020-02-13 12:19:10      1  ...       NaN  NaN           NaN        NaN
# 197  2022-02-28 12:29:34      1  ...       NaN  NaN           NaN        NaN
# 198  2022-02-28 10:36:38      1  ...       NaN  NaN           NaN        NaN
# 199  2022-02-28 12:34:26      1  ...       NaN  NaN           NaN        NaN
#
#     numpages language citeulike-article-id priority posted-at bibsource
# 0        NaN      NaN                  NaN      NaN       NaN       NaN
# 1        NaN      NaN                  NaN      NaN       NaN       NaN
# 2        NaN      NaN                  NaN      NaN       NaN       NaN
# 3        NaN      NaN                  NaN      NaN       NaN       NaN
# 4        NaN      NaN                  NaN      NaN       NaN       NaN
# ..       ...      ...                  ...      ...       ...       ...
# 195      NaN      NaN                  NaN      NaN       NaN       NaN
# 196      NaN      NaN                  NaN      NaN       NaN       NaN
# 197      NaN      NaN                  NaN      NaN       NaN       NaN
# 198      NaN      NaN                  NaN      NaN       NaN       NaN
# 199      NaN      NaN                  NaN      NaN       NaN       NaN
#
# [200 rows x 52 columns]

# %%
df_search2
# Out:
#             type                                                 id  \
# 0       Bookmark  https://www.bibsonomy.org/url/bf08e62b2ae96961...
# 1       Bookmark  https://www.bibsonomy.org/url/252294047b101bdb...
# 2       Bookmark  https://www.bibsonomy.org/url/27d2cf6d927e3c14...
# 3       Bookmark  https://www.bibsonomy.org/url/24a281d4e8e33f81...
# 4       Bookmark  https://www.bibsonomy.org/url/0734714d0d35f8a0...
# ..           ...                                                ...
# 101  Publication  https://www.bibsonomy.org/bibtex/257415091921f...
# 102  Publication  https://www.bibsonomy.org/bibtex/271d33d933ed6...
# 103  Publication  https://www.bibsonomy.org/bibtex/2a7189be7a33c...
# 104  Publication  https://www.bibsonomy.org/bibtex/2b2f7171a0bb3...
# 105  Publication  https://www.bibsonomy.org/bibtex/257585621f7ab...
#
#                                   tags                         intraHash  \
# 0           [politics, culture, media]  bf08e62b2ae96961b03e948b7b1cf010
# 1           [news, bias, metric, home]  252294047b101bdb695790f5bf0f4142
# 2             [web, bias, media, vote]  27d2cf6d927e3c1472656f41a38e9d80
# 3                        [fact, check]  24a281d4e8e33f81b68912946cd84f8e
# 4    [Diigo_-_Jem_Fleming's_Bookmarks]  0734714d0d35f8a0d70882d1e2215666
# ..                                 ...                               ...
# 101                             [dblp]  57415091921ff4f533289739183fb742
# 102                             [dblp]  71d33d933ed6799821397aa8c94ae608
# 103                             [dblp]  a7189be7a33c43a0027b1d2793e322ab
# 104                             [dblp]  b2f7171a0bb346b7b8fab3c214fb2022
# 105                             [dblp]  57585621f7ab645ec129ad215499488a
#
#                                                  label           user  \
# 0              MediaBite / A Shot at Bias in the media  georgeroberts
# 1    Breaking News Headlines and Media Bias | Groun...        bshanks
# 2      Skewz.com - Media Bias - All sides of the story        bshanks
# 3    AllSides | Balanced news via media bias rating...       heluking
# 4                                      Unfiltered News     jemfleming
# ..                                                 ...            ...
# 101  Tracking Bias in News Sources Using Social Med...           dblp
# 102  Promoting users' intention to share online hea...           dblp
# 103  Topic bias in the social media - The represent...           dblp
# 104  Gender Bias in Sharenting: Both Men and Women ...           dblp
# 105  That's Not the Way It Is: How User-Generated C...           dblp
#
#                                            description                 date  \
# 0                                                       2007-10-18 19:06:13
# 1                                                       2022-04-28 20:20:48
# 2                                                       2016-12-12 10:00:54
# 3                                                       2020-04-30 16:29:51
# 4    "The primary media outlets in every country ar...  2012-10-09 01:05:21
# ..                                                 ...                  ...
# 101                                                     2020-01-28 00:00:00
# 102                                                     2020-11-07 00:00:00
# 103                                                     2020-02-06 00:00:00
# 104                                                     2018-08-13 00:00:00
# 105                                                     2020-10-01 00:00:00
#
#               changeDate  count  ...      pages               isbn numpages  \
# 0    2013-09-12 08:18:16      1  ...        NaN                NaN      NaN
# 1    2022-04-28 20:20:55      1  ...        NaN                NaN      NaN
# 2    2020-06-15 21:39:35      1  ...        NaN                NaN      NaN
# 3    2020-05-10 17:45:19      1  ...        NaN                NaN      NaN
# 4    2012-10-09 01:23:45      1  ...        NaN                NaN      NaN
# ..                   ...    ...  ...        ...                ...      ...
# 101  2020-01-29 11:50:14      1  ...      13-18  978-1-945626-88-3      NaN
# 102  2020-11-09 11:35:00      1  ...     102354                NaN      NaN
# 103  2020-07-24 01:07:23      1  ...  1791-1803  978-3-88579-248-2      NaN
# 104  2018-08-14 12:08:43      1  ...        NaN                NaN      NaN
# 105  2020-10-02 11:44:03      1  ...      32-45                NaN      NaN
#
#     location abstractnote                                           editor  \
# 0        NaN          NaN                                              NaN
# 1        NaN          NaN                                              NaN
# 2        NaN          NaN                                              NaN
# 3        NaN          NaN                                              NaN
# 4        NaN          NaN                                              NaN
# ..       ...          ...                                              ...
# 101      NaN          NaN            [Octavian Popescu, Carlo Strapparava]
# 102      NaN          NaN                                              NaN
# 103      NaN          NaN  [Stefan Fischer, Erik Maehle, Rüdiger Reischuk]
# 104      NaN          NaN                                              NaN
# 105      NaN          NaN                                              NaN
#
#                                                editors  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 101  [{'first': 'Octavian', 'last': 'Popescu'}, {'f...
# 102                                                NaN
# 103  [{'first': 'Stefan', 'last': 'Fischer'}, {'fir...
# 104                                                NaN
# 105                                                NaN
#
#                                                     ee language mendeley-tags
# 0                                                  NaN      NaN           NaN
# 1                                                  NaN      NaN           NaN
# 2                                                  NaN      NaN           NaN
# 3                                                  NaN      NaN           NaN
# 4                                                  NaN      NaN           NaN
# ..                                                 ...      ...           ...
# 101         https://www.aclweb.org/anthology/W17-4203/      NaN           NaN
# 102          https://doi.org/10.1016/j.ipm.2020.102354      NaN           NaN
# 103  http://subs.emis.de/LNI/Proceedings/Proceeding...      NaN           NaN
# 104                    http://arxiv.org/abs/1803.10329      NaN           NaN
# 105   https://doi.org/10.1111/j.1083-6101.2012.01597.x      NaN           NaN
#
# [106 rows x 43 columns]

# %% [markdown]
# Es gibt zwar verschienene Möglichkeiten, DataFrames zusammenzuführen, in diesem Fall funktioniert .concat am besten, das eine Liste von Dictionaries als Argument nimmt:

# %%
# Mit .concat(Liste von DataFrames) lassen sich DataFrames miteinander kombinieren. 
df_both = pd.concat([df_search1, df_search2])

# %% [markdown]
# Das entstandene DataFrame hat alle Zeilen der beiden DataFrames:

# %%
df_both
# Out:
#             type                                                 id  \
# 0       Bookmark  https://www.bibsonomy.org/url/9a261c8872ecb14c...
# 1       Bookmark  https://www.bibsonomy.org/url/a16672be36fd00b3...
# 2       Bookmark  https://www.bibsonomy.org/url/b0b96f3140af77e8...
# 3       Bookmark  https://www.bibsonomy.org/url/a16f6b2e28923bb4...
# 4       Bookmark  https://www.bibsonomy.org/url/46c0d406f2483fe1...
# ..           ...                                                ...
# 101  Publication  https://www.bibsonomy.org/bibtex/257415091921f...
# 102  Publication  https://www.bibsonomy.org/bibtex/271d33d933ed6...
# 103  Publication  https://www.bibsonomy.org/bibtex/2a7189be7a33c...
# 104  Publication  https://www.bibsonomy.org/bibtex/2b2f7171a0bb3...
# 105  Publication  https://www.bibsonomy.org/bibtex/257585621f7ab...
#
#                                                   tags  \
# 0                           [cologne, theater, cinema]
# 1                    [de, jobs, cologne, selbstaendig]
# 2                                 [coworking, cologne]
# 3    [GErmany, Dom, Kirche, landmark, church, yovis...
# 4                   [schmap, julianausserhofer, photo]
# ..                                                 ...
# 101                                             [dblp]
# 102                                             [dblp]
# 103                                             [dblp]
# 104                                             [dblp]
# 105                                             [dblp]
#
#                             intraHash  \
# 0    9a261c8872ecb14c92fbe783c8e13710
# 1    a16672be36fd00b3dadb76f773711961
# 2    b0b96f3140af77e8a421023136c35a65
# 3    a16f6b2e28923bb455110f4945815381
# 4    46c0d406f2483fe1cc89b8ef61c31798
# ..                                ...
# 101  57415091921ff4f533289739183fb742
# 102  71d33d933ed6799821397aa8c94ae608
# 103  a7189be7a33c43a0027b1d2793e322ab
# 104  b2f7171a0bb346b7b8fab3c214fb2022
# 105  57585621f7ab645ec129ad215499488a
#
#                                                  label               user  \
# 0                                      Choices cologne             sorkin
# 1                                      coLabor Cologne             fsteeg
# 2                                    Coworking Cologne             fsteeg
# 3    The Cologne Cathedral - More than 600 Years of...         lysander07
# 4                        Cologne - Schmap Travel Guide  julianausserhofer
# ..                                                 ...                ...
# 101  Tracking Bias in News Sources Using Social Med...               dblp
# 102  Promoting users' intention to share online hea...               dblp
# 103  Topic bias in the social media - The represent...               dblp
# 104  Gender Bias in Sharenting: Both Men and Women ...               dblp
# 105  That's Not the Way It Is: How User-Generated C...               dblp
#
#                                            description                 date  \
# 0                   cologne Cinema and Theater program  2006-06-27 14:13:55
# 1    coLabor is a coworking space to be set up some...  2007-03-28 00:22:19
# 2    Coworking Cologne. Kleines Coworking Space in ...  2013-09-15 15:39:14
# 3    On August 14, 1880, after more than 600 years ...  2013-08-14 19:43:10
# 4    I was delighted to hear that two of my photos ...  2007-12-02 23:10:39
# ..                                                 ...                  ...
# 101                                                     2020-01-28 00:00:00
# 102                                                     2020-11-07 00:00:00
# 103                                                     2020-02-06 00:00:00
# 104                                                     2018-08-13 00:00:00
# 105                                                     2020-10-01 00:00:00
#
#               changeDate  count  ... language citeulike-article-id priority  \
# 0    2006-06-27 14:13:55      1  ...      NaN                  NaN      NaN
# 1    2009-04-30 14:23:47      1  ...      NaN                  NaN      NaN
# 2    2013-09-15 15:39:14      1  ...      NaN                  NaN      NaN
# 3    2013-08-14 19:43:10      1  ...      NaN                  NaN      NaN
# 4    2008-04-16 18:56:44      1  ...      NaN                  NaN      NaN
# ..                   ...    ...  ...      ...                  ...      ...
# 101  2020-01-29 11:50:14      1  ...      NaN                  NaN      NaN
# 102  2020-11-09 11:35:00      1  ...      NaN                  NaN      NaN
# 103  2020-07-24 01:07:23      1  ...      NaN                  NaN      NaN
# 104  2018-08-14 12:08:43      1  ...      NaN                  NaN      NaN
# 105  2020-10-02 11:44:03      1  ...      NaN                  NaN      NaN
#
#     posted-at bibsource citeulike-linkout-1 citeulike-linkout-0 location  \
# 0         NaN       NaN                 NaN                 NaN      NaN
# 1         NaN       NaN                 NaN                 NaN      NaN
# 2         NaN       NaN                 NaN                 NaN      NaN
# 3         NaN       NaN                 NaN                 NaN      NaN
# 4         NaN       NaN                 NaN                 NaN      NaN
# ..        ...       ...                 ...                 ...      ...
# 101       NaN       NaN                 NaN                 NaN      NaN
# 102       NaN       NaN                 NaN                 NaN      NaN
# 103       NaN       NaN                 NaN                 NaN      NaN
# 104       NaN       NaN                 NaN                 NaN      NaN
# 105       NaN       NaN                 NaN                 NaN      NaN
#
#     abstractnote mendeley-tags
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
# ..           ...           ...
# 101          NaN           NaN
# 102          NaN           NaN
# 103          NaN           NaN
# 104          NaN           NaN
# 105          NaN           NaN
#
# [306 rows x 57 columns]

# %% [markdown]
# BONUS INFO: Der resultierende DataFrame hat mehr Spalten als die beiden DataFrames, die wir verbunden haben, weil es exklusive Spalten gibt, die nur in jeweils einem der beiden DataFrames erscheinen. Wir können das mit List Comprehension überprüfen:

# %%
# Spalten, die in beiden DataFrames sind:
[a for a in df_search1.columns.to_list() if a in df_search2.columns.to_list()]
# Out:
# ['type',
#  'id',
#  'tags',
#  'intraHash',
#  'label',
#  'user',
#  'description',
#  'date',
#  'changeDate',
#  'count',
#  'url',
#  'interHash',
#  'pub-type',
#  'booktitle',
#  'address',
#  'year',
#  'author',
#  'authors',
#  'editor',
#  'editors',
#  'bibtexKey',
#  'series',
#  'publisher',
#  'number',
#  'volume',
#  'ee',
#  'journal',
#  'pages',
#  'note',
#  'abstract',
#  'isbn',
#  'issn',
#  'doi',
#  'numpages',
#  'language',
#  'citeulike-article-id',
#  'priority',
#  'posted-at']

# %%
# Spalten, die nur im ersten DataFrame sind:
[a for a in df_search1.columns.to_list() if a not in df_search2.columns.to_list()]
# Out:
# ['shortauthor',
#  'urldate',
#  'pdf',
#  'eventtitle',
#  'venue',
#  'eventdate',
#  'dnbtitleid',
#  'eissn',
#  'orcid-numbers',
#  'article-number',
#  'unique-id',
#  'date-modified',
#  'date-added',
#  'bibsource']

# %%
# Spalten, die nur im zweiten DataFrame sind:
[a for a in df_search2.columns.to_list() if a not in df_search1.columns.to_list()]
# Out:
# ['citeulike-linkout-1',
#  'citeulike-linkout-0',
#  'location',
#  'abstractnote',
#  'mendeley-tags']

# %% [markdown]
# ## Daten Exportieren
# es gibt eine Reihe von Möglichkeiten, Daten mit Pandas zu exportieren. Im folgenden zeigen wir, wie wir unseren Datensatz als CSV und JSON Datei exportieren können.

# %% [markdown]
# ### Export als CSV
# Zum Exportieren der Daten als als CSV Datei kann die .to_csv() Methode verwendet werden. Es muss ein Name für die Ausgabedatei angegeben werden. Um Probleme mit den Kommata beim Einlesen zu vermeiden, kann über sep= ein anderer Seperator angegeben werden, der nicht oder weniger Wahrscheinlich in den Daten vorkommt (oft bietet sich hier ein Semikolon oder ein anderes, noch seltener genutzes Sonderzeichen an). Pandas nutzt aber in der Regel alle Möglichkeiten, die Seperatoren in Daten zu "Escapen", sodass diese beim Einlesen nicht als Seperatoren Genutzt werden.

# %%
df_bibsonomy_selection.to_csv("data/output.csv", sep=";")

# %%
pd.read_csv("data/output.csv", sep=";")
# Out:
#      Unnamed: 0                                              title  \
# 0          1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1          1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 2          1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 3          1003  Wissenschaft online. Elektronisches Publiziere...
# 4          1004               Bibliothek 2.0 -- Wird alles anders?
# ..          ...                                                ...
# 829        1995  Die Erfindung der Nation: zur Karriere eines f...
# 830        1996                         Der Islam: Eine Einführung
# 831        1997                                Vom Kriege: Auswahl
# 832        1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 833        1999                                 Zum ewigen Frieden
#
#                                                authors         type  \
# 0       [' Berufsverband Information Bibliothek e.V.']  Publication
# 1    ['Michaela Selbach', 'Bibliothek der Fachhochs...  Publication
# 2                                   ['Manuela Schulz']  Publication
# 3                                     ['Beate Tröger']  Publication
# 4               ['Patrick Danowski', 'Lambert Heller']  Publication
# ..                                                 ...          ...
# 829                      ["Benedict R. O'G. Anderson"]  Publication
# 830                             ['Annemarie Schimmel']  Publication
# 831                            ['Carl von Clausewitz']  Publication
# 832                     ['Theodor Wiesengrund Adorno']  Publication
# 833                                  ['Immanuel Kant']  Publication
#
#      year_correct  year_number collected_by  number_authors
# 0            True         2021       Fabian               1
# 1            True         2007       Fabian               2
# 2            True         2010       Fabian               1
# 3            True         2000       Fabian               1
# 4            True         2007       Fabian               2
# ..            ...          ...          ...             ...
# 829          True         2005       Fabian               1
# 830          True         1997       Fabian               1
# 831          True         1995       Fabian               1
# 832          True         1951       Fabian               1
# 833          True         1992       Fabian               1
#
# [834 rows x 8 columns]

# %%
df_bibsonomy_selection.to_csv("data/output.csv")

# %%
pd.read_csv("data/output.csv")
# Out:
#      Unnamed: 0                                              title  \
# 0          1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1          1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 2          1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 3          1003  Wissenschaft online. Elektronisches Publiziere...
# 4          1004               Bibliothek 2.0 -- Wird alles anders?
# ..          ...                                                ...
# 829        1995  Die Erfindung der Nation: zur Karriere eines f...
# 830        1996                         Der Islam: Eine Einführung
# 831        1997                                Vom Kriege: Auswahl
# 832        1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 833        1999                                 Zum ewigen Frieden
#
#                                                authors         type  \
# 0       [' Berufsverband Information Bibliothek e.V.']  Publication
# 1    ['Michaela Selbach', 'Bibliothek der Fachhochs...  Publication
# 2                                   ['Manuela Schulz']  Publication
# 3                                     ['Beate Tröger']  Publication
# 4               ['Patrick Danowski', 'Lambert Heller']  Publication
# ..                                                 ...          ...
# 829                      ["Benedict R. O'G. Anderson"]  Publication
# 830                             ['Annemarie Schimmel']  Publication
# 831                            ['Carl von Clausewitz']  Publication
# 832                     ['Theodor Wiesengrund Adorno']  Publication
# 833                                  ['Immanuel Kant']  Publication
#
#      year_correct  year_number collected_by  number_authors
# 0            True         2021       Fabian               1
# 1            True         2007       Fabian               2
# 2            True         2010       Fabian               1
# 3            True         2000       Fabian               1
# 4            True         2007       Fabian               2
# ..            ...          ...          ...             ...
# 829          True         2005       Fabian               1
# 830          True         1997       Fabian               1
# 831          True         1995       Fabian               1
# 832          True         1951       Fabian               1
# 833          True         1992       Fabian               1
#
# [834 rows x 8 columns]

# %% [markdown]
# ### Export als JSON
# Zum Exportieren der Daten als als JSON file kann die .to_json() Methode verwendet werden. Es muss ein Name für die Ausgabedatei angegeben werden. Zusätzlich kann es sein (beispielsweise für den Export für die Verwendung in SOLR!), dass mit orient="records" eine eintragsorientierte ausgabe spezifiziert werden muss.

# %%
df_bibsonomy_selection.to_json("data/output.json", orient="records")

# %%
# check, if it look correct
with open("data/output.json", "r") as f:
    j_load = json.load(f)
    print(json.dumps(j_load, indent=2))
# Out:
# [
#   {
#     "title": "BIB Fundgrube Fachinformation Gr\u00fcne Bibliothek. BibInfo",
#     "authors": [
#       " Berufsverband Information Bibliothek e.V."
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2021,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliothek 2.0 : neue Perspektiven und Einsatzm\u00f6glichkeiten f\u00fcr wissenschaftliche Bibliotheken",
#     "authors": [
#       "Michaela Selbach",
#       "Bibliothek der Fachhochsch."
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2007,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Service vor Ort? Die Bibliothek geht zum Nutzer",
#     "authors": [
#       "Manuela Schulz"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2010,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Wissenschaft online. Elektronisches Publizieren in Bibliothek und Hochschule",
#     "authors": [
#       "Beate Tr\u00f6ger"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2000,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliothek 2.0 -- Wird alles anders?",
#     "authors": [
#       "Patrick Danowski",
#       "Lambert Heller"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2007,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Bibliothek 2. 0: Die Zukunft der Bibliothek?",
#     "authors": [
#       "Patrick Danowski",
#       "Lambert Heller"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2006,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Akademische Soziale Netzwerke und ihre Auswirkungen auf wissenschaftliche Bibliotheken",
#     "authors": [
#       "Thomas Nachreiner"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2019,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Netzwerk \u201eGr\u00fcne Bibliothek\u201c gegr\u00fcndet",
#     "authors": [
#       "Berthold Schmitt"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2018,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Und wo sind hier die B\u00fccher? Bibliothek der Zukunft",
#     "authors": [
#       "Simon Strauss"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2015,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliothek - Mythos, Metapher, Maschine oder: Der ort der Bibliothek in der Lebenswelt der Stadt",
#     "authors": [
#       "Hans-Christoph Hobohm"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2000,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Telefonzelle wird zu Bibliothek",
#     "authors": [
#       "Redaktion K\u00e4rnten ORF"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2020,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Gr\u00fcne Bibliothek der Nachbarschaft",
#     "authors": [
#       "Gabriele Koll"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2015,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die unheimliche Bibliothek : Erz\u00e4hlung",
#     "authors": [
#       "Haruki Murakami",
#       "Kat Menschik"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2013,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Wielkopolska Biblioteka Cyfrowa (Gro\u00dfpolnische Digitale Bibliothek)",
#     "authors": [
#       "Wielkopolska Biblioteka Cyfrowa (Gro\u00dfpolnische Digitale Bibliothek)"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2008,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Bibliothek als Lernort - neue Servicekonzepte",
#     "authors": [
#       "Christine Gl\u00e4ser"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2008,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliothek 2.0 - Perspektiven, Probleme, Handlungsbereiche",
#     "authors": [
#       "Lambert Heller"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2008,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Open-Air-Bibliothek kam schon im Corona-Sommer gut an",
#     "authors": [
#       "Horst Fr\u00f6hling"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2021,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Zeusch f\u00fcr Eusch: Die Bibliothek der Dinge",
#     "authors": [
#       " Stadtb\u00fccherei Frankfurt am Main"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2021,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Unwahrscheinlichkeit von Wissenstradition und die Beharrlichkeit der Bibliothek",
#     "authors": [
#       "Wolfgang Ernst"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2018,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Gr\u00fcne Bibliothek - nachhaltig leben",
#     "authors": [
#       " Goethe-Institut Rum\u00e4nien"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2021,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliothek 2.0 - Die Zukunft der Bibliothek?",
#     "authors": [
#       "Patrick Danowski",
#       "Lambert Heller"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2006,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Kleidertausch in der Bibliothek",
#     "authors": [
#       " Shochzwei"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2019,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Bibliothek bei Nacht",
#     "authors": [
#       "Alberto Manguel"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2007,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bewegung am Lernort: Ein stromerzeugendes Fahrradergometer in der Philologischen Bibliothek der Freien Universit\u00e4t Berlin",
#     "authors": [
#       "Janet Wagner"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2019,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Basiskenntnis Bibliothek: eine Fachkunde f\u00fcr Fachangestellte f\u00fcr Medien- und Informationsdienste - Fachrichtung Bibliothek",
#     "authors": [
#       "Klaus-Peter B\u00f6ttger"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2011,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Warum es nicht funktioniert: Klimaanpassung und die \u00d6ffentliche Bibliothek",
#     "authors": [
#       "Sonja Schillings"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2022,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Was ist eine Gr\u00fcne Bibliothek?",
#     "authors": [
#       " IFLA Section Environment, Sustainability_and_Libraries"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2022,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Handelsblatt Management Bibliothek. Bd. 5: Die erfolgreichsten Unternehmer, L-Z",
#     "authors": [
#       "Handelsblatt Management Bibliothek"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2005,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Moderne Bibliothek",
#     "authors": [
#       " ?"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2008,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Grobkonzept Deutsche Digitale Bibliothek",
#     "authors": [
#       "Kai Stalmann",
#       "Reinhard Budde."
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2010,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Text und Data Mining: Herausforderungen und M\u00f6glichkeiten f\u00fcr Bibliotheken",
#     "authors": [
#       "Bastian Drees"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2016,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bewegung f\u00f6rdert Lernen: Neue Angebote am Lernort Bibliothek dargestellt am Beispiel der Philologischen Bibliothek der Freien Universit\u00e4t Berlin",
#     "authors": [
#       "Janet Wagner"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2020,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliothek 2.0",
#     "authors": [
#       " x"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2010,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Bibliothek der Dinge: Welche Rolle spielen Bibliotheken in der \"sharing economy\"?",
#     "authors": [
#       "_ Goethe-Institut Bratislava"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2016,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Bibliothek der Zukunft: eine Typologie von Zukunftsbeschreibungen",
#     "authors": [
#       "Jens Ilg"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2008,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Radfahren in der Bibliothek",
#     "authors": [
#       "_ Biblioblog; Freie Universit\u00e4t Berlin"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2019,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliothek 2.0 neue Perspektiven und Einsatzm\u00f6glichkeiten f\u00fcr wissenschaftliche Bibliotheken",
#     "authors": [
#       "Michaela Selbach"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2007,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Bibliothek von L\u00f6wen - Eine Episode aus der Zeit der Weltkriege",
#     "authors": [
#       "Wolfgang Schivelbusch"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1988,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Rolle der Bibliothek.",
#     "authors": [
#       "Elmar Mittler"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1995,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Bibliothek im Informationszeitalter",
#     "authors": [
#       "Robert Darnton"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2009,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Zukunft der digitalen Bibliothek",
#     "authors": [
#       "Jeanette Hofmann"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2009,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Der Neubau der Gesamthochschul-Bibliothek Kassel, Landesbibliothek und Murhardschen Bibliothek der Stadt Kassel",
#     "authors": [
#       "Hans-J\u00fcrgen Kahlfu\u00df"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1990,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Projekt Deutsche Digitale Bibliothek (DDB) Architekturdokumentation",
#     "authors": [
#       "Fraunhofer IAIS Cortex Plattform."
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2010,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Umweltbildung in nieders\u00e4chsischen Bibliotheken: Die B\u00fcchereizentrale Niedersachsen hat f\u00fcr 2022 ihre neue Kampagne \"Bildung - Nachhaltigkeit - Bibliothek (BiNaBi)\" ausgerufen",
#     "authors": [
#       " Redaktion BuB"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2022,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Veranstaltungen im Hof vor der Bibliothek am Wasserturm",
#     "authors": [
#       " Stadtbibliothek Pankow"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2021,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliothek mit F\u00f6rdeblick - Der Erweiterungsbau der Deutschen Zentralbibliothek f\u00fcr Wirtschaftswissenschaften (ZBW) in Kiel",
#     "authors": [
#       "Ralf Flohr"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2002,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "FaMI-Auszubildende als \"ForFuture-Denker/-innen\"! Dreit\u00e4giger Workshop zum Thema \"Gr\u00fcne Bibliothek\" inspiriert den Berufsnachwuchs",
#     "authors": [
#       "Saskia Kussin",
#       "Janet Wagner"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2022,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "LibraryThing ? die kollaborative Bibliothek 2.0",
#     "authors": [
#       " Czerwinski Silvia",
#       " Vo\u00df Jakob"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2010,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Social Software -- Bausteine einer \"Bibliothek 2.0\"",
#     "authors": [
#       "Lambert Heller"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2007,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Lexikon Buch - Bibliothek - Neue Medien",
#     "authors": [
#       "Dietmar Strauch",
#       "Margarete Rehm"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2007,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Lexikon Buch, Bibliothek, neue Medien",
#     "authors": [
#       "Dietmar Strauch",
#       "Margarete Rehm"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2007,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Auf dem Weg zur Deutschen Digitalen Bibliothek",
#     "authors": [
#       "Fraunhofer Institut f\u00fcr Intelligente Analyse-und Informationssysteme"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2008,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Social Software \u2013 Bausteine einer \"Bibliothek 2.0\"",
#     "authors": [
#       "Heller Lambert"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2007,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Buch, Bibliothek und geisteswissenschaftliche Forschung",
#     "authors": [
#       "Bernhard Fabian"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1983,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "LibraryThing -- die kollaborative Bibliothek 2.0",
#     "authors": [
#       "Silvia Czerwinski",
#       "Jakob Vo\u00df"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2010,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Die Bibliothek des Johann Christian von Boineburg (1622 - 1672)",
#     "authors": [
#       "Kathrin Paasch"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2005,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Vom Wert des Sammelns und vom Mehrwert des Digitalen : verstreute Bemerkungen zur gegenw\u00e4rtigen Lage der Bibliothek",
#     "authors": [
#       "Klaus Ceynowa"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2015,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Plan S in der Diskussion \u2013 Reaktionen aus der Wissenschaft auf die internationale Open-Access-Initiative",
#     "authors": [
#       "Mona Alina Kirsch"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2021,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die mittelalterliche Bibliothek der Abtei Wei\u00dfenau",
#     "authors": [
#       "Elke Wenzel"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1996,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliotheken im Web 2.0 \u2013 Bibliothek 2.0",
#     "authors": [
#       "Lambert Heller"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2009,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Bibliothek von Babel",
#     "authors": [
#       "Jorge Luis Borges"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1974,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Bibliotheca Alexandrina. Eine sich selbst erfindende Bibliothek des Lehrens und Lernens",
#     "authors": [
#       "Martin Nissen",
#       "Lambert Heller"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2010,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Ein St\u00fcck Bibliothek im Park: Ein Praxisbericht zum Einsatz des \u00bbbookbike nrw\u00ab bei der Stadtbibliothek Duisburg",
#     "authors": [
#       "Marita Dubke"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2020,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Stadtb\u00fccherei T\u00fcbingen - das Konzept \"Gr\u00fcne Bibliothek\"",
#     "authors": [
#       "Monika Fridrich"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2021,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Hitler-Jugend. Prim\ufffdr- und Sekund\ufffdrliteratur der Bibliothek f\ufffdr Bildungsgeschichtliche Forschung.",
#     "authors": [
#       " ?"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2003,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Von der elektronischen Bibliothek zur innovativen Forschungsinfrastruktur",
#     "authors": [
#       "Maria Effinger",
#       "Leonhard Maylein",
#       "Jakub \u0160imek"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2019,
#     "collected_by": "Fabian",
#     "number_authors": 3
#   },
#   {
#     "title": "Kujawsko-Pomorska Digitale Bibliothek",
#     "authors": [
#       "Universit\u00e4t Torun"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2008,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Studien zur Geschichte der Bibliothek von C\u00e4sarea",
#     "authors": [
#       "Marco Frenschkowski"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2006,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliothek der Dinge: Lieber leihen statt kaufen!",
#     "authors": [
#       "_ Stadtbibliothek Rosenheim"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2020,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Gr\u00fcne Bibliothek als Chance? Konzeptentwicklung f\u00fcr die Stadtb\u00fccherei Wedel. Bachelorarbeit",
#     "authors": [
#       "Carolyn Bauke"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2014,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Was ist eine Bibliothek?",
#     "authors": [
#       "Roland Wagner-D\u00f6bler"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2000,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Das Motiv der Bibliothek in der Kriminalliteratur",
#     "authors": [
#       "Zsuzsanna Csuka"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2016,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliothek 2.0: Die Zukunft der Bibliothek?",
#     "authors": [
#       "Lambert Heller Dirk Lewandoski"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2006,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "\ufffdDie elektronische Bibliothek : Literatur- und Informationsbeschaffung im Internet",
#     "authors": [
#       "Hans Hehl"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2001,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Welt der B\u00fccher. Eine Geschichte der Bibliothek",
#     "authors": [
#       "Matthew Battles"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2012,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Internes Wissensmanagement in kleineren Bibliotheken \u2013 Die Bibliothek des Wissenschaftsparks Albert Einstein",
#     "authors": [
#       "Katja Stender"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2013,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Inhaltliche Zusammenf\u00fchrung eines fach\u00fcbergreifenden Bibliothekbestandes am Beispiel der Martha-Muchow-Bibliothek der Universit\u00e4t Hamburg",
#     "authors": [
#       "Kea Cordlandwehr"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2017,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Automatisierte Volltexterschlie\u00dfung von Retrodigitalisaten am Beispiel historischer Zeitungen",
#     "authors": [
#       "Anna Kugler"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2018,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Digitale Welt und wissenschaftliche Bibliothek - Informationspraxis im Wandel: Determinanten, Ressourcen, Dienste, Kompetenzen ; eine Einf\u00fchrung",
#     "authors": [
#       "Wilfried S\u00fchl-Strohmenger"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2008,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Literatur unter B\u00e4umen: Die neue Open-Air-Bibliothek auf der Landesgartenschau in \u00dcberlingen",
#     "authors": [
#       " Schw\u00e4bische Zeitung"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2021,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliothek 2.0 - Neue Perspektiven und Einsatzm\u00f6glichkeiten f\u00fcr wissenschaftliche Bibliotheken",
#     "authors": [
#       "Selbach Michaela"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2007,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Recycling von B\u00fcchern: Die Bibliothek Lockenhaus wei\u00df auch \u00e4ltere B\u00fccher zu verwerten",
#     "authors": [
#       "Emmerich Gager"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2015,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Bibliothek als Dienstleister\r\nf\u00fcr den Umgang mit Forschungsdaten",
#     "authors": [
#       "Dr. Johanna Vompras",
#       "Jochen Schirrwagen",
#       "Dr. Wolfram Horstmann"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2011,
#     "collected_by": "Fabian",
#     "number_authors": 3
#   },
#   {
#     "title": "Die wissenschaftliche Bibliothek und ihre Effektivit\u00e4t aus bedienungstheoretischer Sicht",
#     "authors": [
#       "Karl Heinrich Bell"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1981,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Der Braunschweiger Stadtschreiber Gerwin von Hameln und seine Bibliothek",
#     "authors": [
#       "Anette Haucap-Nass"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1989,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die \u201egr\u00fcne Bibliothek\" - Wie wichtig Nachhaltigkeit f\u00fcr das deutsche Bibliothekswesen ist und warum es bis jetzt nur wenig praktische Ans\u00e4tze daf\u00fcr gibt",
#     "authors": [
#       "Filiz R\u00f6ger"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2015,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Philologie und Bibliothek \u2013 Philologie oder Bibliothek? Das Verh\u00e4ltnis von Fachstudium und Bibliothek als Herausforderung\r\nin beruflicher Praxis und bibliothekarischer Ausbildung",
#     "authors": [
#       "Marcus Schr\u00f6ter",
#       "Eric W. Steinhauer"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2005,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Modelica Predictive Control \u2013 An MPC Library for Modelica Eine MPC-Bibliothek f\u00fcr Modelica",
#     "authors": [
#       "Sebastian H\u00f6lemann",
#       "Dirk Abel"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2009,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Digitale Bibliothek",
#     "authors": [
#       " Gerland"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2007,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Merkw\u00fcrdigkeiten der k. k. garellischen \u00f6ffentl. Bibliothek am Theresiano",
#     "authors": [
#       "Johann Nepomuk Cosmas Michael Denis"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1780,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliotheca Zelteriana: Rekonstruktion der Bibliothek Carl Friedrich Zelters, alphabetischer Katalog",
#     "authors": [
#       "Thomas Richter"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1997,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Was bedeutet Open Access? Die Farben aus Sicht von Wissenschaft, Bibliothek und Gesellschaft.",
#     "authors": [
#       "Claudia Frick"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2020,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Zukunft der Informationsinfrastrukturen : das deutsche Bibliothekswesen im digitalen Zeitalter",
#     "authors": [
#       "Bastian Drees"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2016,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Ein Weblog als Informations-und Kommunikationsinstrument an der Universit\u00e4tsbibliothek der Medizinischen Universit\u00e4t Wien: 1 Jahr UBMUW-INFO",
#     "authors": [
#       "Bruno Hartl"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2007,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Das Raum-Informationssystem der Philologischen Bibliothek der Freien Universit\u00e4t Berlin",
#     "authors": [
#       "Michael Franke"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2006,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die mittelalterliche Bibliothek des Augustinerchorherrenstifts Sankt Mang in Stadtamhof/Regensburg",
#     "authors": [
#       "Franz Fuchs"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1987,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliothek und Internet : die Identit\u00e4tskrise einer Institution im digitalen Informationszeitalter",
#     "authors": [
#       "Achim Bonte",
#       "Klaus Ceynowa"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2013,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Aufbau und Nutzung einer digitalen Bibliothek in einer universit\u00e4ren Ausbildungsumgebung",
#     "authors": [
#       "Matthias Will"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2001,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Text und Data Mining : Herausforderungen und M\u00f6glichkeiten f\u00fcr Bibliotheken",
#     "authors": [
#       "Bastian Drees"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2016,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Franziskaner in G\u00f6ttingen: die Geschichte des Klosters und seiner Bibliothek",
#     "authors": [
#       "Eva Schlotheuber"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1994,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Entspannen unter Strom: Stromerzeugendes Fahrradergometer f\u00fcr Studierende in der Philologischen Bibliothek der Freien Universit\u00e4t aufgestellt",
#     "authors": [
#       "_ Freie Universit\u00e4t Berlin; Zentrale Online-Redaktion"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2019,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Bibliothek des Schweinfurter Stadtphysicus Dr. Johann Laurentius Bausch (1605 - 1665)",
#     "authors": [
#       "Claudia Michael"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1994,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Gr\u00fcne Bibliothek",
#     "authors": [
#       "Petra Hauke"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2015,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Bibliothek r\u00e4t",
#     "authors": [
#       "Christiane Schmidt ; Daniela Sendelbach ; Barbara Waszynski"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2010,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Ressourcen sparen bei Buchlieferungen -- ein Erfahrungsbericht aus der Philologischen Bibliothek. Biblioblog",
#     "authors": [
#       "Janet Wagner"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2021,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Zettelwirtschaft : die Geburt der Kartei aus dem Geiste der Bibliothek",
#     "authors": [
#       "Markus Krajewski"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2002,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliothek der Zeit",
#     "authors": [
#       "Rita Schreiner"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2020,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "C Standard-Bibliothek",
#     "authors": [
#       "Peter Klingebiel"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1999,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Umwelttage in der Bibliothek: Die Stadtb\u00fccherei Eggenburg hat die \"Eggenburger Umwelt- und Energietage\" ins Leben gerufen",
#     "authors": [
#       "Eva Gaspar"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2015,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Gr\u00fcne Bibliothek Malm\u00f6: Pilotversuch einer gr\u00fcnen Allmende in der Nachbarschaftsbibliothek Sofielund",
#     "authors": [
#       "Nicolas Keller"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2022,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Bibliothek des Klosters St. Maximin bei Trier bis zum 12. Jahrhundert",
#     "authors": [
#       "Isabel Knoblich"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1994,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Semantische Suche in einer digitalen Bibliothek",
#     "authors": [
#       "Natalja Friesen",
#       "Christoph Lange"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2015,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Informationskompetenz vermitteln \u2013 Das modulare Blended- Learning-Szenario der Bibliothek der Universit\u00e4t Konstanz",
#     "authors": [
#       "Sandra Merten"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2005,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Johannes Cincinnius von Lippstadt (ca. 1485 - 1555): Bibliothek und Geisteswelt eines westf\u00e4lischen Humanisten",
#     "authors": [
#       "Andreas Freit\u00e4ger"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1997,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Wie tr\u00e4gt Ihre Bibliothek zu einer nachhaltigen Entwicklung bei?",
#     "authors": [
#       "Nathalice Bezerra Cardoso"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2021,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die medizinische Literatur in der Bibliothek der Grafen von Sch\u00f6nborn in Schloss Pommersfelden",
#     "authors": [
#       "Benedikt Ignatzek"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1988,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Mein Traum von Bibliothek",
#     "authors": [
#       "Charlotte Bauer",
#       "Ulrich Johannes Schneider"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2011,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Ver\u00e4nderung des Verh\u00e4ltnisses von Kunde und Bibliothek",
#     "authors": [
#       "Nadin Wei\u00df"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2007,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die leishu der imperialen Bibliothek des Qianlong (reg. 1736 - 1796): Untersuchungen zur chinesischen Enzyklop\u00e4die",
#     "authors": [
#       "Christoph Kaderas"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1997,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Das sog. Evangeliar des Heiligen Augustinus, Cambridge, Bibliothek des Corpus Christi College, Cod. 286",
#     "authors": [
#       "Petra Guschewski"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1996,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Plattform f\u00fcr gesellschaftliche  Teilhabe und Integration: Zur Profilbildung der \u00d6ffentlichen Bibliothek. Rezension",
#     "authors": [
#       "Petra Hauke"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2018,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Nachhhaltigkeit in der Bibliothek",
#     "authors": [
#       "Petra Hauke"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2020,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Wissenschaft und Digitale Bibliothek",
#     "authors": [
#       "Klaus Fuchs-Kittowski"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2000,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Eine Bibliothek der Weltliteratur",
#     "authors": [
#       "Hermann Hesse"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1953,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bibliothek und Wissenschaft: wissenschaftstheoretische Probleme und Inhalte in der Ausbildung von Bibliothekaren und Informatoren",
#     "authors": [
#       "Peter St\u00e4ber"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1991,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Schwerpunkt: DARIAH-DE \u2013 Digitalit\u00e4t in den Geistes- und Kulturwissenschaften | Bibliothek \u2013 Forschung und Praxis",
#     "authors": [
#       " Varia"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2016,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Bibliothek von Nag Hammadi: einige Probleme des Christentums in \u00c4gypten w\u00e4hrend der ersten Jahrhunderte",
#     "authors": [
#       "Aleksandr Chosroev"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1994,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "HERAUSFORDERUNG BIBLIOTHEK 2.0: Chancen und Risiken f\u00fcr Verbundkataloge durch die Anreicherung mit Web 2.0-Konzepten",
#     "authors": [
#       "Barbara Haubenwaller"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2009,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Schrift, Wissen und Ged\u00e4chtnis. Das Motiv der Bibliothek als Spiegel des Medienwandels im 20. Jahrhundert",
#     "authors": [
#       "G\u00fcnther Stocker"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1997,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Untersuchungen zur Geschichte der Geburtszange und der Geburtshilfe aufgrund der Altbest\u00e4nde der Universit\u00e4ts-Frauenklinik-Bibliothek",
#     "authors": [
#       "ir Z hid"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1999,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Geschichte der chinesischen Bibliothek Tian Yi Ge vom 16. Jahrhundert bis in die Gegenwart",
#     "authors": [
#       "Ulrich Stackmann"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1990,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Krajewski, Markus: Zettelwirtschaft. Die Geburt der Kartei aus dem Geiste der Bibliothek. Berlin : Kulturverl. Kadmos, 2002. review",
#     "authors": [
#       "Thomas Hapke"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2002,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Future Library: Die K\u00fcnstlerin Katie Peterson pflanzt eine Bibliothek \u2013 und das im w\u00f6rtlichen Sinne. Interview",
#     "authors": [
#       "Simone Kremsberger",
#       "Katie Peterson"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2015,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Hochschulbibliografie 2008 (August)",
#     "authors": [
#       "MHH Hannover"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2008,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Partizipative Entwicklung von Diensten in der Bibliothek 2.0: Methoden und Ergebnisse aus Katalog-2.0-Projekten",
#     "authors": [
#       "Anne Christensen"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2009,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Literatur und Klosterreform: die Bibliothek der Benediktiner von St. Mang zu F\u00fcssen im 15. Jahrhundert",
#     "authors": [
#       "Christoph Roth"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1994,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Literatur und Klosterreform: die Bibliothek der Benediktiner von St. Mang zu Fu\u0308ssen im 15. Jahrhundert",
#     "authors": [
#       "Christoph Roth"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1994,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Hanns W. Eppelsheimer (1890-1972) : Bibliothekar, Literaturwissenschaftler, homme de lettres ; eine Ausstellung der Deutschen Bibliothek und der Stadt- und Universit\u00e4tsbibliothek Frankfurt",
#     "authors": [
#       "Harro Kieser",
#       "Germany Deutsche Bibliothek Frankfurt am Main",
#       " Stadt- und Universit\u00e4tsbibliothek Frankfurt am Main"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1990,
#     "collected_by": "Fabian",
#     "number_authors": 3
#   },
#   {
#     "title": "Eine studentische Musiksammlung der Reformationszeit: die Handschrift Misc. 236 a - d der Schermar-Bibliothek in Ulm",
#     "authors": [
#       "Alfred Wendel"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1991,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Individualisierte QR-Codes zur Verkn\u00fcpfung von Print- und E-Bestand",
#     "authors": [
#       "Gehrmann Petra"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2014,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Digitalisierung im bibliothekarischen Alltag am Beispiel der Universit\u00e4tsbibliothek Kassel - Landesbibliothek und Murhardsche Bibliothek der Stadt Kassel",
#     "authors": [
#       "Helge Steenweg"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2012,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Dautzenbergs B\u00fccher: Leben und Wirken des Peter Joseph Franz Dautzenberg (1769 - 1828) im Spiegel seiner Bibliothek",
#     "authors": [
#       "Frank Pohle"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1998,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Klimaschutz und Wurmkistenbau - mehr als nur ein Trend: Die B\u00fccherhallen Hamburg engagieren sich",
#     "authors": [
#       "Heinrike Buerke",
#       "Frauke Untiedt"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2019,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Die Bibliothek geht ins Gr\u00fcne",
#     "authors": [
#       "Hedwig Wei\u00df"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2015,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die g\u00fcne Bibliothek steht weltweit im Fokus: Bericht von der ENSULIB Konferenz in Berlin",
#     "authors": [
#       "A. Kaufmann"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2017,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Selbstbedienung in der hybriden Bibliothek",
#     "authors": [
#       "Glen E. Holt",
#       "Jens Ingemann Larsen",
#       "Vlimmeren Ton van"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2002,
#     "collected_by": "Fabian",
#     "number_authors": 3
#   },
#   {
#     "title": "librtipc - Bibliothek f\u00fcr echtzeitf\u00e4hige Interprozesskommunikation.",
#     "authors": [
#       "Josef Raschen"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2012,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Bibliothek des Klosters St. Pantaleon in K\u00f6ln bis zum 13. Jahrhundert: Studien zum geistigen Leben",
#     "authors": [
#       "Regina P\u00fctz"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1997,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Agenda 2030",
#     "authors": [
#       " HTWK Bibliothek Leipzig"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2021,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Funktion und Struktur der sozialistischen Hochschulbibliothek, dargestellt am Beispiel der Bibliothek der Technischen Hochschule Karl-Marx-Stadt",
#     "authors": [
#       "D Scheffel"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1973,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Der Systemcharakter der wissenschaftlichen Bibliothek: Grundlagen und Entwicklungsm\u00f6glichkeiten der wissenschaftlichen Bibliotheken der Bundesrepublik Deutschland aus systemtheoretischer Sicht",
#     "authors": [
#       "Felicitas Stroh"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1993,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Zur Entwicklung der Kommunalen \u00d6ffentlichen Bibliothek in der BRD 1969 - 1976 neunzehnhundertneunundsechzig bis neunzehnhundertsechsundsiebzig: Politik, \u00d6konomie, Ideologie",
#     "authors": [
#       "Klaus Pl\u00f6tz"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1981,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Buchdruck in Aachen 1573 - 1792: Untersuchungen zur Produktion Aachener Buchdrucker anhand des Bestandes der \u00d6ffentlichen Bibliothek Aachen",
#     "authors": [
#       "Walter Vennen"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1992,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "\"In einer Bibliothek, da sitzen Frauen!\" Qualitative Untersuchung zum Verh\u00e4ltnis von Frauen und M\u00e4nnern in einem Frauenberuf",
#     "authors": [
#       "Antje Bischoff-K\u00fcmmel"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1992,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Virtual reading room. Possibilities of a user-friendly presentation of collections via internet: BIBLIOTHEK Forschung und Praxis",
#     "authors": [
#       "Susanne Maier"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2007,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Technisch-wissenschaftliche Dokumentation in Deutschland von 1900 bis 1945: unter besonderer Ber\u00fccksichtigung des Verh\u00e4ltnisses von Bibliothek und Dokumentation",
#     "authors": [
#       "Elke Behrends"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1994,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "5 nachhaltige Ideen f\u00fcr Ihre Bibliothek",
#     "authors": [
#       " Bibliotheksfachstelle der Di\u00f6zese Linz"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2020,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Menschen, B\u00fccher und Computer / Berufsfeld Bibliothek",
#     "authors": [
#       "Anne Buhrfeind"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1994,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Bachs theologische Bibliothek: eine kritische Bibliographie",
#     "authors": [
#       "R. A. Leaver"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1983,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Library 2.0 \u00e2\\text\\euro`` New perspectives in research libraries and experiences in Germany: BIBLIOTHEK Forschung und Praxis",
#     "authors": [
#       "Michaela Selbach"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2009,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Technisch-wissenschaftliche Dokumentation in Deutschland von 1900 bis 1945: unter besonderer Beru\u0308cksichtigung des Verha\u0308ltnisses von Bibliothek und Dokumentation",
#     "authors": [
#       "Elke Behrends"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1994,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
# ...
#     "authors": [
#       "Holm Tetens"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1994,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Philosophische Schriften in 4 B\u00e4nden:  Hauptschriften zur Grundlegung der Philosophie. Teil 2:  \u00fcbersetzt von Artur Buchenau",
#     "authors": [
#       "Gottfried W. Leibniz"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1999,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Philosophische Schriften in 4 B\u00e4nden:  Hauptschriften zur Grundlegung der Philosophie. Teil 1:  \u00fcbersetzt von Artur Buchenau",
#     "authors": [
#       "Gottfried Wilhelm Leibniz"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1999,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Industrieller Friede?",
#     "authors": [
#       "Peter Hinrichs",
#       "Lothar Peter"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1976,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Networking mit Windows NT 4.0",
#     "authors": [
#       "Eric Tierling"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1997,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Ph\u00e4nomenologie des Geistes",
#     "authors": [
#       "Georg Wilhelm Friedrich Hegel"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1952,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Meditationen \u00fcber die Grundlagen der Philosophie",
#     "authors": [
#       "Ren\u00e9 Descartes"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1994,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Alt\u00e4gyptische Dichtung",
#     "authors": [
#       "Erik Hornung"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1996,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Was ist ein Text?",
#     "authors": [
#       "Paul Ric\u0153ur"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2005,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Einleitung zur Enzyklop\u00e4die von 1751",
#     "authors": [
#       "Jean Le Rond d' Alembert"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1955,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Dewey-Dezimalklassifikation und Register (DDC 22) ; 4 B\u00e4nde",
#     "authors": [
#       "Melvil Dewey",
#       "Joan Mitchell",
#       "Julianne Beall",
#       "Giles Martin",
#       "Winton Matthews",
#       "Gregory New",
#       "Germany Deutsche Bibliothek Frankfurt am Main"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2005,
#     "collected_by": "Fabian",
#     "number_authors": 7
#   },
#   {
#     "title": "Fernsehspuren im Handeln von Kindern",
#     "authors": [
#       "Ben Bachmair"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1984,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Wie Uli der Knecht gl\u00fccklich wird:  Eine Gabe f\u00fcr Dienstboten und Meisterleute:  Mit Illustrationen von Friedrich Walthard",
#     "authors": [
#       "Jeremias Gotthelf"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1984,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Niederhessen in der Krise?",
#     "authors": [
#       "Ingrid Baumg\u00e4rtner"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2006,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "\u00dcber Keynes und den Keynesianismus",
#     "authors": [
#       "Axel Leijonhufvud"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1973,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Arbeitsp\u00e4dagogik im Betrieb",
#     "authors": [
#       "Johannes Riedel"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1958,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Der Verfall des Fortschrittsgedankens in der \u00f6konomischen Theorie",
#     "authors": [
#       "Eugen Rau"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1972,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die BASF",
#     "authors": [
#       "J\u00fcrgen R\u00e4uschel"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1975,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "\u00d6ffentliche Betriebe",
#     "authors": [
#       "Albert Schnettler"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1956,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Kapitaltheorie",
#     "authors": [
#       "Jack Hirshleifer"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1974,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Fabrikbuchhaltung",
#     "authors": [
#       "Albert Calmes"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1909,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Gegen Unternehmermacht und Patriarchat",
#     "authors": [
#       " ?"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1989,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Wir sind in die Irre gegangen. Die Schuld der Kirche unterm Hakenkreuz, nach dem Bekenntnis des \u00bbDarmst\u00e4dter Wortes\u00ab von 1947",
#     "authors": [
#       "Hans Prolingheuer"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1987,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Am Beginn des Abschwungs: mit Arbeitszeitverk\u00fcrzung und Umweltprogrammen gegen die Krise",
#     "authors": [
#       " ?"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1987,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Philosophische Untersuchungen - Auf Grundlage der Kritisch-genetischen Edition, neu herausgegeben von Joachim Schulte, 2003",
#     "authors": [
#       "Ludwig Wittgenstein"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1953,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Monadologie:  franz\u00f6sisch--deutsch, \u00fcbersetzt und",
#     "authors": [
#       "Gottfried Wilhelm Leibniz"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1998,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Technik in der Antike",
#     "authors": [
#       "Brigitte Cech"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2010,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Philosophische Untersuchungen \u00fcber das Wesen der menschlichen Freiheit und die damit zusammenh\u00e4ngenden Gegenst\u00e4nde",
#     "authors": [
#       "Friedrich Wilhelm Joseph von Schelling",
#       "Thomas Buchheim"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1997,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Territorium und Stadt: Aufs\u00e4tze zur deutschen Verfassungs- Verwaltungs- und Wirtschaftsgeschichte",
#     "authors": [
#       "Georg von Below"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1923,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Der r\u00f6mische Staat, Teil 1: Die Republik",
#     "authors": [
#       "Ingemar K\u00f6nig"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1992,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Union der festen Hand",
#     "authors": [
#       "Erik Reger"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1979,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Maschinenfabrik N.&K. - Ein Roman aus dem proletarischen Alltag",
#     "authors": [
#       "Willi Bredel"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1975,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Martin Luther",
#     "authors": [
#       "Lucien Febvre"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1996,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Lichte Zukunft",
#     "authors": [
#       "Alexander Sinowjew"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1979,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Rasse, Blut und Gene \u2013 Geschichte der Eugenik und Rassenhygiene in Deutschland",
#     "authors": [
#       "Peter Weingart",
#       "J\u00fcrgen Kroll",
#       "Kurt Bayertz"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1988,
#     "collected_by": "Fabian",
#     "number_authors": 3
#   },
#   {
#     "title": "Menschen auf der Stra\u00dfe",
#     "authors": [
#       "Carsten K\u00fcther"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1983,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Ver\u00e4nderung der seelischen Gesundheit durch arbeitsmarktpolitische Ma\u00dfnahmen",
#     "authors": [
#       "Heike Behle"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2007,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Geht die Arbeitslosenversicherung in Rente?",
#     "authors": [
#       "Roman Lutz"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2009,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Sozialpsychologie",
#     "authors": [
#       "Leon Mann"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1976,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Geschichte der Arbeitslosigkeit",
#     "authors": [
#       "Frank Niess"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1979,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Lagerwirtschaft",
#     "authors": [
#       "Friedrich Henzel"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1950,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Kontenrahmen und Kontenpl\u00e4ne der Unternehmungen",
#     "authors": [
#       "Erich Kosiol"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1962,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die im Schatten leben",
#     "authors": [
#       "Walter Baumann"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1982,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "F\u00fcr eine besch\u00e4ftigungspolitische Offensive",
#     "authors": [
#       " ?"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1986,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Wo Organisation endet",
#     "authors": [
#       "Kenneth Joseph Arrow"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1980,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Methoden und Technik der Betriebsstatistik",
#     "authors": [
#       "Max Rudolf Lehmann"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1960,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Kommunikationspolitik als Gesellschaftspolitik",
#     "authors": [
#       "Franz Ronneberger"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1980,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Nationale Wettbewerbsvorteile",
#     "authors": [
#       "Michael E. Porter"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1999,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Der Selbstmord in der abendl\u00e4ndischen Epik des Hochmittelalters",
#     "authors": [
#       "Fritz Peter Knapp"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1979,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Staat, multinationale Konzerne und politische Union in Westeuropa",
#     "authors": [
#       "Heinz-J\u00fcrgen Axt"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1978,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Demokratische Wirtschaftspolitik gegen Marktmacht und Sparma\u00dfnahmen",
#     "authors": [
#       " ?"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1981,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "QuickStart PostScript",
#     "authors": [
#       "Florian D\u00e4umling",
#       "Daniel Sillescu"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1990,
#     "collected_by": "Fabian",
#     "number_authors": 2
#   },
#   {
#     "title": "Doctor Faustus",
#     "authors": [
#       "Frank Baron"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1978,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Geschichte schreiben in der Postmoderne:  Beitr\u00e4ge zur aktuellen Diskussion",
#     "authors": [
#       "Christoph Conrad"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1994,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Solidarit\u00e4t oder Objektivit\u00e4t?:  Drei philosophische Essays:  aus dem Engl. von Joachim Schulte",
#     "authors": [
#       "Richard Rorty"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1995,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Lateinische Umgangssprache",
#     "authors": [
#       "J. B. Hofmann"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1926,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Die Erfindung der Nation: zur Karriere eines folgenreichen Konzepts",
#     "authors": [
#       "Benedict R. O'G. Anderson"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 2005,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Der Islam: Eine Einf\u00fchrung",
#     "authors": [
#       "Annemarie Schimmel"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1997,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Vom Kriege: Auswahl",
#     "authors": [
#       "Carl von Clausewitz"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1995,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Minima Moralia. Reflexionen aus dem besch\u00e4digten Leben",
#     "authors": [
#       "Theodor Wiesengrund Adorno"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1951,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   },
#   {
#     "title": "Zum ewigen Frieden",
#     "authors": [
#       "Immanuel Kant"
#     ],
#     "type": "Publication",
#     "year_correct": true,
#     "year_number": 1992,
#     "collected_by": "Fabian",
#     "number_authors": 1
#   }
# ]

# %% [markdown]
# ## Fragestunde 23.01.

# %% [markdown]
# #### wie kann man sich mehr als die ersten und die letzten 5 Einträge/Zeilen anzeigen lassen?

# %%
df_bibsonomy_selection.head(20)
# Out:
#                                                   title  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# ...                                                 ...
# 1021  Bibliothek 2.0 - Perspektiven, Probleme, Handl...
# 1022  Open-Air-Bibliothek kam schon im Corona-Sommer...
# 1024         Zeusch für Eusch: Die Bibliothek der Dinge
# 1025  Die Unwahrscheinlichkeit von Wissenstradition ...
# 1026            Die Grüne Bibliothek - nachhaltig leben
#
#                                               authors         type  \
# 1000     [ Berufsverband Information Bibliothek e.V.]  Publication
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]  Publication
# 1002                                 [Manuela Schulz]  Publication
# 1003                                   [Beate Tröger]  Publication
# 1004               [Patrick Danowski, Lambert Heller]  Publication
# ...                                               ...          ...
# 1021                                 [Lambert Heller]  Publication
# 1022                                 [Horst Fröhling]  Publication
# 1024               [ Stadtbücherei Frankfurt am Main]  Publication
# 1025                                 [Wolfgang Ernst]  Publication
# 1026                      [ Goethe-Institut Rumänien]  Publication
#
#       year_correct  year_number collected_by  number_authors  \
# 1000          True         2021       Fabian               1
# 1001          True         2007       Fabian               2
# 1002          True         2010       Fabian               1
# 1003          True         2000       Fabian               1
# 1004          True         2007       Fabian               2
# ...            ...          ...          ...             ...
# 1021          True         2008       Fabian               1
# 1022          True         2021       Fabian               1
# 1024          True         2021       Fabian               1
# 1025          True         2018       Fabian               1
# 1026          True         2021       Fabian               1
#
#                                        Erstautor
# 1000   Berufsverband Information Bibliothek e.V.
# 1001                            Michaela Selbach
# 1002                              Manuela Schulz
# 1003                                Beate Tröger
# 1004                            Patrick Danowski
# ...                                          ...
# 1021                              Lambert Heller
# 1022                              Horst Fröhling
# 1024             Stadtbücherei Frankfurt am Main
# 1025                              Wolfgang Ernst
# 1026                    Goethe-Institut Rumänien
#
# [20 rows x 8 columns]

# %%
# maximale anzahl angezeigter reihen
pd.set_option('display.max_rows', 50)

# %%
df_bibsonomy_selection.head(25)
# Out:
#                                                   title  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# 1005       Bibliothek 2. 0: Die Zukunft der Bibliothek?
# 1011  Akademische Soziale Netzwerke und ihre Auswirk...
# 1012              Netzwerk „Grüne Bibliothek“ gegründet
# 1013  Und wo sind hier die Bücher? Bibliothek der Zu...
# 1014  Bibliothek - Mythos, Metapher, Maschine oder: ...
# 1015                    Telefonzelle wird zu Bibliothek
# 1017             Die Grüne Bibliothek der Nachbarschaft
# 1018             Die unheimliche Bibliothek : Erzählung
# 1019  Wielkopolska Biblioteka Cyfrowa (Großpolnische...
# 1020  Die Bibliothek als Lernort - neue Servicekonzepte
# 1021  Bibliothek 2.0 - Perspektiven, Probleme, Handl...
# 1022  Open-Air-Bibliothek kam schon im Corona-Sommer...
# 1024         Zeusch für Eusch: Die Bibliothek der Dinge
# 1025  Die Unwahrscheinlichkeit von Wissenstradition ...
# 1026            Die Grüne Bibliothek - nachhaltig leben
# 1029       Bibliothek 2.0 - Die Zukunft der Bibliothek?
# 1032                    Kleidertausch in der Bibliothek
# 1035                           Die Bibliothek bei Nacht
# 1036  Bewegung am Lernort: Ein stromerzeugendes Fahr...
# 1037  Basiskenntnis Bibliothek: eine Fachkunde für F...
#
#                                                 authors         type  \
# 1000       [ Berufsverband Information Bibliothek e.V.]  Publication
# 1001    [Michaela Selbach, Bibliothek der Fachhochsch.]  Publication
# 1002                                   [Manuela Schulz]  Publication
# 1003                                     [Beate Tröger]  Publication
# 1004                 [Patrick Danowski, Lambert Heller]  Publication
# 1005                 [Patrick Danowski, Lambert Heller]  Publication
# 1011                                [Thomas Nachreiner]  Publication
# 1012                                 [Berthold Schmitt]  Publication
# 1013                                    [Simon Strauss]  Publication
# 1014                            [Hans-Christoph Hobohm]  Publication
# 1015                            [Redaktion Kärnten ORF]  Publication
# 1017                                    [Gabriele Koll]  Publication
# 1018                    [Haruki Murakami, Kat Menschik]  Publication
# 1019  [Wielkopolska Biblioteka Cyfrowa (Großpolnisch...  Publication
# 1020                                 [Christine Gläser]  Publication
# 1021                                   [Lambert Heller]  Publication
# 1022                                   [Horst Fröhling]  Publication
# 1024                 [ Stadtbücherei Frankfurt am Main]  Publication
# 1025                                   [Wolfgang Ernst]  Publication
# 1026                        [ Goethe-Institut Rumänien]  Publication
# 1029                 [Patrick Danowski, Lambert Heller]  Publication
# 1032                                       [ Shochzwei]  Publication
# 1035                                  [Alberto Manguel]  Publication
# 1036                                     [Janet Wagner]  Publication
# 1037                              [Klaus-Peter Böttger]  Publication
#
#       year_correct  year_number collected_by  number_authors  \
# 1000          True         2021       Fabian               1
# 1001          True         2007       Fabian               2
# 1002          True         2010       Fabian               1
# 1003          True         2000       Fabian               1
# 1004          True         2007       Fabian               2
# 1005          True         2006       Fabian               2
# 1011          True         2019       Fabian               1
# 1012          True         2018       Fabian               1
# 1013          True         2015       Fabian               1
# 1014          True         2000       Fabian               1
# 1015          True         2020       Fabian               1
# 1017          True         2015       Fabian               1
# 1018          True         2013       Fabian               2
# 1019          True         2008       Fabian               1
# 1020          True         2008       Fabian               1
# 1021          True         2008       Fabian               1
# 1022          True         2021       Fabian               1
# 1024          True         2021       Fabian               1
# 1025          True         2018       Fabian               1
# 1026          True         2021       Fabian               1
# 1029          True         2006       Fabian               2
# 1032          True         2019       Fabian               1
# 1035          True         2007       Fabian               1
# 1036          True         2019       Fabian               1
# 1037          True         2011       Fabian               1
#
#                                               Erstautor
# 1000          Berufsverband Information Bibliothek e.V.
# 1001                                   Michaela Selbach
# 1002                                     Manuela Schulz
# 1003                                       Beate Tröger
# 1004                                   Patrick Danowski
# 1005                                   Patrick Danowski
# 1011                                  Thomas Nachreiner
# 1012                                   Berthold Schmitt
# 1013                                      Simon Strauss
# 1014                              Hans-Christoph Hobohm
# 1015                              Redaktion Kärnten ORF
# 1017                                      Gabriele Koll
# 1018                                    Haruki Murakami
# 1019  Wielkopolska Biblioteka Cyfrowa (Großpolnische...
# 1020                                   Christine Gläser
# 1021                                     Lambert Heller
# 1022                                     Horst Fröhling
# 1024                    Stadtbücherei Frankfurt am Main
# 1025                                     Wolfgang Ernst
# 1026                           Goethe-Institut Rumänien
# 1029                                   Patrick Danowski
# 1032                                          Shochzwei
# 1035                                    Alberto Manguel
# 1036                                       Janet Wagner
# 1037                                Klaus-Peter Böttger

# %%
df_bibsonomy_selection.iloc[20:50]
# Out:
#                                                   title  \
# 1029       Bibliothek 2.0 - Die Zukunft der Bibliothek?
# 1032                    Kleidertausch in der Bibliothek
# 1035                           Die Bibliothek bei Nacht
# 1036  Bewegung am Lernort: Ein stromerzeugendes Fahr...
# 1037  Basiskenntnis Bibliothek: eine Fachkunde für F...
# 1038  Warum es nicht funktioniert: Klimaanpassung un...
# 1039                     Was ist eine Grüne Bibliothek?
# 1040  Handelsblatt Management Bibliothek. Bd. 5: Die...
# 1041                                 Moderne Bibliothek
# 1042           Grobkonzept Deutsche Digitale Bibliothek
# 1043  Text und Data Mining: Herausforderungen und Mö...
# 1044  Bewegung fördert Lernen: Neue Angebote am Lern...
# 1045                                     Bibliothek 2.0
# 1051  Die Bibliothek der Dinge: Welche Rolle spielen...
# 1052  Die Bibliothek der Zukunft: eine Typologie von...
# 1053                        Radfahren in der Bibliothek
# 1054  Bibliothek 2.0 neue Perspektiven und Einsatzmö...
# 1055  Die Bibliothek von Löwen - Eine Episode aus de...
# 1056                          Die Rolle der Bibliothek.
# 1058            Die Bibliothek im Informationszeitalter
# 1059                   Zukunft der digitalen Bibliothek
# 1060  Der Neubau der Gesamthochschul-Bibliothek Kass...
# 1061  Projekt Deutsche Digitale Bibliothek (DDB) Arc...
# 1062  Umweltbildung in niedersächsischen Bibliotheke...
# 1063  Veranstaltungen im Hof vor der Bibliothek am W...
# 1064  Bibliothek mit Fördeblick - Der Erweiterungsba...
# 1065  FaMI-Auszubildende als "ForFuture-Denker/-inne...
# 1066    LibraryThing ? die kollaborative Bibliothek 2.0
# 1067  Social Software -- Bausteine einer "Bibliothek...
# 1068            Lexikon Buch - Bibliothek - Neue Medien
#
#                                                 authors         type  \
# 1029                 [Patrick Danowski, Lambert Heller]  Publication
# 1032                                       [ Shochzwei]  Publication
# 1035                                  [Alberto Manguel]  Publication
# 1036                                     [Janet Wagner]  Publication
# 1037                              [Klaus-Peter Böttger]  Publication
# 1038                                 [Sonja Schillings]  Publication
# 1039  [ IFLA Section Environment, Sustainability_and...  Publication
# 1040               [Handelsblatt Management Bibliothek]  Publication
# 1041                                               [ ?]  Publication
# 1042                    [Kai Stalmann, Reinhard Budde.]  Publication
# 1043                                    [Bastian Drees]  Publication
# 1044                                     [Janet Wagner]  Publication
# 1045                                               [ x]  Publication
# 1051                     [_ Goethe-Institut Bratislava]  Publication
# 1052                                         [Jens Ilg]  Publication
# 1053           [_ Biblioblog; Freie Universität Berlin]  Publication
# 1054                                 [Michaela Selbach]  Publication
# 1055                            [Wolfgang Schivelbusch]  Publication
# 1056                                    [Elmar Mittler]  Publication
# 1058                                   [Robert Darnton]  Publication
# 1059                                 [Jeanette Hofmann]  Publication
# 1060                              [Hans-Jürgen Kahlfuß]  Publication
# 1061                [Fraunhofer IAIS Cortex Plattform.]  Publication
# 1062                                   [ Redaktion BuB]  Publication
# 1063                          [ Stadtbibliothek Pankow]  Publication
# 1064                                       [Ralf Flohr]  Publication
# 1065                      [Saskia Kussin, Janet Wagner]  Publication
# 1066                   [ Czerwinski Silvia,  Voß Jakob]  Publication
# 1067                                   [Lambert Heller]  Publication
# 1068                  [Dietmar Strauch, Margarete Rehm]  Publication
#
#       year_correct  year_number collected_by  number_authors
# 1029          True         2006       Fabian               2
# 1032          True         2019       Fabian               1
# 1035          True         2007       Fabian               1
# 1036          True         2019       Fabian               1
# 1037          True         2011       Fabian               1
# 1038          True         2022       Fabian               1
# 1039          True         2022       Fabian               1
# 1040          True         2005       Fabian               1
# 1041          True         2008       Fabian               1
# 1042          True         2010       Fabian               2
# 1043          True         2016       Fabian               1
# 1044          True         2020       Fabian               1
# 1045          True         2010       Fabian               1
# 1051          True         2016       Fabian               1
# 1052          True         2008       Fabian               1
# 1053          True         2019       Fabian               1
# 1054          True         2007       Fabian               1
# 1055          True         1988       Fabian               1
# 1056          True         1995       Fabian               1
# 1058          True         2009       Fabian               1
# 1059          True         2009       Fabian               1
# 1060          True         1990       Fabian               1
# 1061          True         2010       Fabian               1
# 1062          True         2022       Fabian               1
# 1063          True         2021       Fabian               1
# 1064          True         2002       Fabian               1
# 1065          True         2022       Fabian               2
# 1066          True         2010       Fabian               2
# 1067          True         2007       Fabian               1
# 1068          True         2007       Fabian               2

# %% [markdown]
# #### Wie kann man aus einem df mehrere Spalten löschen, ohne alle einzeln eingeben zu müssen?

# %%
df_bibsonomy_selection
# Out:
#                                                   title  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                               authors         type  \
# 1000     [ Berufsverband Information Bibliothek e.V.]  Publication
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]  Publication
# 1002                                 [Manuela Schulz]  Publication
# 1003                                   [Beate Tröger]  Publication
# 1004               [Patrick Danowski, Lambert Heller]  Publication
# ...                                               ...          ...
# 1995                      [Benedict R. O'G. Anderson]  Publication
# 1996                             [Annemarie Schimmel]  Publication
# 1997                            [Carl von Clausewitz]  Publication
# 1998                     [Theodor Wiesengrund Adorno]  Publication
# 1999                                  [Immanuel Kant]  Publication
#
#       year_correct  year_number collected_by  number_authors  \
# 1000          True         2021       Fabian               1
# 1001          True         2007       Fabian               2
# 1002          True         2010       Fabian               1
# 1003          True         2000       Fabian               1
# 1004          True         2007       Fabian               2
# ...            ...          ...          ...             ...
# 1995          True         2005       Fabian               1
# 1996          True         1997       Fabian               1
# 1997          True         1995       Fabian               1
# 1998          True         1951       Fabian               1
# 1999          True         1992       Fabian               1
#
#                                        Erstautor
# 1000   Berufsverband Information Bibliothek e.V.
# 1001                            Michaela Selbach
# 1002                              Manuela Schulz
# 1003                                Beate Tröger
# 1004                            Patrick Danowski
# ...                                          ...
# 1995                   Benedict R. O'G. Anderson
# 1996                          Annemarie Schimmel
# 1997                         Carl von Clausewitz
# 1998                  Theodor Wiesengrund Adorno
# 1999                               Immanuel Kant
#
# [834 rows x 8 columns]

# %%
df_bibsonomy_selection.drop(columns=['type', 'collected_by'])
# Out:
#                                                   title  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                               authors  year_correct  \
# 1000     [ Berufsverband Information Bibliothek e.V.]          True
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]          True
# 1002                                 [Manuela Schulz]          True
# 1003                                   [Beate Tröger]          True
# 1004               [Patrick Danowski, Lambert Heller]          True
# ...                                               ...           ...
# 1995                      [Benedict R. O'G. Anderson]          True
# 1996                             [Annemarie Schimmel]          True
# 1997                            [Carl von Clausewitz]          True
# 1998                     [Theodor Wiesengrund Adorno]          True
# 1999                                  [Immanuel Kant]          True
#
#       year_number  number_authors
# 1000         2021               1
# 1001         2007               2
# 1002         2010               1
# 1003         2000               1
# 1004         2007               2
# ...           ...             ...
# 1995         2005               1
# 1996         1997               1
# 1997         1995               1
# 1998         1951               1
# 1999         1992               1
#
# [834 rows x 5 columns]

# %%
df_bibsonomy_selection[['type', 'collected_by']]
# Out:
#              type collected_by
# 1000  Publication       Fabian
# 1001  Publication       Fabian
# 1002  Publication       Fabian
# 1003  Publication       Fabian
# 1004  Publication       Fabian
# ...           ...          ...
# 1995  Publication       Fabian
# 1996  Publication       Fabian
# 1997  Publication       Fabian
# 1998  Publication       Fabian
# 1999  Publication       Fabian
#
# [834 rows x 2 columns]

# %%
df_bibsonomy_selection.drop([1000,1001, 1002], axis="index")
# Out:
#                                                   title  \
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# 1005       Bibliothek 2. 0: Die Zukunft der Bibliothek?
# 1011  Akademische Soziale Netzwerke und ihre Auswirk...
# 1012              Netzwerk „Grüne Bibliothek“ gegründet
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                  authors         type  year_correct  \
# 1003                      [Beate Tröger]  Publication          True
# 1004  [Patrick Danowski, Lambert Heller]  Publication          True
# 1005  [Patrick Danowski, Lambert Heller]  Publication          True
# 1011                 [Thomas Nachreiner]  Publication          True
# 1012                  [Berthold Schmitt]  Publication          True
# ...                                  ...          ...           ...
# 1995         [Benedict R. O'G. Anderson]  Publication          True
# 1996                [Annemarie Schimmel]  Publication          True
# 1997               [Carl von Clausewitz]  Publication          True
# 1998        [Theodor Wiesengrund Adorno]  Publication          True
# 1999                     [Immanuel Kant]  Publication          True
#
#       year_number collected_by  number_authors                   Erstautor
# 1003         2000       Fabian               1                Beate Tröger
# 1004         2007       Fabian               2            Patrick Danowski
# 1005         2006       Fabian               2            Patrick Danowski
# 1011         2019       Fabian               1           Thomas Nachreiner
# 1012         2018       Fabian               1            Berthold Schmitt
# ...           ...          ...             ...                         ...
# 1995         2005       Fabian               1   Benedict R. O'G. Anderson
# 1996         1997       Fabian               1          Annemarie Schimmel
# 1997         1995       Fabian               1         Carl von Clausewitz
# 1998         1951       Fabian               1  Theodor Wiesengrund Adorno
# 1999         1992       Fabian               1               Immanuel Kant
#
# [831 rows x 8 columns]

# %%
df_bibsonomy_selection.drop(index=[1000,1001,1002])
# Out:
#                                                   title  \
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# 1005       Bibliothek 2. 0: Die Zukunft der Bibliothek?
# 1011  Akademische Soziale Netzwerke und ihre Auswirk...
# 1012              Netzwerk „Grüne Bibliothek“ gegründet
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                  authors         type  year_correct  \
# 1003                      [Beate Tröger]  Publication          True
# 1004  [Patrick Danowski, Lambert Heller]  Publication          True
# 1005  [Patrick Danowski, Lambert Heller]  Publication          True
# 1011                 [Thomas Nachreiner]  Publication          True
# 1012                  [Berthold Schmitt]  Publication          True
# ...                                  ...          ...           ...
# 1995         [Benedict R. O'G. Anderson]  Publication          True
# 1996                [Annemarie Schimmel]  Publication          True
# 1997               [Carl von Clausewitz]  Publication          True
# 1998        [Theodor Wiesengrund Adorno]  Publication          True
# 1999                     [Immanuel Kant]  Publication          True
#
#       year_number collected_by  number_authors
# 1003         2000       Fabian               1
# 1004         2007       Fabian               2
# 1005         2006       Fabian               2
# 1011         2019       Fabian               1
# 1012         2018       Fabian               1
# ...           ...          ...             ...
# 1995         2005       Fabian               1
# 1996         1997       Fabian               1
# 1997         1995       Fabian               1
# 1998         1951       Fabian               1
# 1999         1992       Fabian               1
#
# [831 rows x 7 columns]

# %%
df_bibsonomy_selection.drop(index=range(1002,1005))
# Out:
#                                                   title  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1005       Bibliothek 2. 0: Die Zukunft der Bibliothek?
# 1011  Akademische Soziale Netzwerke und ihre Auswirk...
# 1012              Netzwerk „Grüne Bibliothek“ gegründet
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                               authors         type  \
# 1000     [ Berufsverband Information Bibliothek e.V.]  Publication
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]  Publication
# 1005               [Patrick Danowski, Lambert Heller]  Publication
# 1011                              [Thomas Nachreiner]  Publication
# 1012                               [Berthold Schmitt]  Publication
# ...                                               ...          ...
# 1995                      [Benedict R. O'G. Anderson]  Publication
# 1996                             [Annemarie Schimmel]  Publication
# 1997                            [Carl von Clausewitz]  Publication
# 1998                     [Theodor Wiesengrund Adorno]  Publication
# 1999                                  [Immanuel Kant]  Publication
#
#       year_correct  year_number collected_by  number_authors  \
# 1000          True         2021       Fabian               1
# 1001          True         2007       Fabian               2
# 1005          True         2006       Fabian               2
# 1011          True         2019       Fabian               1
# 1012          True         2018       Fabian               1
# ...            ...          ...          ...             ...
# 1995          True         2005       Fabian               1
# 1996          True         1997       Fabian               1
# 1997          True         1995       Fabian               1
# 1998          True         1951       Fabian               1
# 1999          True         1992       Fabian               1
#
#                                        Erstautor
# 1000   Berufsverband Information Bibliothek e.V.
# 1001                            Michaela Selbach
# 1005                            Patrick Danowski
# 1011                           Thomas Nachreiner
# 1012                            Berthold Schmitt
# ...                                          ...
# 1995                   Benedict R. O'G. Anderson
# 1996                          Annemarie Schimmel
# 1997                         Carl von Clausewitz
# 1998                  Theodor Wiesengrund Adorno
# 1999                               Immanuel Kant
#
# [831 rows x 8 columns]

# %% [markdown]
# #### auf das Feld author kann ich kein unique() anwenden ---> weil es vom Typ Liste ist??

# %%
df_bibsonomy_selection["authors"].unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [141], line 1
# ----> 1 df_bibsonomy_selection["authors"].unique()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/series.py:2242, in Series.unique(self)
#    2183 def unique(self) -> ArrayLike:
#    2184     """
#    2185     Return unique values of Series object.
#    2186
#    (...)
#    2240     Categories (3, object): ['a' < 'b' < 'c']
#    2241     """
# -> 2242     return super().unique()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/base.py:1001, in IndexOpsMixin.unique(self)
#     999         result = np.asarray(result)
#    1000 else:
# -> 1001     result = unique1d(values)
#    1003 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/algorithms.py:409, in unique(values)
#     315 def unique(values):
#     316     """
#     317     Return unique values based on a hash table.
#     318
#    (...)
#     407     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     408     """
# --> 409     return unique_with_mask(values)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/algorithms.py:425, in unique_with_mask(values, mask)
#     423 table = htable(len(values))
#     424 if mask is None:
# --> 425     uniques = table.unique(values)
#     426     uniques = _reconstruct_data(uniques, original.dtype, original)
#     427     return uniques
#
# File pandas/_libs/hashtable_class_helper.pxi:5910, in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# File pandas/_libs/hashtable_class_helper.pxi:5857, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
df_bibsonomy_selection["authors"].to_list()
# Out:
# [[' Berufsverband Information Bibliothek e.V.'],
#  ['Michaela Selbach', 'Bibliothek der Fachhochsch.'],
#  ['Manuela Schulz'],
#  ['Beate Tröger'],
#  ['Patrick Danowski', 'Lambert Heller'],
#  ['Patrick Danowski', 'Lambert Heller'],
#  ['Thomas Nachreiner'],
#  ['Berthold Schmitt'],
#  ['Simon Strauss'],
#  ['Hans-Christoph Hobohm'],
#  ['Redaktion Kärnten ORF'],
#  ['Gabriele Koll'],
#  ['Haruki Murakami', 'Kat Menschik'],
#  ['Wielkopolska Biblioteka Cyfrowa (Großpolnische Digitale Bibliothek)'],
#  ['Christine Gläser'],
#  ['Lambert Heller'],
#  ['Horst Fröhling'],
#  [' Stadtbücherei Frankfurt am Main'],
#  ['Wolfgang Ernst'],
#  [' Goethe-Institut Rumänien'],
#  ['Patrick Danowski', 'Lambert Heller'],
#  [' Shochzwei'],
#  ['Alberto Manguel'],
#  ['Janet Wagner'],
#  ['Klaus-Peter Böttger'],
#  ['Sonja Schillings'],
#  [' IFLA Section Environment, Sustainability_and_Libraries'],
#  ['Handelsblatt Management Bibliothek'],
#  [' ?'],
#  ['Kai Stalmann', 'Reinhard Budde.'],
#  ['Bastian Drees'],
#  ['Janet Wagner'],
#  [' x'],
#  ['_ Goethe-Institut Bratislava'],
#  ['Jens Ilg'],
#  ['_ Biblioblog; Freie Universität Berlin'],
#  ['Michaela Selbach'],
#  ['Wolfgang Schivelbusch'],
#  ['Elmar Mittler'],
#  ['Robert Darnton'],
#  ['Jeanette Hofmann'],
#  ['Hans-Jürgen Kahlfuß'],
#  ['Fraunhofer IAIS Cortex Plattform.'],
#  [' Redaktion BuB'],
#  [' Stadtbibliothek Pankow'],
#  ['Ralf Flohr'],
#  ['Saskia Kussin', 'Janet Wagner'],
#  [' Czerwinski Silvia', ' Voß Jakob'],
#  ['Lambert Heller'],
#  ['Dietmar Strauch', 'Margarete Rehm'],
#  ['Dietmar Strauch', 'Margarete Rehm'],
#  ['Fraunhofer Institut für Intelligente Analyse-und Informationssysteme'],
#  ['Heller Lambert'],
#  ['Bernhard Fabian'],
#  ['Silvia Czerwinski', 'Jakob Voß'],
#  ['Kathrin Paasch'],
#  ['Klaus Ceynowa'],
#  ['Mona Alina Kirsch'],
#  ['Elke Wenzel'],
#  ['Lambert Heller'],
#  ['Jorge Luis Borges'],
#  ['Martin Nissen', 'Lambert Heller'],
#  ['Marita Dubke'],
#  ['Monika Fridrich'],
#  [' ?'],
#  ['Maria Effinger', 'Leonhard Maylein', 'Jakub Šimek'],
#  ['Universität Torun'],
#  ['Marco Frenschkowski'],
#  ['_ Stadtbibliothek Rosenheim'],
#  ['Carolyn Bauke'],
#  ['Roland Wagner-Döbler'],
#  ['Zsuzsanna Csuka'],
#  ['Lambert Heller Dirk Lewandoski'],
#  ['Hans Hehl'],
#  ['Matthew Battles'],
#  ['Katja Stender'],
#  ['Kea Cordlandwehr'],
#  ['Anna Kugler'],
#  ['Wilfried Sühl-Strohmenger'],
#  [' Schwäbische Zeitung'],
#  ['Selbach Michaela'],
#  ['Emmerich Gager'],
#  ['Dr. Johanna Vompras', 'Jochen Schirrwagen', 'Dr. Wolfram Horstmann'],
#  ['Karl Heinrich Bell'],
#  ['Anette Haucap-Nass'],
#  ['Filiz Röger'],
#  ['Marcus Schröter', 'Eric W. Steinhauer'],
#  ['Sebastian Hölemann', 'Dirk Abel'],
#  [' Gerland'],
#  ['Johann Nepomuk Cosmas Michael Denis'],
#  ['Thomas Richter'],
#  ['Claudia Frick'],
#  ['Bastian Drees'],
#  ['Bruno Hartl'],
#  ['Michael Franke'],
#  ['Franz Fuchs'],
#  ['Achim Bonte', 'Klaus Ceynowa'],
#  ['Matthias Will'],
#  ['Bastian Drees'],
#  ['Eva Schlotheuber'],
#  ['_ Freie Universität Berlin; Zentrale Online-Redaktion'],
#  ['Claudia Michael'],
#  ['Petra Hauke'],
#  ['Christiane Schmidt ; Daniela Sendelbach ; Barbara Waszynski'],
#  ['Janet Wagner'],
#  ['Markus Krajewski'],
#  ['Rita Schreiner'],
#  ['Peter Klingebiel'],
#  ['Eva Gaspar'],
#  ['Nicolas Keller'],
#  ['Isabel Knoblich'],
#  ['Natalja Friesen', 'Christoph Lange'],
#  ['Sandra Merten'],
#  ['Andreas Freitäger'],
#  ['Nathalice Bezerra Cardoso'],
#  ['Benedikt Ignatzek'],
#  ['Charlotte Bauer', 'Ulrich Johannes Schneider'],
#  ['Nadin Weiß'],
#  ['Christoph Kaderas'],
#  ['Petra Guschewski'],
#  ['Petra Hauke'],
#  ['Petra Hauke'],
#  ['Klaus Fuchs-Kittowski'],
#  ['Hermann Hesse'],
#  ['Peter Stäber'],
#  [' Varia'],
#  ['Aleksandr Chosroev'],
#  ['Barbara Haubenwaller'],
#  ['Günther Stocker'],
#  ['ir Z hid'],
#  ['Ulrich Stackmann'],
#  ['Thomas Hapke'],
#  ['Simone Kremsberger', 'Katie Peterson'],
#  ['MHH Hannover'],
#  ['Anne Christensen'],
#  ['Christoph Roth'],
#  ['Christoph Roth'],
#  ['Harro Kieser',
#   'Germany Deutsche Bibliothek Frankfurt am Main',
#   ' Stadt- und Universitätsbibliothek Frankfurt am Main'],
#  ['Alfred Wendel'],
#  ['Gehrmann Petra'],
#  ['Helge Steenweg'],
#  ['Frank Pohle'],
#  ['Heinrike Buerke', 'Frauke Untiedt'],
#  ['Hedwig Weiß'],
#  ['A. Kaufmann'],
#  ['Glen E. Holt', 'Jens Ingemann Larsen', 'Vlimmeren Ton van'],
#  ['Josef Raschen'],
#  ['Regina Pütz'],
#  [' HTWK Bibliothek Leipzig'],
#  ['D Scheffel'],
#  ['Felicitas Stroh'],
#  ['Klaus Plötz'],
#  ['Walter Vennen'],
#  ['Antje Bischoff-Kümmel'],
#  ['Susanne Maier'],
#  ['Elke Behrends'],
#  [' Bibliotheksfachstelle der Diözese Linz'],
#  ['Anne Buhrfeind'],
#  ['R. A. Leaver'],
#  ['Michaela Selbach'],
#  ['Elke Behrends'],
#  ['Jean-Noël Jeanneney'],
#  ['Jean-Noël Jeanneney'],
#  ['Gerlinde Lamping'],
#  ['Jean-Noe͏̈l Jeanneney'],
#  ['Noah Bubenhofer', 'Klaus Rothenhäusler'],
#  ['Frank Lützenkirchen'],
#  ['Gerlinde Lamping'],
#  ['Gerhard Lehmann'],
#  [' ?'],
#  ['Christian Kaier'],
#  ['Gerhard Lehmann'],
#  ['Thomas Bürger'],
#  ['Noah Bubenhofer', 'Klaus Rothenhäusler'],
#  ['Beate Hörning'],
#  ['Annekathrin Genest'],
#  ['Moritz Sommet'],
#  ['Thomas Haffner'],
#  ['Klaus Fuchs-Kittowski'],
#  ['Paul Trommsdorf'],
#  ['Susanna Engelmann'],
#  ['Anja Freckmann'],
#  ['Anna Kasprzik'],
#  ['Anna Kasprzik'],
#  ['Markus Schnalke', 'Markus Schnalke'],
#  ['Mirko Hanke'],
#  ['Kerstin Keller-Loibl'],
#  ['Thomas Haffner'],
#  ['Mirjam Blümm'],
#  ['Francesca Schulze'],
#  ['Thomas Hapke'],
#  ['Birgit Lindel'],
#  ['Friedrich von Schiller'],
#  ['Christiane Brockerhoff'],
#  ['Anna Söder'],
#  ['Tanja Heber'],
#  ['Rike Brecht', 'Bastian Büchl', 'Heidi Krömker'],
#  ['Patrick Danowski', 'Jakob Voß'],
#  ['Thomas Hapke'],
#  ['Viola Voß'],
#  ['Jochen Apel'],
#  ['Hendrik Birus', 'Sebastian Donat'],
#  ['Thomas Seng'],
#  ['Guenter Ost'],
#  ['Saskia Sandow'],
#  ['Liu Liu', 'Georg Frey'],
#  ['Britta Woldering'],
#  ['Heike Ditlevsen', 'Bettina Fischer'],
#  ['Wilfried Sühl-Strohmenger'],
#  ['Matthew Battles'],
#  ['Sigrid Schüler-Juckenack'],
#  ['Heike Neuroth', 'Laura Rothfritz', 'Vivien Petras', 'Maxi Kindling'],
#  ['Petra Hauke'],
#  ['Christina Kläre', 'Kim-Sarah Jung'],
#  ['Matthias Spielkamp'],
#  ['Dirk Kottke'],
#  ['Roland Wagner'],
#  ['Heike Ditlevsen', 'Bettina Fischer'],
#  ['Karin Dengler-Schreiber'],
#  ['Conny Äng', 'Henk Das', 'Allison Dobbie', 'Susan Kent'],
#  ['Lutz-Frieder Schützler'],
#  ['Dalia Bukauskait'],
#  ['Anne Christensen'],
#  ['Regina Peeters'],
#  ['Lena Schulz'],
#  ['Tim Schumann'],
#  ['Bastian Drees'],
#  ['Kai Stalmann',
#   'Reinhard Budde',
#   'Robert Mertens',
#   'Christoph Tornau',
#   'Dennis Wegener',
#   'Volker Heydegger',
#   'Thorsten Wunderlich',
#   'Bernd Ingenbleek',
#   'Florian Schulz'],
#  ['Kerstin Juchem', 'Christian Schlögl', 'Wolfgang G. Stock'],
#  ['Christian May'],
#  ['Mathias Schmalisch', 'Hagen Ploog', 'Dirk Timmermann'],
#  [' ?'],
#  ['Thomas Papanikolaou'],
#  ['Dorothea Franke'],
#  ['Achim Bonte'],
#  ['Volker Klotz', 'Christoph Meinel'],
#  ['Maik Köhler'],
#  ['Philipp Bohnenstengel', 'Martin Christof Kindsmüller', 'Michael Herczeg'],
#  ['Joachim Meyer'],
#  [' ?'],
#  ['Karl H. Pruys'],
#  ['Athanasios Mazarakis', 'Isabella Peters'],
#  ['Werner Stephan'],
#  ['Michaela Selbach'],
#  ['Jin Tan'],
#  ['Mark Buzinkay'],
#  ['Martin Schrettinger'],
#  ['Martin Schrettinger'],
#  ['Ute Schneider'],
#  ['Christian Reimann'],
#  ['Christian Reimann'],
#  ['Alexander Böhlig'],
#  ['Maik Köhler'],
#  ['Jens Mittelbach'],
#  ['Thomas Hapke'],
#  ['Dirk Asendorpf'],
#  ['Markus Krajewski'],
#  ['Hamazasp Oskian'],
#  ['Markus Krajewski'],
#  ['Jakowbos W. Dashian'],
#  ['Alf Wachsmann'],
#  ['Hans Hehl'],
#  ['Ursula Jaksch'],
#  ['Thomas Kaden', 'Klaus Janschek'],
#  ['Fritz Droop'],
#  ['Friedrich Summann'],
#  ['Katrin Keller'],
#  ['Michael Heinz', 'Helmut Voigt'],
#  ['Matthias Schulze Ulrich Hahn'],
#  ['Jakowbos W. Tašean'],
#  ['Jürgen Theuer'],
#  ['Herbert Schneidler'],
#  ['Tobias Voigt'],
#  ['Konrad Umlauf', 'Klaus Ulrich Werner', 'Andrea Kaufmann'],
#  ['Matthias Hahn'],
#  ['Matthias Schumann', 'Otto Rienhoff'],
#  ['Burt Franklin'],
#  ['Margarete Kupfer'],
#  ['Patrick Bühler'],
#  ['Ulrike Verch'],
#  ['Alexandra Schmidt'],
#  ['Michael Seadle'],
#  ['Hamazasp Oskean'],
#  ['Norbert Köckler'],
#  ['Gudrun Kulzer'],
#  ['Herbert Schneidler'],
#  ['Alf Wachsmann'],
#  ['Christoph Conrad', 'Martina Kessel'],
#  ['Thomas Kratzberg'],
#  ['Ernst Engels'],
#  ['Sebastian Kötz'],
#  ['Rudolf Mumenthaler'],
#  ['Daniel Schäfer'],
#  ['Arne Klawitter'],
#  ['Werner von Grimm'],
#  ['Detlef Döring'],
#  ['Tim Schumann'],
#  ['Werner Grimm'],
#  ['Ria Deters'],
#  ['Heidrun Wiesenmüller'],
#  ['Eusebio Colomer'],
#  ['Michaela Selbach'],
#  ['Johann Wolfgang von Goethe'],
#  ['Axel Christoph Trefzer'],
#  ['Fotis Jannidis', 'Katja Mellmann'],
#  ['Josef Heidmann'],
#  ['Martina Haller'],
#  ['E.R. Hilf'],
#  ['D. E. Zimmer'],
#  ['Hans-Michael Schäfer'],
#  ['Hans-Michael Schäfer'],
#  ['Rebekkah Smith Aldrich'],
#  ['_ Bibliothek mit Dachgarten'],
#  ['Katharina Regulski'],
#  [' Epikur'],
#  ['Hermann Otto Vaubel'],
#  ['Thomas Wäkerle'],
#  ['Werner Stanglow'],
#  ['Werner Stanglow'],
#  ['Carola Pongratz'],
#  ['Carolin Ahnert', 'Martin Bauschmann'],
#  ['Josef Montebaur'],
#  ['Nissen Martin', 'Heller Lambert'],
#  ['Barbara Krebs'],
#  ['Wilfried Bautsch'],
#  ['Dominik Steindorf'],
#  ['Georg Daniel Fuchs'],
#  ['Sandra Merten'],
#  ['Gabriele Crusius'],
#  ['Elif Ermis'],
#  ['Ulrike Mertz'],
#  ['Stefan Weber'],
#  ['Albert Schmid'],
#  ['Friedrich Schultze', 'Gustav Meyer'],
#  ['Gabriele Plenz'],
#  ['Eric Schulze-Bahr'],
#  ['Marc Amberg'],
#  ['Alexandra Süß'],
#  ['Alexandra Süß'],
#  ['Miyasat Alieva'],
#  ['Sebastian Hölemann', 'Dirk Abel'],
#  ['Andreas Franz Borchert'],
#  ['William Edward Collinson'],
#  ['Miriam von Gehren'],
#  ['Andreas Franz Borchert'],
#  ['Axel Halle'],
#  ['Helge Steenweg'],
#  ['Priska Bucher'],
#  ['Jörn Wolf'],
#  ['Otto-Ernst Krawehl'],
#  ['Martin Jesinghausen'],
#  ['Martin Jesinghausen-Lauster'],
#  ['Heinrich Schreiber'],
#  ['H. Hehl'],
#  ['Simone Mengis'],
#  ['Björn Stelte', 'Björn Saxe'],
#  ['Maximilian Stempfhuber', 'Benjamin Zapilko'],
#  ['Andreas Petrovitsch', 'Erik Senst', 'Sabine Wolf'],
#  ['Helge Steenweg'],
#  ['Thomas Hapke'],
#  ['Johanna Rachinger'],
#  ['Dagmar Schmidt'],
#  ['Annette Pozzo'],
#  ['Thomas Hapke'],
#  ['Oliver Mandal'],
#  ['Dominik Radlmaier'],
#  ['Eleonore von Bothmer'],
#  ['Uwe Färber'],
#  ['Benjamin Blinten'],
#  ['Rachel Singer Gordon / Michael Stephens'],
#  ['Christiane Hoffrath'],
#  ['Günter Guttroff'],
#  ['Bodo Spranz'],
#  ['Anke Berghaus-Sprengel', 'Tobias Kühne'],
#  ['Danny Bading'],
#  ['Hubert Zitt'],
#  ['Annette Pozzo'],
#  ['Franz Samma'],
#  ['Annette Pozzo'],
#  ['Marcus Wenzel'],
#  ['Sabine Kirk'],
#  ['Lambert Heller'],
#  ['Nadine Meiers', 'Stefanie Schröder'],
#  ['Barbara Haubenwaller'],
#  ['Anne Christensen'],
#  ['Thomas Hapke'],
#  ['Kathrin Paasch'],
#  ['Cyrill Brand'],
#  ['Gudula Schütz'],
#  ['Tom Becker'],
#  ['Manfred Nowak', 'Lambert Heller', 'Sascha Korzen'],
#  ['Petra Labriga'],
#  ['Peter Nasse'],
#  ['Josef Albert Hüntemann'],
#  ['Kathrin Paasch'],
#  ['Aleksandr Leonovič Chosroev'],
#  ['Daniel Geißler'],
#  ['Günther Stocker'],
#  ['Anke Lösch'],
#  ['Petra Stahl'],
#  ['Simone Fühles-Ubach',
#   'Philipp Schaer',
#   'Klaus Lepsky',
#   'Alwis Ragna Seidler de'],
#  ['Gernot U. Gabel'],
#  ['Hellen Niegaard'],
#  [' Bibliothek der Universität Konstanz'],
#  ['Rick Bennett',
#   'Christina Hengel-Dittrich',
#   'Edward T. O’Neill',
#   'Barbara B. Tillett'],
#  ['Carsten Zwick'],
#  ['Gerhard Bahn'],
#  ['Lukas Hanke'],
#  ['Annette Pozzo'],
#  ['Dirk Reuter'],
#  ['Oliver Deeg'],
#  ['Sabine Wolf'],
#  ['Miriam Lorenz', 'Simone Fühles-Ubach', ' Projektteam'],
#  ['Friedrich Figge',
#   'Kirsten Darby',
#   'Jens Hardt',
#   'Theresa Liebig',
#   'Eva-Maria Remeli',
#   'Viviane Wilde'],
#  ['Klaus Döhmer'],
#  ['Leila Sonkkanen'],
#  ['Matthias Harbeck', 'Sonja Kobold'],
#  ['Sophie Köberle'],
#  ['Felicitas Stroh'],
#  ['Claudia Stockinger'],
#  ['Teresa Ledermann', 'Jens Renner'],
#  ['Thomas Hapke'],
#  ['Petra Simon'],
#  ['Thomas Risse', 'Matthias Hemmje'],
#  ['Sophie Köberle'],
#  ['Dagmar Arndt'],
#  ['Bruno Bauer', 'Ronald M. Schmidt'],
#  ['Katharina Portugal'],
#  ['Franz-Josef Kuntz'],
#  ['Dirk Ullmann'],
#  ['Martin Gabriel'],
#  [' ?'],
#  ['Beat Mattmann', 'Noah Regenass'],
#  ['Stein Christian'],
#  ['Milan Bulaty',
#   'Anna-Katharina Huth',
#   'Regina Pfeifenberger',
#   'Katharina Tollkühn',
#   'Christian Winterhalter'],
#  ['_ aubib.de | Blog'],
#  ['Jürgen Plieninger'],
#  ['Otto Hartig', 'Richard Stauber'],
#  ['Stefanie Rühle', 'Francesca Schulze', 'Michael Büchner'],
#  ['Heike Ehrlicher', 'Janet Wagner'],
#  ['Dirk Ullmann'],
#  ['Martin Gabriel'],
#  ['Lo Wan Ni', 'Soh Lin Li'],
#  ['Jaakko Kneissl', 'Heidrun Wiesenmüller'],
#  ['Ragnar Andreas Audunson'],
#  ['Martin Brecht'],
#  ['Anne Linsler', 'Michael Mönnich'],
#  ['Melanie Hoffmann'],
#  ['Konrad Willi'],
#  ['Melanie Hoffmann'],
#  ['Friedhilde Krause'],
#  ['Andrea Opitz'],
#  ['Tim Schumann'],
#  ['Petra Hauke'],
#  ['Gerald Jasbar'],
#  ['Marianne Reuter'],
#  ['Konrad Willi'],
#  ['Werner Salow'],
#  ['al-Q sim Ibn-Ê¿Al al- ar r'],
#  ['al-Q sim Ibn-Ê¿Al al- ar r', 'Bahar Mokhtarian'],
#  ['Matija Vlačić Ilirik'],
#  ['Konstantin Hermann'],
#  ['Naftali Apt'],
#  ['Harald H. Zimmermann'],
#  ['Chris Mayrhofer'],
#  ['Christiane Fritze'],
#  [' Stadtbücherei Frankfurt am Main'],
#  ['Susanne Brandt'],
#  ['Wilfried Brennecke'],
#  ['Mathias Etter'],
#  ['Mathias Etter'],
#  ['Christian Wagenknecht'],
#  ['Jochen Schevel'],
#  ['Fritz Hoffmann'],
#  ['Christian Hallmann'],
#  ['Joachim Hotz'],
#  ['Urs Gröhbiel'],
#  ['Stephan Mosel'],
#  ['Mathias Heilig', 'Mischa Demarmels', 'Stephan Huber', 'Harald Reiterer'],
#  ['Natalia Daniel'],
#  ['Alexander Schmidt-Salzmann'],
#  ['Matija Vlačić Ilirik'],
#  ['Matija Vlačić Ilirik'],
#  ['Karen Latimer'],
#  ['Thomas Hapke'],
#  ['Karlheinz Döring'],
#  ['Ernst Hellgardt'],
#  ['Lucas Zeise'],
#  ['Michael Hagner'],
#  ['Sigrun Wittmann'],
#  ['Rolf Schulmeister'],
#  ['Christian Ritzi'],
#  ['Christian Ritzi'],
#  ['Wilfried Sühl-Strohmenger'],
#  [' ?'],
#  ['Smil Grünberg'],
#  ['Anton Hackl'],
#  ['Stephan Leucht'],
#  ['Hans-Georg Müller'],
#  ['Kaspar Bütikofer'],
#  ['Ursula Krömmelbein'],
#  ['Christiane Hoffrath'],
#  ['Eva Renate Wutta'],
#  ['Hans-Georg Müller'],
#  ['Walter Damm'],
#  ['Ekkehart Seusing'],
#  ['Lambert Heller'],
#  ['Ulrik Wrangell'],
#  ['Walter Benjamin', 'Rolf Tiedemann', 'Hermann Schweppenhäuser'],
#  ['Lotta Continua'],
#  ['Stephen Gundle'],
#  ['Francis Haskell'],
#  ['Götz Aly'],
#  ['Aldo Cazzullo'],
#  ['Wilfried Sühl-Strohmenger'],
#  ['Philip Cooke'],
#  ['Toni Negri'],
#  ['Margaret S. Creighton', 'List Nording'],
#  ['Luisa Passerini'],
#  ['Matthias Franz'],
#  ['Thomas Bürger',
#   'Claudia Fabian',
#   'Rupert Schaab',
#   'Barbara Schneider-Kempf',
#   'Heiner Schnelling',
#   'Manfred Thaller'],
#  [' Hans J. Becker',
#   ' Reiner Diedrichs',
#   ' Bernhard Eversberg',
#   ' Annette Rath-Beckmann',
#   ' Hans-Joachim Wätjen',
#   ' Wolfgang Zick',
#   ' Hartmut Zillmann'],
#  ['Martella Gutiérrez-Denhoff'],
#  ['Alberto Franceschini'],
#  ['Raniero Panzieri'],
#  ['Raymond Queneau', 'Eugen Helmlé'],
#  ['Pier Paolo Pasolini'],
#  ['Ulrich Welke'],
#  ['Paul Lindau'],
#  ['Sascha Verlan', 'Hannes Loh'],
#  ['Ruth Ben-Ghiat'],
#  ['Michael Grüttner'],
#  ['Luciano Lanza'],
#  ['Giorgio Galli'],
#  ['George L. Mosse'],
#  ['Émile Gaboriau'],
#  ['E. Yourdon', 'L.L. Constantine'],
#  ['Ulrich Herbert'],
#  ['Carlo Ginzburg'],
#  ['Grazia Deledda'],
#  ['Fernand Braudel'],
#  ['Elio Petri'],
#  ['Georges Canguilhem'],
#  ['Georg Rusche', 'Otto Kirchheimer'],
#  ['Helge Steenweg'],
#  ['Randy Olsen', 'Christopher McAfee'],
#  ['Libero Traversa'],
#  ['Hannes Loh', 'Murat Güngör'],
#  ['Philipp Sarasin', 'Jakob Tanner'],
#  ['Stefan Seifert'],
#  ['Adriano Sofri', 'Luciano Della Mea'],
#  ['Adriano Sofri', 'Luca Sofri'],
#  ['Alfons Labisch'],
#  ['Guido Viale'],
#  ['Corrado Sannucci'],
#  ['Gaston Leroux'],
#  ['Rafael Capurro'],
#  ['Reinhart Siegert'],
#  ['Tobias Möller Walsdorf'],
#  ['Aron Zweifel'],
#  ['Michael Mangold'],
#  ['Christian Riepl'],
#  ['Ludger Syré', 'Jürgen Seefeldt', ' Georg-Olms-Verlag'],
#  ['Mehdi Yahyawi'],
#  ['Clothilde Sennewaldt'],
#  ['Frieda Otto'],
#  ['Peter Weibel'],
#  ['Ute Palmer'],
#  ['Erik Margraf'],
#  ['Erik Margraf'],
#  ['Gerhard Schulze'],
#  [' ?'],
#  ['Lo Wan Ni', 'Lin Li. Soh'],
#  [' ?'],
#  ['Friedrich Six'],
#  ['Friedrich Six'],
#  ['Lorraine Daston', 'Katharine Park'],
#  ['Paul Heyse'],
#  ['Nicola Labanca'],
#  ['Rossana Rossanda'],
#  ['Julie Wheelwright'],
#  ['Alex Demirovi´c'],
#  ['Antonio Gramsci', 'Klaus Bochmann', 'Wolfgang Fritz Haug'],
#  ['Carlo M. Cipolla'],
#  ['Fergus W. Hume'],
#  ['Annke D. Frick'],
#  ['Bernhard Groß'],
#  ['Wolfgang Schivelbusch'],
#  ['Willi Bredel'],
#  ['Michael Baxandell'],
#  ['Jan Valtin (d.i. Richard Hermann Julius Krebs)'],
#  ['Anna Clark'],
#  ['Peter Linebaugh', 'Marcus Rediker'],
#  ['Stephen Gundle'],
#  ['Mariacarla Gadebusch Bondio', 'Rolf Winau', 'Heinz Müller-Dietz'],
#  ['Mario Moretti', 'Carla Mosca', 'Rossana Rossanda'],
#  ['Lucien Febvre'],
#  ['Carlo Ginzburg'],
#  ['Gabriela Holzmann'],
#  ['Ursula Liebmann'],
#  ['Patrick Wagner'],
#  ['Klaus Theweleit'],
#  ['Marcus Rediker'],
#  ['Carlo Ginzburg'],
#  ['Alexander De Grand'],
#  ['Alain Corbin'],
#  ['Judith R. Walkowitz'],
#  ['Jim G. Tobias', 'Peter Zinke'],
#  ['Alex Demirovi´c', 'Manuela Bojadˆzijev'],
#  ['Carlo Ginzburg'],
#  ['Carlo Ginzburg'],
#  ['Michael Furger', 'Raffael Ball'],
#  ['_ International Federation of Library Associations_and_Institutions (IFLA)'],
#  [' div'],
#  ['Christoph Nytsch-Geusen',
#   'Jörg Huber',
#   'Manuel Ljubijankic',
#   'Jörg Rädler'],
#  ['Arno Haase'],
#  ['Jürgen Hüther', 'Bernd Schorb'],
#  ['Helmut Hilz'],
#  ['Elisabeth Thek'],
#  ['Manfred Wilde'],
#  ['Martin Schulze Wessel'],
#  ['Ulrich Naumann'],
#  ['Michael Baxandell'],
#  ['Prosper Mérimée'],
#  ['Rudolf Wittkower'],
#  ['Judith R. Walkowitz'],
#  ['Bonnie Bullough', 'Vern L. Bullough'],
#  ['Émile Gaboriau'],
#  ['Émile Gaboriau'],
#  ['ENRICH: European networking resources',
#   ' information concerning cultural heritage'],
#  ['Uta Keite', 'Raffael Banduch'],
#  ['Gaston Bachelard'],
#  ['Vanessa R. Schwartz'],
#  ['Karl Grünberg'],
#  ['Umberto Eco'],
#  ['Tilman Baumgärtel'],
#  ['Michel Foucault'],
#  ['Linda Williams'],
#  ['Jan Rehmann'],
#  ['Georges Canguilhem'],
#  ['Georges Canguilhem'],
#  ['Fjodor Gladkow'],
#  ['Klaus Kreimeier'],
#  ['Dietlind Hüchtker'],
#  ['Fernand Braudel'],
#  ['Claudia Pollich-Post'],
#  ['Anna Kasprzik'],
#  ['Peter Thiessen'],
#  ['Cordula Franzke'],
#  ['Maria Ganahl'],
#  ['Margarethe Behr'],
#  ['Walter Serner'],
#  ['Marcello Brusegan'],
#  ['Helen Lefkowitz Horowitz'],
#  ['Friedrich Glauser'],
#  ['Tina Hohmann'],
#  ['Dieter Lüttje'],
#  ['Tim Schumann'],
#  ['Matthew R. Goldner'],
#  ['Margret Schild'],
#  ['Petra Hauke', 'Klaus Ulrich Werner'],
#  ['Harri Sahavirta'],
#  ['Michael Göhlich'],
#  ['Susanna Blaser-Meier'],
#  ['Jennifer Khan'],
#  ['Silke Glitsch',
#   'Niedersächsische Staats und Universitätsbibliothek Göttingen.'],
#  ['Andreas Scharf'],
#  ['G Stahl', 'F. Hesse'],
#  [' Sächsische Landesfachstelle für Bibliotheken'],
#  ['Deborah Cameron', 'Elizabeth Frazer'],
#  ['Anton Tschechow'],
#  [' Springer-Verlag GmbH'],
#  [' United States National Library of Medicine'],
#  [' ?'],
#  ['Albrecht Koschorke',
#   'Susanne Lüdemann',
#   'Thomas Frank',
#   'Ethel Matala de Mazza'],
#  ['Jürgen Zimmerer'],
#  ['Steve Wright'],
#  ['Orlando Figes'],
#  ['Michel Foucault'],
#  ['Carsten Küther'],
#  ['Hugo Bettauer'],
#  ['Gilbert Keith Chesterton'],
#  ['Émile Gaboriau'],
#  ['Michael Baxandell'],
#  ['Corrado Stajano'],
#  ['Kai Geschuhn'],
#  ['Partho Halder'],
#  ['Heinrich Stute'],
#  ['Heinrich Stute'],
#  [' ?'],
#  ['Max Raphael'],
#  ['Luisa Passerini'],
#  ['Tommaso Di Ciaula'],
#  ['Jan Weiss'],
#  ['Carlo Ginzburg'],
#  ['Gérard Leclerc', 'Wolf Lepenies', 'Henning Ritter'],
#  ['Michael Mönnich'],
#  ['Janet Wagner', 'Tim Schumann', 'Christina Riesenweber'],
#  ['Saul Kussiel Padover'],
#  ['Markus Andreas Lohmann'],
#  ['Michael Gasser', 'Regina Wanger', 'Ismail Prada'],
#  ['Heinrich Stute'],
#  ['Rudolf Brockhaus', 'Sebastian Lange'],
#  ['F. Geißelmann'],
#  ['Alexander Botte'],
#  ['Hans Ollig', 'Bruno Bauer'],
#  ['Alice Keller'],
#  ['Gotthard Hoffmann'],
#  ['Ingrid Baumgärtner'],
#  ['Bernhard Eversberg'],
#  ['Lee Lundrigan', 'Vidal Graupera', 'Sarah Allen'],
#  ['Dietrich Kerlen'],
#  ['Giordano Bruno'],
#  ['Hans Blumenberg'],
#  ['Markus Heckmann'],
#  ['Leopold Wiese'],
#  ['J. A. Stilwell', 'Richard George Lipsey'],
#  ['Ludwig H. Adolph Geck'],
#  ['Konrad Mellerowicz'],
#  ['Ulrich Briefs'],
#  ['Thorsten Ritter'],
#  ['Karl-Heinz Uhlig'],
#  [' ?'],
#  ['Eric Tierling'],
#  ['Hermannus Pfeiffer'],
#  [' ?'],
#  ['Ulrich Briefs'],
#  ['Peter Hinrichs'],
#  ['Abu Bakr Ibn Tufail'],
#  ['Franz Ronneberger'],
#  [' Aristoteles'],
#  ['Immanuel Kant'],
#  ['Wolfgang Klafki'],
#  ['Philipp Fuchs'],
#  ['Dziga Vertov'],
#  ['René Descartes'],
#  ['René Descartes'],
#  ['Gottfried Wilhelm Leibniz'],
#  ['Paul Ricoeur'],
#  ['Edmund Husserl'],
#  ['Erik Gurgsdies', 'Klaus Wieser'],
#  ['Günter Danert'],
#  ['Erich Schäfer'],
#  ['Hermann Funke', 'Hans Blohm'],
#  ['Rosabeth Moss Kanter'],
#  ['Thomas Rothe'],
#  ['Eric Tierling'],
#  ['Lars Gerschau'],
#  [' ?'],
#  ['Theodor Ascher'],
#  ['Konrad Mellerowicz'],
#  ['Rene Descartes'],
#  ['Franz Ronneberger'],
#  ['Jörg Goldberg'],
#  ['Peter Römer'],
#  [' ?'],
#  ['Christian Schmid'],
#  [' Aristoteles', 'Martin Dreher'],
#  ['René Descartes'],
#  ['Theodor W. Adorno'],
#  ['Uwe Timm'],
#  ['Gaston Bachelard'],
#  [' ?'],
#  ['Walter Baur'],
#  ['Pavel Rapoÿés'],
#  ['Karl Dietrich Bracher'],
#  ['James E. Meade'],
#  ['Hanns Linhardt'],
#  ['Jozef Wilczynski'],
#  ['Jörg Bankmann'],
#  ['Susanne Koch', 'Peter Kupka', 'Joß Steinke'],
#  ['Dziga Vertov'],
#  ['Walter Benjamin', 'Rolf Tiedemann', 'Theodor W. Adorno'],
#  ['Holm Tetens'],
#  ['Gottfried W. Leibniz'],
#  ['Gottfried Wilhelm Leibniz'],
#  ['Peter Hinrichs', 'Lothar Peter'],
#  ['Eric Tierling'],
#  ['Georg Wilhelm Friedrich Hegel'],
#  ['René Descartes'],
#  ['Erik Hornung'],
#  ['Paul Ricœur'],
#  ["Jean Le Rond d' Alembert"],
#  ['Melvil Dewey',
#   'Joan Mitchell',
#   'Julianne Beall',
#   'Giles Martin',
#   'Winton Matthews',
#   'Gregory New',
#   'Germany Deutsche Bibliothek Frankfurt am Main'],
#  ['Ben Bachmair'],
#  ['Jeremias Gotthelf'],
#  ['Ingrid Baumgärtner'],
#  ['Axel Leijonhufvud'],
#  ['Johannes Riedel'],
#  ['Eugen Rau'],
#  ['Jürgen Räuschel'],
#  ['Albert Schnettler'],
#  ['Jack Hirshleifer'],
#  ['Albert Calmes'],
#  [' ?'],
#  ['Hans Prolingheuer'],
#  [' ?'],
#  ['Ludwig Wittgenstein'],
#  ['Gottfried Wilhelm Leibniz'],
#  ['Brigitte Cech'],
#  ['Friedrich Wilhelm Joseph von Schelling', 'Thomas Buchheim'],
#  ['Georg von Below'],
#  ['Ingemar König'],
#  ['Erik Reger'],
#  ['Willi Bredel'],
#  ['Lucien Febvre'],
#  ['Alexander Sinowjew'],
#  ['Peter Weingart', 'Jürgen Kroll', 'Kurt Bayertz'],
#  ['Carsten Küther'],
#  ['Heike Behle'],
#  ['Roman Lutz'],
#  ['Leon Mann'],
#  ['Frank Niess'],
#  ['Friedrich Henzel'],
#  ['Erich Kosiol'],
#  ['Walter Baumann'],
#  [' ?'],
#  ['Kenneth Joseph Arrow'],
#  ['Max Rudolf Lehmann'],
#  ['Franz Ronneberger'],
#  ['Michael E. Porter'],
#  ['Fritz Peter Knapp'],
#  ['Heinz-Jürgen Axt'],
#  [' ?'],
#  ['Florian Däumling', 'Daniel Sillescu'],
#  ['Frank Baron'],
#  ['Christoph Conrad'],
#  ['Richard Rorty'],
#  ['J. B. Hofmann'],
#  ["Benedict R. O'G. Anderson"],
#  ['Annemarie Schimmel'],
#  ['Carl von Clausewitz'],
#  ['Theodor Wiesengrund Adorno'],
#  ['Immanuel Kant']]

# %%
len(df_bibsonomy_selection["authors"].to_list())
# Out:
# 834

# %%
df_bibsonomy_selection["authors"].drop_duplicates()
# Out:
# 1000       [ Berufsverband Information Bibliothek e.V.]
# 1001    [Michaela Selbach, Bibliothek der Fachhochsch.]
# 1002                                   [Manuela Schulz]
# 1003                                     [Beate Tröger]
# 1004                 [Patrick Danowski, Lambert Heller]
#                              ...
# 1992                                    [J. B. Hofmann]
# 1995                        [Benedict R. O'G. Anderson]
# 1996                               [Annemarie Schimmel]
# 1997                              [Carl von Clausewitz]
# 1998                       [Theodor Wiesengrund Adorno]
# Name: authors, Length: 695, dtype: object

# %% [markdown]
# ####  Gibt es eine Möglichkeit, dass man den Index der verbliebenen Zeilen dann wieder ab 1 starten lässt? Die type="Publication" starten glauben so ab Index 1000

# %%
# copy of dataframe 
df_bibsonomy_selection_new_index = df_bibsonomy_selection
# Series object als neuen index 
s = pd.Series(range(0,len(df_bibsonomy_selection_new_index)))
df_bibsonomy_selection_new_index.set_index(s)
# Out:
#                                                  title  \
# 0    BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1    Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 2      Service vor Ort? Die Bibliothek geht zum Nutzer
# 3    Wissenschaft online. Elektronisches Publiziere...
# 4                 Bibliothek 2.0 -- Wird alles anders?
# ..                                                 ...
# 829  Die Erfindung der Nation: zur Karriere eines f...
# 830                         Der Islam: Eine Einführung
# 831                                Vom Kriege: Auswahl
# 832  Minima Moralia. Reflexionen aus dem beschädigt...
# 833                                 Zum ewigen Frieden
#
#                                              authors         type  \
# 0       [ Berufsverband Information Bibliothek e.V.]  Publication
# 1    [Michaela Selbach, Bibliothek der Fachhochsch.]  Publication
# 2                                   [Manuela Schulz]  Publication
# 3                                     [Beate Tröger]  Publication
# 4                 [Patrick Danowski, Lambert Heller]  Publication
# ..                                               ...          ...
# 829                      [Benedict R. O'G. Anderson]  Publication
# 830                             [Annemarie Schimmel]  Publication
# 831                            [Carl von Clausewitz]  Publication
# 832                     [Theodor Wiesengrund Adorno]  Publication
# 833                                  [Immanuel Kant]  Publication
#
#      year_correct  year_number collected_by  number_authors
# 0            True         2021       Fabian               1
# 1            True         2007       Fabian               2
# 2            True         2010       Fabian               1
# 3            True         2000       Fabian               1
# 4            True         2007       Fabian               2
# ..            ...          ...          ...             ...
# 829          True         2005       Fabian               1
# 830          True         1997       Fabian               1
# 831          True         1995       Fabian               1
# 832          True         1951       Fabian               1
# 833          True         1992       Fabian               1
#
# [834 rows x 7 columns]

# %%
# Anfangen mit 1
df_bibsonomy_selection_new_index2 = df_bibsonomy_selection
# Series object als neuen index 
# jetzt: wir müssen mit len()+1 arbeiten!
s = pd.Series(range(1,len(df_bibsonomy_selection_new_index)+1))
df_bibsonomy_selection_new_index2.set_index(s)
# Out:
#                                                  title  \
# 1    BIB Fundgrube Fachinformation Grüne Bibliothek...
# 2    Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 3      Service vor Ort? Die Bibliothek geht zum Nutzer
# 4    Wissenschaft online. Elektronisches Publiziere...
# 5                 Bibliothek 2.0 -- Wird alles anders?
# ..                                                 ...
# 830  Die Erfindung der Nation: zur Karriere eines f...
# 831                         Der Islam: Eine Einführung
# 832                                Vom Kriege: Auswahl
# 833  Minima Moralia. Reflexionen aus dem beschädigt...
# 834                                 Zum ewigen Frieden
#
#                                              authors         type  \
# 1       [ Berufsverband Information Bibliothek e.V.]  Publication
# 2    [Michaela Selbach, Bibliothek der Fachhochsch.]  Publication
# 3                                   [Manuela Schulz]  Publication
# 4                                     [Beate Tröger]  Publication
# 5                 [Patrick Danowski, Lambert Heller]  Publication
# ..                                               ...          ...
# 830                      [Benedict R. O'G. Anderson]  Publication
# 831                             [Annemarie Schimmel]  Publication
# 832                            [Carl von Clausewitz]  Publication
# 833                     [Theodor Wiesengrund Adorno]  Publication
# 834                                  [Immanuel Kant]  Publication
#
#      year_correct  year_number collected_by  number_authors
# 1            True         2021       Fabian               1
# 2            True         2007       Fabian               2
# 3            True         2010       Fabian               1
# 4            True         2000       Fabian               1
# 5            True         2007       Fabian               2
# ..            ...          ...          ...             ...
# 830          True         2005       Fabian               1
# 831          True         1997       Fabian               1
# 832          True         1995       Fabian               1
# 833          True         1951       Fabian               1
# 834          True         1992       Fabian               1
#
# [834 rows x 7 columns]

# %%
df_bibsonomy_selection_new_index2 = df_bibsonomy_selection
df_bibsonomy_selection_new_index2 = df_bibsonomy_selection_new_index2.reset_index()
df_bibsonomy_selection_new_index2
# Out:
#      index                                              title  \
# 0     1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1     1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 2     1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 3     1003  Wissenschaft online. Elektronisches Publiziere...
# 4     1004               Bibliothek 2.0 -- Wird alles anders?
# ..     ...                                                ...
# 829   1995  Die Erfindung der Nation: zur Karriere eines f...
# 830   1996                         Der Islam: Eine Einführung
# 831   1997                                Vom Kriege: Auswahl
# 832   1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 833   1999                                 Zum ewigen Frieden
#
#                                              authors         type  \
# 0       [ Berufsverband Information Bibliothek e.V.]  Publication
# 1    [Michaela Selbach, Bibliothek der Fachhochsch.]  Publication
# 2                                   [Manuela Schulz]  Publication
# 3                                     [Beate Tröger]  Publication
# 4                 [Patrick Danowski, Lambert Heller]  Publication
# ..                                               ...          ...
# 829                      [Benedict R. O'G. Anderson]  Publication
# 830                             [Annemarie Schimmel]  Publication
# 831                            [Carl von Clausewitz]  Publication
# 832                     [Theodor Wiesengrund Adorno]  Publication
# 833                                  [Immanuel Kant]  Publication
#
#      year_correct  year_number collected_by  number_authors  \
# 0            True         2021       Fabian               1
# 1            True         2007       Fabian               2
# 2            True         2010       Fabian               1
# 3            True         2000       Fabian               1
# 4            True         2007       Fabian               2
# ..            ...          ...          ...             ...
# 829          True         2005       Fabian               1
# 830          True         1997       Fabian               1
# 831          True         1995       Fabian               1
# 832          True         1951       Fabian               1
# 833          True         1992       Fabian               1
#
#                                       Erstautor
# 0     Berufsverband Information Bibliothek e.V.
# 1                              Michaela Selbach
# 2                                Manuela Schulz
# 3                                  Beate Tröger
# 4                              Patrick Danowski
# ..                                          ...
# 829                   Benedict R. O'G. Anderson
# 830                          Annemarie Schimmel
# 831                         Carl von Clausewitz
# 832                  Theodor Wiesengrund Adorno
# 833                               Immanuel Kant
#
# [834 rows x 9 columns]

# %% [markdown]
# #### könntet ihr Bitte nochmal die Funktion .apply (lambda ... ) erklären. Was passiert da genau?

# %%
df_bibsonomy_selection_test = df_bibsonomy_selection

# %%
df_bibsonomy_selection_test["Erstautor"] = "text"

# %%
df_bibsonomy_selection_test
# Out:
#                                                   title  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                               authors         type  \
# 1000     [ Berufsverband Information Bibliothek e.V.]  Publication
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]  Publication
# 1002                                 [Manuela Schulz]  Publication
# 1003                                   [Beate Tröger]  Publication
# 1004               [Patrick Danowski, Lambert Heller]  Publication
# ...                                               ...          ...
# 1995                      [Benedict R. O'G. Anderson]  Publication
# 1996                             [Annemarie Schimmel]  Publication
# 1997                            [Carl von Clausewitz]  Publication
# 1998                     [Theodor Wiesengrund Adorno]  Publication
# 1999                                  [Immanuel Kant]  Publication
#
#       year_correct  year_number collected_by  number_authors Erstautor
# 1000          True         2021       Fabian               1      text
# 1001          True         2007       Fabian               2      text
# 1002          True         2010       Fabian               1      text
# 1003          True         2000       Fabian               1      text
# 1004          True         2007       Fabian               2      text
# ...            ...          ...          ...             ...       ...
# 1995          True         2005       Fabian               1      text
# 1996          True         1997       Fabian               1      text
# 1997          True         1995       Fabian               1      text
# 1998          True         1951       Fabian               1      text
# 1999          True         1992       Fabian               1      text
#
# [834 rows x 8 columns]

# %%
def count_authors(in_list):
    return len(in_list)

# %%
df_bibsonomy_selection_test["Erstautor"] = df_bibsonomy_selection_test.apply(lambda row: row["authors"][0], axis=1)

# %%
df_bibsonomy_selection_test
# Out:
#                                                   title  \
# 1000  BIB Fundgrube Fachinformation Grüne Bibliothek...
# 1001  Bibliothek 2.0 : neue Perspektiven und Einsatz...
# 1002    Service vor Ort? Die Bibliothek geht zum Nutzer
# 1003  Wissenschaft online. Elektronisches Publiziere...
# 1004               Bibliothek 2.0 -- Wird alles anders?
# ...                                                 ...
# 1995  Die Erfindung der Nation: zur Karriere eines f...
# 1996                         Der Islam: Eine Einführung
# 1997                                Vom Kriege: Auswahl
# 1998  Minima Moralia. Reflexionen aus dem beschädigt...
# 1999                                 Zum ewigen Frieden
#
#                                               authors         type  \
# 1000     [ Berufsverband Information Bibliothek e.V.]  Publication
# 1001  [Michaela Selbach, Bibliothek der Fachhochsch.]  Publication
# 1002                                 [Manuela Schulz]  Publication
# 1003                                   [Beate Tröger]  Publication
# 1004               [Patrick Danowski, Lambert Heller]  Publication
# ...                                               ...          ...
# 1995                      [Benedict R. O'G. Anderson]  Publication
# 1996                             [Annemarie Schimmel]  Publication
# 1997                            [Carl von Clausewitz]  Publication
# 1998                     [Theodor Wiesengrund Adorno]  Publication
# 1999                                  [Immanuel Kant]  Publication
#
#       year_correct  year_number collected_by  number_authors  \
# 1000          True         2021       Fabian               1
# 1001          True         2007       Fabian               2
# 1002          True         2010       Fabian               1
# 1003          True         2000       Fabian               1
# 1004          True         2007       Fabian               2
# ...            ...          ...          ...             ...
# 1995          True         2005       Fabian               1
# 1996          True         1997       Fabian               1
# 1997          True         1995       Fabian               1
# 1998          True         1951       Fabian               1
# 1999          True         1992       Fabian               1
#
#                                        Erstautor  num_auth
# 1000   Berufsverband Information Bibliothek e.V.         1
# 1001                            Michaela Selbach         2
# 1002                              Manuela Schulz         1
# 1003                                Beate Tröger         1
# 1004                            Patrick Danowski         2
# ...                                          ...       ...
# 1995                   Benedict R. O'G. Anderson         1
# 1996                          Annemarie Schimmel         1
# 1997                         Carl von Clausewitz         1
# 1998                  Theodor Wiesengrund Adorno         1
# 1999                               Immanuel Kant         1
#
# [834 rows x 9 columns]

# %% [markdown]
# #### Wie kann ich das überprüfen, dass die JSON Datei auch die richtige Form hat? -> Ihr habt im Notebook unter Export JSON einene Abschnitt mit #check if it looks correct. -> könntet ihr bitte darauf eingehen was genau da passiert und warum man davon ableitet dass die JSON korrekt aussieht?

# %%
df_bibsonomy_selection.to_json("data/output_no-orient.json")

# %%
# check, if it look correct
with open("data/output_no-orient.json", "r") as f:
    j_load = json.load(f)
    print(json.dumps(j_load, indent=2))
# Out:
# {
#   "title": {
#     "1000": "BIB Fundgrube Fachinformation Gr\u00fcne Bibliothek. BibInfo",
#     "1001": "Bibliothek 2.0 : neue Perspektiven und Einsatzm\u00f6glichkeiten f\u00fcr wissenschaftliche Bibliotheken",
#     "1002": "Service vor Ort? Die Bibliothek geht zum Nutzer",
#     "1003": "Wissenschaft online. Elektronisches Publizieren in Bibliothek und Hochschule",
#     "1004": "Bibliothek 2.0 -- Wird alles anders?",
#     "1005": "Bibliothek 2. 0: Die Zukunft der Bibliothek?",
#     "1011": "Akademische Soziale Netzwerke und ihre Auswirkungen auf wissenschaftliche Bibliotheken",
#     "1012": "Netzwerk \u201eGr\u00fcne Bibliothek\u201c gegr\u00fcndet",
#     "1013": "Und wo sind hier die B\u00fccher? Bibliothek der Zukunft",
#     "1014": "Bibliothek - Mythos, Metapher, Maschine oder: Der ort der Bibliothek in der Lebenswelt der Stadt",
#     "1015": "Telefonzelle wird zu Bibliothek",
#     "1017": "Die Gr\u00fcne Bibliothek der Nachbarschaft",
#     "1018": "Die unheimliche Bibliothek : Erz\u00e4hlung",
#     "1019": "Wielkopolska Biblioteka Cyfrowa (Gro\u00dfpolnische Digitale Bibliothek)",
#     "1020": "Die Bibliothek als Lernort - neue Servicekonzepte",
#     "1021": "Bibliothek 2.0 - Perspektiven, Probleme, Handlungsbereiche",
#     "1022": "Open-Air-Bibliothek kam schon im Corona-Sommer gut an",
#     "1024": "Zeusch f\u00fcr Eusch: Die Bibliothek der Dinge",
#     "1025": "Die Unwahrscheinlichkeit von Wissenstradition und die Beharrlichkeit der Bibliothek",
#     "1026": "Die Gr\u00fcne Bibliothek - nachhaltig leben",
#     "1029": "Bibliothek 2.0 - Die Zukunft der Bibliothek?",
#     "1032": "Kleidertausch in der Bibliothek",
#     "1035": "Die Bibliothek bei Nacht",
#     "1036": "Bewegung am Lernort: Ein stromerzeugendes Fahrradergometer in der Philologischen Bibliothek der Freien Universit\u00e4t Berlin",
#     "1037": "Basiskenntnis Bibliothek: eine Fachkunde f\u00fcr Fachangestellte f\u00fcr Medien- und Informationsdienste - Fachrichtung Bibliothek",
#     "1038": "Warum es nicht funktioniert: Klimaanpassung und die \u00d6ffentliche Bibliothek",
#     "1039": "Was ist eine Gr\u00fcne Bibliothek?",
#     "1040": "Handelsblatt Management Bibliothek. Bd. 5: Die erfolgreichsten Unternehmer, L-Z",
#     "1041": "Moderne Bibliothek",
#     "1042": "Grobkonzept Deutsche Digitale Bibliothek",
#     "1043": "Text und Data Mining: Herausforderungen und M\u00f6glichkeiten f\u00fcr Bibliotheken",
#     "1044": "Bewegung f\u00f6rdert Lernen: Neue Angebote am Lernort Bibliothek dargestellt am Beispiel der Philologischen Bibliothek der Freien Universit\u00e4t Berlin",
#     "1045": "Bibliothek 2.0",
#     "1051": "Die Bibliothek der Dinge: Welche Rolle spielen Bibliotheken in der \"sharing economy\"?",
#     "1052": "Die Bibliothek der Zukunft: eine Typologie von Zukunftsbeschreibungen",
#     "1053": "Radfahren in der Bibliothek",
#     "1054": "Bibliothek 2.0 neue Perspektiven und Einsatzm\u00f6glichkeiten f\u00fcr wissenschaftliche Bibliotheken",
#     "1055": "Die Bibliothek von L\u00f6wen - Eine Episode aus der Zeit der Weltkriege",
#     "1056": "Die Rolle der Bibliothek.",
#     "1058": "Die Bibliothek im Informationszeitalter",
#     "1059": "Zukunft der digitalen Bibliothek",
#     "1060": "Der Neubau der Gesamthochschul-Bibliothek Kassel, Landesbibliothek und Murhardschen Bibliothek der Stadt Kassel",
#     "1061": "Projekt Deutsche Digitale Bibliothek (DDB) Architekturdokumentation",
#     "1062": "Umweltbildung in nieders\u00e4chsischen Bibliotheken: Die B\u00fcchereizentrale Niedersachsen hat f\u00fcr 2022 ihre neue Kampagne \"Bildung - Nachhaltigkeit - Bibliothek (BiNaBi)\" ausgerufen",
#     "1063": "Veranstaltungen im Hof vor der Bibliothek am Wasserturm",
#     "1064": "Bibliothek mit F\u00f6rdeblick - Der Erweiterungsbau der Deutschen Zentralbibliothek f\u00fcr Wirtschaftswissenschaften (ZBW) in Kiel",
#     "1065": "FaMI-Auszubildende als \"ForFuture-Denker/-innen\"! Dreit\u00e4giger Workshop zum Thema \"Gr\u00fcne Bibliothek\" inspiriert den Berufsnachwuchs",
#     "1066": "LibraryThing ? die kollaborative Bibliothek 2.0",
#     "1067": "Social Software -- Bausteine einer \"Bibliothek 2.0\"",
#     "1068": "Lexikon Buch - Bibliothek - Neue Medien",
#     "1069": "Lexikon Buch, Bibliothek, neue Medien",
#     "1071": "Auf dem Weg zur Deutschen Digitalen Bibliothek",
#     "1072": "Social Software \u2013 Bausteine einer \"Bibliothek 2.0\"",
#     "1074": "Buch, Bibliothek und geisteswissenschaftliche Forschung",
#     "1077": "LibraryThing -- die kollaborative Bibliothek 2.0",
#     "1080": "Die Bibliothek des Johann Christian von Boineburg (1622 - 1672)",
#     "1081": "Vom Wert des Sammelns und vom Mehrwert des Digitalen : verstreute Bemerkungen zur gegenw\u00e4rtigen Lage der Bibliothek",
#     "1082": "Plan S in der Diskussion \u2013 Reaktionen aus der Wissenschaft auf die internationale Open-Access-Initiative",
#     "1083": "Die mittelalterliche Bibliothek der Abtei Wei\u00dfenau",
#     "1084": "Bibliotheken im Web 2.0 \u2013 Bibliothek 2.0",
#     "1086": "Die Bibliothek von Babel",
#     "1087": "Die Bibliotheca Alexandrina. Eine sich selbst erfindende Bibliothek des Lehrens und Lernens",
#     "1088": "Ein St\u00fcck Bibliothek im Park: Ein Praxisbericht zum Einsatz des \u00bbbookbike nrw\u00ab bei der Stadtbibliothek Duisburg",
#     "1089": "Stadtb\u00fccherei T\u00fcbingen - das Konzept \"Gr\u00fcne Bibliothek\"",
#     "1092": "Hitler-Jugend. Prim\ufffdr- und Sekund\ufffdrliteratur der Bibliothek f\ufffdr Bildungsgeschichtliche Forschung.",
#     "1093": "Von der elektronischen Bibliothek zur innovativen Forschungsinfrastruktur",
#     "1094": "Kujawsko-Pomorska Digitale Bibliothek",
#     "1095": "Studien zur Geschichte der Bibliothek von C\u00e4sarea",
#     "1096": "Bibliothek der Dinge: Lieber leihen statt kaufen!",
#     "1097": "Gr\u00fcne Bibliothek als Chance? Konzeptentwicklung f\u00fcr die Stadtb\u00fccherei Wedel. Bachelorarbeit",
#     "1098": "Was ist eine Bibliothek?",
#     "1099": "Das Motiv der Bibliothek in der Kriminalliteratur",
#     "1100": "Bibliothek 2.0: Die Zukunft der Bibliothek?",
#     "1102": "\ufffdDie elektronische Bibliothek : Literatur- und Informationsbeschaffung im Internet",
#     "1103": "Die Welt der B\u00fccher. Eine Geschichte der Bibliothek",
#     "1105": "Internes Wissensmanagement in kleineren Bibliotheken \u2013 Die Bibliothek des Wissenschaftsparks Albert Einstein",
#     "1110": "Inhaltliche Zusammenf\u00fchrung eines fach\u00fcbergreifenden Bibliothekbestandes am Beispiel der Martha-Muchow-Bibliothek der Universit\u00e4t Hamburg",
#     "1111": "Automatisierte Volltexterschlie\u00dfung von Retrodigitalisaten am Beispiel historischer Zeitungen",
#     "1112": "Digitale Welt und wissenschaftliche Bibliothek - Informationspraxis im Wandel: Determinanten, Ressourcen, Dienste, Kompetenzen ; eine Einf\u00fchrung",
#     "1113": "Literatur unter B\u00e4umen: Die neue Open-Air-Bibliothek auf der Landesgartenschau in \u00dcberlingen",
#     "1114": "Bibliothek 2.0 - Neue Perspektiven und Einsatzm\u00f6glichkeiten f\u00fcr wissenschaftliche Bibliotheken",
#     "1115": "Recycling von B\u00fcchern: Die Bibliothek Lockenhaus wei\u00df auch \u00e4ltere B\u00fccher zu verwerten",
#     "1116": "Die Bibliothek als Dienstleister\r\nf\u00fcr den Umgang mit Forschungsdaten",
#     "1117": "Die wissenschaftliche Bibliothek und ihre Effektivit\u00e4t aus bedienungstheoretischer Sicht",
#     "1118": "Der Braunschweiger Stadtschreiber Gerwin von Hameln und seine Bibliothek",
#     "1120": "Die \u201egr\u00fcne Bibliothek\" - Wie wichtig Nachhaltigkeit f\u00fcr das deutsche Bibliothekswesen ist und warum es bis jetzt nur wenig praktische Ans\u00e4tze daf\u00fcr gibt",
#     "1121": "Philologie und Bibliothek \u2013 Philologie oder Bibliothek? Das Verh\u00e4ltnis von Fachstudium und Bibliothek als Herausforderung\r\nin beruflicher Praxis und bibliothekarischer Ausbildung",
#     "1122": "Modelica Predictive Control \u2013 An MPC Library for Modelica Eine MPC-Bibliothek f\u00fcr Modelica",
#     "1123": "Digitale Bibliothek",
#     "1124": "Die Merkw\u00fcrdigkeiten der k. k. garellischen \u00f6ffentl. Bibliothek am Theresiano",
#     "1125": "Bibliotheca Zelteriana: Rekonstruktion der Bibliothek Carl Friedrich Zelters, alphabetischer Katalog",
#     "1126": "Was bedeutet Open Access? Die Farben aus Sicht von Wissenschaft, Bibliothek und Gesellschaft.",
#     "1127": "Zukunft der Informationsinfrastrukturen : das deutsche Bibliothekswesen im digitalen Zeitalter",
#     "1128": "Ein Weblog als Informations-und Kommunikationsinstrument an der Universit\u00e4tsbibliothek der Medizinischen Universit\u00e4t Wien: 1 Jahr UBMUW-INFO",
#     "1129": "Das Raum-Informationssystem der Philologischen Bibliothek der Freien Universit\u00e4t Berlin",
#     "1130": "Die mittelalterliche Bibliothek des Augustinerchorherrenstifts Sankt Mang in Stadtamhof/Regensburg",
#     "1131": "Bibliothek und Internet : die Identit\u00e4tskrise einer Institution im digitalen Informationszeitalter",
#     "1132": "Aufbau und Nutzung einer digitalen Bibliothek in einer universit\u00e4ren Ausbildungsumgebung",
#     "1133": "Text und Data Mining : Herausforderungen und M\u00f6glichkeiten f\u00fcr Bibliotheken",
#     "1134": "Die Franziskaner in G\u00f6ttingen: die Geschichte des Klosters und seiner Bibliothek",
#     "1137": "Entspannen unter Strom: Stromerzeugendes Fahrradergometer f\u00fcr Studierende in der Philologischen Bibliothek der Freien Universit\u00e4t aufgestellt",
#     "1138": "Die Bibliothek des Schweinfurter Stadtphysicus Dr. Johann Laurentius Bausch (1605 - 1665)",
#     "1141": "Die Gr\u00fcne Bibliothek",
#     "1142": "Die Bibliothek r\u00e4t",
#     "1145": "Ressourcen sparen bei Buchlieferungen -- ein Erfahrungsbericht aus der Philologischen Bibliothek. Biblioblog",
#     "1146": "Zettelwirtschaft : die Geburt der Kartei aus dem Geiste der Bibliothek",
#     "1148": "Bibliothek der Zeit",
#     "1149": "C Standard-Bibliothek",
#     "1151": "Umwelttage in der Bibliothek: Die Stadtb\u00fccherei Eggenburg hat die \"Eggenburger Umwelt- und Energietage\" ins Leben gerufen",
#     "1152": "Gr\u00fcne Bibliothek Malm\u00f6: Pilotversuch einer gr\u00fcnen Allmende in der Nachbarschaftsbibliothek Sofielund",
#     "1153": "Die Bibliothek des Klosters St. Maximin bei Trier bis zum 12. Jahrhundert",
#     "1154": "Semantische Suche in einer digitalen Bibliothek",
#     "1156": "Informationskompetenz vermitteln \u2013 Das modulare Blended- Learning-Szenario der Bibliothek der Universit\u00e4t Konstanz",
#     "1157": "Johannes Cincinnius von Lippstadt (ca. 1485 - 1555): Bibliothek und Geisteswelt eines westf\u00e4lischen Humanisten",
#     "1158": "Wie tr\u00e4gt Ihre Bibliothek zu einer nachhaltigen Entwicklung bei?",
#     "1159": "Die medizinische Literatur in der Bibliothek der Grafen von Sch\u00f6nborn in Schloss Pommersfelden",
#     "1161": "Mein Traum von Bibliothek",
#     "1164": "Ver\u00e4nderung des Verh\u00e4ltnisses von Kunde und Bibliothek",
#     "1165": "Die leishu der imperialen Bibliothek des Qianlong (reg. 1736 - 1796): Untersuchungen zur chinesischen Enzyklop\u00e4die",
#     "1166": "Das sog. Evangeliar des Heiligen Augustinus, Cambridge, Bibliothek des Corpus Christi College, Cod. 286",
#     "1167": "Plattform f\u00fcr gesellschaftliche  Teilhabe und Integration: Zur Profilbildung der \u00d6ffentlichen Bibliothek. Rezension",
#     "1170": "Nachhhaltigkeit in der Bibliothek",
#     "1171": "Wissenschaft und Digitale Bibliothek",
#     "1172": "Eine Bibliothek der Weltliteratur",
#     "1173": "Bibliothek und Wissenschaft: wissenschaftstheoretische Probleme und Inhalte in der Ausbildung von Bibliothekaren und Informatoren",
#     "1174": "Schwerpunkt: DARIAH-DE \u2013 Digitalit\u00e4t in den Geistes- und Kulturwissenschaften | Bibliothek \u2013 Forschung und Praxis",
#     "1176": "Die Bibliothek von Nag Hammadi: einige Probleme des Christentums in \u00c4gypten w\u00e4hrend der ersten Jahrhunderte",
#     "1177": "HERAUSFORDERUNG BIBLIOTHEK 2.0: Chancen und Risiken f\u00fcr Verbundkataloge durch die Anreicherung mit Web 2.0-Konzepten",
#     "1178": "Schrift, Wissen und Ged\u00e4chtnis. Das Motiv der Bibliothek als Spiegel des Medienwandels im 20. Jahrhundert",
#     "1179": "Untersuchungen zur Geschichte der Geburtszange und der Geburtshilfe aufgrund der Altbest\u00e4nde der Universit\u00e4ts-Frauenklinik-Bibliothek",
#     "1180": "Die Geschichte der chinesischen Bibliothek Tian Yi Ge vom 16. Jahrhundert bis in die Gegenwart",
#     "1181": "Krajewski, Markus: Zettelwirtschaft. Die Geburt der Kartei aus dem Geiste der Bibliothek. Berlin : Kulturverl. Kadmos, 2002. review",
#     "1182": "Future Library: Die K\u00fcnstlerin Katie Peterson pflanzt eine Bibliothek \u2013 und das im w\u00f6rtlichen Sinne. Interview",
#     "1183": "Hochschulbibliografie 2008 (August)",
#     "1184": "Partizipative Entwicklung von Diensten in der Bibliothek 2.0: Methoden und Ergebnisse aus Katalog-2.0-Projekten",
#     "1185": "Literatur und Klosterreform: die Bibliothek der Benediktiner von St. Mang zu F\u00fcssen im 15. Jahrhundert",
#     "1186": "Literatur und Klosterreform: die Bibliothek der Benediktiner von St. Mang zu Fu\u0308ssen im 15. Jahrhundert",
#     "1188": "Hanns W. Eppelsheimer (1890-1972) : Bibliothekar, Literaturwissenschaftler, homme de lettres ; eine Ausstellung der Deutschen Bibliothek und der Stadt- und Universit\u00e4tsbibliothek Frankfurt",
#     "1189": "Eine studentische Musiksammlung der Reformationszeit: die Handschrift Misc. 236 a - d der Schermar-Bibliothek in Ulm",
#     "1190": "Individualisierte QR-Codes zur Verkn\u00fcpfung von Print- und E-Bestand",
#     "1191": "Digitalisierung im bibliothekarischen Alltag am Beispiel der Universit\u00e4tsbibliothek Kassel - Landesbibliothek und Murhardsche Bibliothek der Stadt Kassel",
#     "1192": "Dautzenbergs B\u00fccher: Leben und Wirken des Peter Joseph Franz Dautzenberg (1769 - 1828) im Spiegel seiner Bibliothek",
#     "1194": "Klimaschutz und Wurmkistenbau - mehr als nur ein Trend: Die B\u00fccherhallen Hamburg engagieren sich",
#     "1197": "Die Bibliothek geht ins Gr\u00fcne",
#     "1198": "Die g\u00fcne Bibliothek steht weltweit im Fokus: Bericht von der ENSULIB Konferenz in Berlin",
#     "1199": "Selbstbedienung in der hybriden Bibliothek",
#     "1200": "librtipc - Bibliothek f\u00fcr echtzeitf\u00e4hige Interprozesskommunikation.",
#     "1201": "Die Bibliothek des Klosters St. Pantaleon in K\u00f6ln bis zum 13. Jahrhundert: Studien zum geistigen Leben",
#     "1202": "Die Agenda 2030",
#     "1203": "Funktion und Struktur der sozialistischen Hochschulbibliothek, dargestellt am Beispiel der Bibliothek der Technischen Hochschule Karl-Marx-Stadt",
#     "1205": "Der Systemcharakter der wissenschaftlichen Bibliothek: Grundlagen und Entwicklungsm\u00f6glichkeiten der wissenschaftlichen Bibliotheken der Bundesrepublik Deutschland aus systemtheoretischer Sicht",
#     "1206": "Zur Entwicklung der Kommunalen \u00d6ffentlichen Bibliothek in der BRD 1969 - 1976 neunzehnhundertneunundsechzig bis neunzehnhundertsechsundsiebzig: Politik, \u00d6konomie, Ideologie",
#     "1207": "Buchdruck in Aachen 1573 - 1792: Untersuchungen zur Produktion Aachener Buchdrucker anhand des Bestandes der \u00d6ffentlichen Bibliothek Aachen",
#     "1208": "\"In einer Bibliothek, da sitzen Frauen!\" Qualitative Untersuchung zum Verh\u00e4ltnis von Frauen und M\u00e4nnern in einem Frauenberuf",
#     "1209": "Virtual reading room. Possibilities of a user-friendly presentation of collections via internet: BIBLIOTHEK Forschung und Praxis",
#     "1210": "Technisch-wissenschaftliche Dokumentation in Deutschland von 1900 bis 1945: unter besonderer Ber\u00fccksichtigung des Verh\u00e4ltnisses von Bibliothek und Dokumentation",
#     "1211": "5 nachhaltige Ideen f\u00fcr Ihre Bibliothek",
#     "1212": "Menschen, B\u00fccher und Computer / Berufsfeld Bibliothek",
#     "1213": "Bachs theologische Bibliothek: eine kritische Bibliographie",
#     "1214": "Library 2.0 \u00e2\\text\\euro`` New perspectives in research libraries and experiences in Germany: BIBLIOTHEK Forschung und Praxis",
#     "1215": "Technisch-wissenschaftliche Dokumentation in Deutschland von 1900 bis 1945: unter besonderer Beru\u0308cksichtigung des Verha\u0308ltnisses von Bibliothek und Dokumentation",
#     "1216": "Googles Herausforderung. F\u00fcr eine europ\u00e4ische\n       Bibliothek",
#     "1217": "Googles Herausforderung. F\u00fcr eine europ\u00e4ische Bibliothek",
#     "1218": "Die Bibliothek der Freien Reichsstadt Windsheim",
#     "1219": "Googles Herausforderung : f\u00fcr eine europ\u00e4ische Bibliothek",
#     "1220": "\u201eKorporatheken\u201c : die digitale und verdatete Bibliothek",
#     "1221": "Das MILESS Datenmodell einer Digitalen Bibliothek.",
#     "1222": "Die Bibliothek der freien Reichsstadt Windsheim",
#     "1223": "Bauliche Grundlagen der allgemeinen \u00f6ffentlichen Bibliothek",
#     "1224": "RAK-Anwendung in der Deutschen Bibliothek",
#     "1225": "Publikationsunterst\u00fctzung: Die Bibliothek ist nicht genug",
#     "1226": "Bauliche Grundlagen der allgemeinen o\u0308ffentlichen Bibliothek",
#     "1227": "Open Access f\u00fcr die Digitale Bibliothek.",
#     "1228": "\u201eKorporatheken\u201c: Die digitale und verdatete Bibliothek",
#     "1229": "Ein Garten auf dem Dach macht noch keine gr\u00fcne Bibliothek: Bibliotheken und die UN-Agenda 2030. Rezension",
#     "1230": "Die Bibliothek des Polnischen Institutes Berlin : \u00dcberlegungen zum Marketing einer One-Person-Library im binationalen Kontext",
#     "1231": "Bibliothek und Moderne in Japan: Das wissenschaftliche Bibliothekswesen zwischen System und Kultur",
#     "1232": "Die Bibliothek des Kardinals Giovanni d'Aragona (1456 - 1485): illuminierte Handschriften und Inkunabeln f\u00fcr einen humanistischen Bibliophilen zwischen Neapel und Rom",
#     "1233": "Organisationsinformatik und Digitale Bibliothek in der Wissenschaft",
#     "1234": "Ein \u00dcberblick \u00fcber die Entwicklung der Bibliothek",
#     "1235": "Babel - Bibel - Bibliothek: Canettis Aphorismen zur Sprache",
#     "1236": "Die Bibliothek des Klosters Bursfelde im Sp\u00e4tmittelalter",
#     "1237": "Vorl\u00e4ufer der Internationalen Katalogisierungsprinzipien",
#     "1238": "Automatisierte und semiautomatisierte Klassifizierung : eine Analyse aktueller Projekte",
#     "1239": "Open Access, Freie Software und Co.: Eine Analyse der Gemengelage",
#     "1240": "Bibliothekarische Klassifikationssysteme im semantischen Web : zu Chancen und Problemen von Linked-Data-Repr\u00e4sentationen ausgew\u00e4hlter Klassifikationssysteme",
#     "1241": "Zukunftslabor Kinder- und Jugendbibliothek: Visionen 2030 und Herausforderungen f\u00fcr die Gegenwart",
#     "1242": "\u0098Die\u009c Bibliothek des Kardinals Giovanni d'Aragona (1456 - 1485): illuminierte Handschriften und Inkunabeln fu\u0308r einen humanistischen Bibliophilen zwischen Neapel und Rom",
#     "1243": "Open Access und Lizenzierung am Beispiel der Allianz-Lizenzen",
#     "1244": "Objektbeschreibende Metadaten in der Deutschen Digitalen Bibliothek : Analyse der Eignung als Informationsfilter im Retrieval",
#     "1245": "Die Bibliothek der Sielkl\u00e4r-Versuchsstation Hamburg-Eppendorf",
#     "1246": "RFID-Technology f\u00fcr die Bibliothek der Zukunft",
#     "1247": "Reclam Universal-Bibliothek, Nr.12, Wilhelm Tell",
#     "1248": "Erfolgreiche Kommunikation mit Kunden in der Bibliothek",
#     "1249": "Quellenuntersuchung zum 1. Buch der Apollodorschen Bibliothek",
#     "1250": "Die Bibliothek als Speichersystem des kulturellen Ged\u00e4chtnisses",
#     "1251": "myDMG-Lib - personalisierter Informationsraum einer digitalen Bibliothek.",
#     "1252": "Bibliothek, Information und Dokumentation in der Wikipedia",
#     "1253": "Elektronische Zeitschriften in der Bibliothek der Zukunft",
#     "1254": "Von vier Haussystematiken zu einer Verbundklassifikation: \u00dcberlegungen zur Reklassifizierung der Bibliothek des Germanistischen Instituts der WWU M\u00fcnster",
#     "1256": "Ein neues Aufgabenfeld f\u00fcr Bibliotheken? Virtuelle Forschungsumgebungen in den Naturwissenschaften am Beispiel des Fachs Physik",
#     "1257": "Die Bibliothek der Weltliteratur. Ausgew\u00e4hlt von Markus Finkbeiner und Thomas Hafki (Digitale Bibliothek 89). Berlin: Directmedia 2004, CD-ROM.",
#     "1258": "Weltanschauung als verlegerische Aufgabe: der Otto-Reichl-Verlag 1909 - 1954 ; mit einer Bibliographie der Verlage von Otto Reichl und der Deutschen Bibliothek",
#     "1259": "Friedrich Nicolais Allgemeine deutsche Bibliothek (Ihre \u00e4u\u00dfere Geschichte)",
#     "1260": "Ressourcenplanung unter Nutzung der Java-Constraint-Bibliothek firstCS.",
#     "1261": "OOAD-Entwicklungsprozess einer Modelica-Bibliothek f\u00fcr vernetzte Automatisierungssysteme.",
#     "1262": "Europeana: Die Europ\u00e4ische Digitale Bibliothek - Entwicklungen und Perspektiven",
#     "1263": "Das neue Fortbildungsportal f\u00fcr Bibliothek und Information -- www.wissenbringtweiter.de",
#     "1264": "Digitale Welt und Wissenschaftliche Bibliothek - Informationspraxis im Wandel",
#     "1265": "Die Welt der B\u00fccher - eine Geschichte der Bibliothek",
#     "1266": "Zum Aufbau einer vollst\u00e4ndigen Gen-Bibliothek des Haushuhns",
#     "1267": "Digitales Datenmanagement als neue Aufgabe f\u00fcr wissenschaftliche Bibliotheken",
#     "1268": "Rezepte zur Nachhaltigkeit: Vielf\u00e4ltige Ideen zur \"Gr\u00fcnen Bibliothek\". Pun, Raymond; Shaffer, Gary L. (eds.), The Sustainable Library's Cookbook (2019): Rezension",
#     "1269": "Data EDUcation an der UDE \u2013 Eine OER f\u00fcr Bibliotheken",
#     "1270": "Fernsehsendungen aufzeichnen. (Fast) freie Bahn zur privaten Bibliothek",
#     "1271": "Erschlie\u00dfung einer Rechenzentrums-Bibliothek mit EDV-erstellten Katalogen.",
#     "1272": "Aussonderungen an Universit\u00e4tsbibliotheken \u2013 Ein Literatur\u00fcberblick und eine explorative Fallstudie zum agrarwissenschaftlichen Bestand der Bibliothek der Humboldt-Universit\u00e4t zu Berlin",
#     "1274": "Das neue Fortbildungsportal f\u00fcr Bibliothek und Information \u2013 www.wissenbringtweiter.de",
#     "1275": "Scriptorium und Bibliothek des Klosters Michelsberg in Bamberg",
#     "1276": "Die \u00d6ffentliche Bibliothek als realer und virtueller Ort",
#     "1278": "Bibliothek 2.0 - Notwendigkeit und M\u00f6glichkeiten neuer bibliothekarischer Dienstleitungen",
#     "1279": "Kommentierter Katalog der nachgelassenen Bibliothek von Johannes Bobrowski",
#     "1280": "Auskunft 2.0: Vom Wie und Wo der bibliothekarischen Antwort im Web 2.0",
#     "1283": "Eine Bibliothek f\u00fcr Babel: Ma\u00dfst\u00e4be einer Spezialbibliothek f\u00fcr literarische \u00dcbersetzer ; eine empirische Untersuchung zu den Informationsbed\u00fcrfnissen von Literatur\u00fcbersetzern unter besonderer Ber\u00fccksichtigung sachlich-inhaltlicher Informationsdefizite",
#     "1286": "Von Bienen und Blumen: \"Wissen w\u00e4chst\" in der Zentralbibliothek der St\u00e4dtischen Bibliotheken Dresden",
#     "1287": "Community Building als Mission: \u00d6ffentliche Bibliotheken als Erm\u00f6glicher",
#     "1288": "Zukunft der Informationsinfrastrukturen: Das deutsche Bibliothekswesen im digitalen Zeitalter",
#     "1289": "Kultur im Wissensnetz - Die Architektur der Deutschen Digitalen Bibliothek.",
#     "1290": "Dimensionen der Zeitschriftenszientometrie am Beispiel von \u201eBuch und Bibliothek\u201c",
#     "1291": "Entwicklung einer Bibliothek zur service-orientierten Modellierung von Ontologien",
#     "1293": "Laufzeitoptimierte VHDL Bibliothek zur Verifikation und Simulation Kryptographischer Prozessoren.",
#     "1294": "Ver\u00f6ffentlichungen und Dokumente der EG eingegangen in der Bibliothek",
#     "1295": "Entwurf und Entwicklung einer objektorientierten Bibliothek f\u00fcr algorithmische Zahlentheorie",
#     "1296": "Konstruktion einer cDNS-Bibliothek der humanen Magenkarzinomzellreihe 23132/87",
#     "1297": "Was ist eine Bibliothek? Physische Bibliotheken im digitalen Zeitalter",
#     "1298": "10 Jahre ECCC - Eine Digitale Bibliothek in weltweiter Benutzung",
#     "1299": "Datenbasis und Bibliothek f\u00fcr ein Programmiersystem f\u00fcr speicherprogrammierbare Steuerungen",
#     "1300": "MCI-DL: Eine digitale Bibliothek f\u00fcr Mensch-Computer-Interaktion.",
#     "1302": "Die Benutzerverwaltung der Digitalen Bibliothek MyCoRe in einem Shibboleth und LDAP Umfeld",
#     "1303": "Ver\u00f6ffentlichungen und Dokumente der EU eingegangen in der Bibliothek",
#     "1304": "Die Bibliothek. 44 B\u00fccher, die man gelesen haben muss",
#     "1305": "Facebook und seine T\u00fccken - ein Experiment an einer Bibliothek.",
#     "1306": "Die Deutsche Bibliothek: The National Archive for Electronic Media?",
#     "1307": "Bibliothek 2.0 : Neue Perspektiven und Einsatzm\u00f6glichkeiten f\u00fcr wissenschaftliche Bibliotheken",
#     "1308": "Bibliotheken in Second Life. Diplomarbeit, Studiengang: Bibliothek, Fachhochschule Potsdam",
#     "1309": "Bibliothek 2.0 - Teaching Library, Web 2.0 und \u00d6ffentliche Bibliotheken",
#     "1310": "Versuch eines vollst\u00e4ndigen Lehrbuches der Bibliothek-Wissenschaft, 2. Band",
#     "1311": "Versuch eines vollst\u00e4ndigen Lehrbuches der Bibliothek-Wissenschaft. Band 1",
#     "1312": "Friedrich Nicolais Allgemeine Deutsche Bibliothek als Integrationsmedium der Gelehrtenrepublik",
#     "1313": "Vom Sinngehalt der Bibliothek im f\u00fcrstlichen Landhaus zu W\u00f6rlitz",
#     "1314": "Vom Sinngehalt der Bibliothek im fu\u0308rstlichen Landhaus zu Wo\u0308rlitz",
#     "1315": "Die griechische Schule und die Bibliothek von Nag Hammadi",
#     "1317": "Datenbasis und Bibliothek f\u00fcr ein Programmiersystem f\u00fcr speicherprogrammierbare Steuerungen.",
#     "1318": "Modernes Datenmanagement : Linked Open Data und die offene Bibliothek",
#     "1319": "Kombinatorisches und Kreatives zum Verh\u00e4ltnis von Mathematik und Bibliothek: Combinatorics and creativity in the relation of mathematics and the library: Ein Nachtrag zum Jahr der Mathematik 2008",
#     "1320": "Generation Google in der Bibliothek. Wer den Weg in die B\u00fccherei scheut, kann sie auch im Internet besuchen. Immer mehr B\u00fccher, Musik, Videos sind digital im Netz ausleihbar",
#     "1321": "Zettelwirtschaft: Die Geburt der Kartei aus dem Geiste der Bibliothek",
#     "1323": "Katalog der armenischen Handschriften in der\r\n                  Mechitharisten-Bibliothek zu Wien",
#     "1324": "Zettelwirtschaft. Die Geburt der Kartei aus dem Geiste der Bibliothek",
#     "1325": "Catalog der armenischen Handschriften in der  Mechitharisten-Bibliothek zu Wien",
#     "1326": "Eine Bibliothek von Basisdiensten f\u00fcr Parallelrechner: Routing, Synchronisation, gemeinsamer Speicher",
#     "1327": "Die elektronische Bibliothek - Literatur- und Informationsbeschaffung im Internet (2.Aufl.).",
#     "1329": "Auf dem Weg zur \u00c4usgezeichneten Bibliothek\" - effizientes Qualit\u00e4tsmanagement in Bibliotheken",
#     "1330": "Modelica-Bibliothek f\u00fcr diffraktive Optik zur Modellierung von optomechatronischen Systemen.",
#     "1331": "Die handschriftlichen Jesuiten-Dramen des Collegii Mannheimensis: (Bibliothek Desbillon 1756)",
#     "1332": "Das Internet-basierte Bibliotheksinformationssystem in der Bibliothek der Universit\u00e4t Bielefeld.",
#     "1333": "Der Fotobestand des Thomas-Mann-Archivs an der ETH-Bibliothek Z\u00fcrich : Bestandesbeschreibung und Konzeption der Erschliessung und Digitalisierung",
#     "1334": "Aufbau einer Suchmaschine f\u00fcr ein Forschungsinstitut - Aufgabe f\u00fcr die Bibliothek?.",
#     "1335": "Katalogerweiterungen, Mashups und Elemente der \u201eBibliothek 2.0\u201c in der Praxis",
#     "1336": "Catalog der armenischen Handschriften in der Mechitharisten-Bibliothek zu Wien",
#     "1338": "Die Blaue Bibliothek aller Nationen, ein Beitrag zur europ\u00e4ischen M\u00e4rchentradition",
#     "1339": "\u0098Die\u009c Septemberbibel Nikolaus Glockendons (1522 - 1524): (Wolfenbu\u0308ttel, Herzog-August-Bibliothek)",
#     "1340": "Prins-Cyclisierung an fester Phase: kombinatorische Synthese einer Tetrahydropyran-Bibliothek",
#     "1341": "Strategien f\u00fcr die Bibliothek als Ort, Festschrift f\u00fcr Petra Hauke",
#     "1342": "Katalogerweiterungen, Mashups und Elemente der \"Bibliothek 2.0\" in der Praxis",
#     "1343": "Das Projekt G\u00f6*: Integriertes Informationsmanagement von Universit\u00e4t, Medizin und Bibliothek.",
#     "1344": "Katalog der Carl Menger-Bibliothek in der Handels-Universit\u00e4t Tokio",
#     "1345": "Die literarische Kritik in Nicolais Allgemeiner deutscher Bibliothek (1765-1794)",
#     "1346": "Die Leiche in der Bibliothek: Friedrich Glauser und der Detektivroman",
#     "1347": "Sonntags in die Bibliothek!: die Wiederbelebung des Bibliothekssonntags in Deutschland",
#     "1348": "Oligosaccharid-basierte Tenside - Synthese und Analytik einer Bibliothek von Glykolipiden",
#     "1349": "Lehrstuhl Digital Library / Lehrstuhl Digitale Bibliothek / La chaire biblioth\u00e8ques num\u00e9riques.",
#     "1351": "Katalog der armenischen Handschriften in der Mechitharisten-Bibliothek zu Wien",
#     "1352": "Numerische Algorithmen in Softwaresystemen - unter besonderer Ber\u00fccksichtigung der NAG-Bibliothek.",
#     "1354": "Bibliothek der dritten Lebensphase : Angebote f\u00fcr die Zielgruppe der \u00c4lteren",
#     "1355": "Die Septemberbibel Nikolaus Glockendons (1522 - 1524): (Wolfenb\u00fcttel, Herzog-August-Bibliothek)",
#     "1356": "Eine Bibliothek von Basisdiensten f\u00fcr Parallelrechner: Routing, Synchronisation, gemeinsamer Speicher.",
#     "1357": "Geschichte schreiben in der Postmoderne - Beitr\u00e4ge zur aktuellen Diskussion",
#     "1358": "Herstellung und Charakterisierung einer cDNA-Bibliothek f\u00fcr das Milchdr\u00fcsengewebe beim Rind",
#     "1359": "Friedrich Nicolais Allgemeine Deutsche Bibliothek und der Friede von Basel 1795",
#     "1360": "\u0098Die\u009c vergessene Bibliothek: Spurensuche zu Biographie und Bu\u0308chersammlung von Victor Manheimer",
#     "1361": "Innovationsmanagement an Hochschulbibliotheken am Beispiel der ETH-Bibliothek - ETH E-Collection",
#     "1362": "Generierung und funktionelle Anwendung einer randomisierten sh- und si-RNA-Bibliothek",
#     "1363": "\u0098Die\u009c \"fiebernde Bibliothek\": Foucaults Sprachontologie und seine diskursanalytische Konzeption moderner Literatur",
#     "1364": "Studien zur Geschichte der Kaiserlichen O\u0308ffentlichen Bibliothek in St. Petersburg (Leningrad)",
#     "1365": "Die Bestandsentwicklung der Bibliothek der Philosophischen Fakult\u00e4t der Universit\u00e4t Leipzig von ihren Anf\u00e4ngen bis zur Mitte des 16. Jh. Jahrhunderts: e. Beitr. zur Wissenschaftsgeschichte d. Leipziger Univ. in ihrer vorreformator. Zeit",
#     "1366": "Konkrete Handlungspotenziale aufgedeckt: Die Klimabilanzierung der Stadtbibliothek Pankow",
#     "1367": "Studien zur Geschichte der Kaiserlichen \u00d6ffentlichen Bibliothek in St. Petersburg (Leningrad)",
#     "1369": "Chemische Modelle f\u00fcr Metalloenzyme: vom biomimetischen Hydrolysekatalysator zur dynamischen Metallorezeptor-Bibliothek",
#     "1370": "Das Konzept der \"virtuellen Bibliothek\" im deutschen Bibliothekswesen der 1990er Jahre",
#     "1371": "Nikolaus von Kues und Raimund Llull: Aus Handschriften d. Kueser Bibliothek",
#     "1372": "Bibliothek 2.0. Neue Perspektiven und Einsatzm\ufffdglichkeiten f\ufffdr wissenschaftliche Bibliotheken",
#     "1373": "Reclam Universal-Bibliothek, Nr.1, Faust I: Der Trag\u00f6die erster Teil",
#     "1374": "Konstruktion einer Glykosyltransferasegen-Bibliothek und ihr Einsatz in der kombinatorischen Biosynthese",
#     "1375": "Mathias Bertram (Hg.): Digitale Bibliothek: Deutsche Literatur von Lessing bis Kafka",
#     "1377": "Der Papyrus 1676 der herculanensischen Bibliothek (Philodemos _P63_E63_R63_I63 _P63_O63_I63_J63_M63_A63_T63_W63_N63): Text u. \u00dcbers.",
#     "1378": "Adaptive Case Management in Bibliotheken - Implementierung in der Bibliothek der DHBW Heidenheim",
#     "1379": "Publikation von Wissenschaft an der Hochschule-Kooperation zwischen Wissenschaftlern und ihrer Bibliothek",
#     "1380": "Die Bibliothek der Zukunft - Text und Schrift in den Zeiten des Internet",
#     "1381": "Die Kulturwissenschaftliche Bibliothek Warburg: Geschichte und Pers\u00f6nlichkeiten der Bibliothek Warburg mit Ber\u00fccksichtigung der Bibliothekslandschaft und der Stadtsituation der Freien und Hansestadt Hamburg zu Beginn des 20. Jahrhunderts",
#     "1382": "\u0098Die\u009c Kulturwissenschaftliche Bibliothek Warburg: Geschichte und Perso\u0308nlichkeiten der Bibliothek Warburg mit Beru\u0308cksichtigung der Bibliothekslandschaft und der Stadtsituation der Freien und Hansestadt Hamburg zu Beginn des 20. Jahrhunderts",
#     "1383": "Global denken, lokal handeln",
#     "1384": "Begr\u00fcnte D\u00e4cher haben viele Vorteile - sie sch\u00fctzen vor Hitze und K\u00e4lte, schonen die Kanalisation und sehen einfach sch\u00f6n aus. Zwei Beispiele f\u00fcr Bibliotheken mit \"Green Roofs\" aus dem Osten und dem Westen der USA",
#     "1386": "Aufwand und Nutzen beim Einsatz von Social-Bookmarking-Services als Nachweisinstrument f\u00fcr wissenschaftliche Forschungsartikel am Beispiel von BibSonomy.",
#     "1387": "Von der \u00dcberwindung der Furcht. Bibliothek der Antike. Katechismus. Lehrbriefe. Spruchsammlung. Fragmente",
#     "1388": "Die Miniaturenhandschriften der Gie\u00dfener Universit\u00e4tsbibliothek und der Gr\u00e4fl. Solmsischen Bibliothek zu Laubach",
#     "1389": "Screening einer Phagen-Bibliothek auf Endothelzellprim\u00e4rkulturen zur Identifizierung von Tumorendothel-assoziierten Antigenen",
#     "1390": "Konzeption und Implementierung von Objekt-Repositorien auf Basis der Ulmer Oberon-Bibliothek",
#     "1391": "Konzeption und Implementierung von Objekt-Repositorien auf Basis der Ulmer Oberon-Bibliothek.",
#     "1392": "Potente HIV-gerichtete RNA-Interferenz mittels Selektion einer randomisierten lentiviralen shRNA-Bibliothek",
#     "1393": "Bibliometrie: Ein neuer Service der Bibliothek der TU Chemnitz in der Forschungsunterst\u00fctzung",
#     "1394": "Studien zur Geschichte der Bibliothek der Abtei St. Eucharius-Matthias zu Trier",
#     "1395": "Die Bibliotheca Alexandrina: Eine sich selbst erfindende Bibliothek des Lehrens und Lernens",
#     "1396": "Biochromatographie einer kombinatorischen Phagen-Peptid-Bibliothek: humane Antik\u00f6rper gegen ein humanes Zytokin",
#     "1397": "Molekularbiologie der zystischen Fibrose: cDNA-Bibliothek, chromosomale DNA-Sonden und biologisches Testsystem",
#     "1398": "Eigenschaften heterotypisch interagierender Transmembranhelices ermittelt durch den Einsatz einer kombinatorischen DNS-Bibliothek",
#     "1399": "Bibliothek der Kirchenversammlungen des vierten und f\u00fcnften Jahrhunderts in Uebersezungen und Ausz\u00fcgen",
#     "1401": "Informationskompetenz vermitteln -- Das modulare Blended- Learning-Szenario der Bibliothek der Universit\u00e4t Konstanz",
#     "1402": "Aufkl\u00e4rung und Bibliophilie: der Hannoveraner Sammler Georg Friedrich Brandes und seine Bibliothek",
#     "1403": "Die Etablierung einer chromosomen-spezifischen DNA-Bibliothek des menschlichen Genoms mittels Mikrodissektion",
#     "1404": "Der Bilderzyklus in der Bibliothek des Klosters San Giorgio Maggiore in Venedig",
#     "1405": "Die Ethik wissenschaftlicher Textproduktion im Zeitalter des Internets. Wie Google und Wikipedia zunehmend die Recherche in der Bibliothek ersetzen",
#     "1406": "Bibliotheken der Dinge als neues Arbeitsfeld \u00d6ffentlicher Bibliotheken: Eine explorative Studie auf Basis von Expert:inneninterviews.  Bachelorarbeit Bibliotheks- und Informationsmanagement",
#     "1407": "Der Neubau f\u00fcr die K\u00f6nigliche Bibliothek und die Akademie der Wissenschaften in Berlin",
#     "1408": "Isolierung und Charakterisierung genomischer Klone f\u00fcr Milchprotein-Gene aus einer bovinen Cosmid-Bibliothek",
#     "1409": "Charakterisierung von anonymen, menschlichen DNA-Sonden aus einer Chromosom 20-spezifischen DNA-Bibliothek",
#     "1410": "FTIR-spektrometrische \u00c4hnlichkeits- und Identit\u00e4tssuchen am Beispiel einer digitalisierten FTIRS-Bibliothek organischer Pigmente",
#     "1411": "Erstellung einer genomischen BAC-Bibliothek f\u00fcr Untersuchungen zur Geschlechtsdeterminierung im Tiermodell Ellobius lutescens",
#     "1412": "Erstellung einer genomischen BAC Bibliothek f\u00fcr Untersuchungen zur Geschlechtsdeterminierung im Tiermodell Ellobius lutescens",
#     "1414": "Metadatenmapping im Projekt Deutsche Digitale Bibliothek anhand von Dublin Core, Lido und EAD.",
#     "1417": "Modelica Predictive Control - An MPC Library for Modelica (Eine MPC-Bibliothek f\u00fcr Modelica).",
#     "1419": "Zur Erweiterung von Programmiersprachen durch Bibliotheken: Konzeption und Realisierung der Ulmer Oberon-Bibliothek",
#     "1420": "Untersuchungen \u00fcber die Katharinenlegende des Hs. II, 143 der Kgl. Bibliothek zu Br\u00fcssel",
#     "1421": "\u0098Die\u009c Herzogin Anna Amalia Bibliothek in Weimar: zur Baugeschichte im Zeitalter der Aufkla\u0308rung",
#     "1422": "Zur Erweiterung von Programmiersprachen durch Bibliotheken: Konzeption und Realisierung der Ulmer Oberon-Bibliothek.",
#     "1424": "Universit\u00e4tsverlage: Stand und Entwicklungsperspektiven : der Vortrag wurde gehalten am 22. M\u00e4rz auf dem 95. Deutschen Bibliothekartag im Themenkreis 8",
#     "1425": "Erfahrungsbericht: Praktische Umsetzung des Informationsmanagements",
#     "1429": "Leseverhalten und Lesefo\u0308rderung: zur Rolle von Schule, Familie und Bibliothek im Medienalltag Heranwachsender",
#     "1430": "Aufbau eines Assays zur In-vitro-Selektion einer Adenosindesaminase aus einer RNA-Bibliothek",
#     "1431": "Erwerbungen der \"Bibliothek der Hansestadt Hamburg\" aus ehemals j\u00fcdischem Besitz (1940 bis 1944)",
#     "1432": "Die Suche nach der symbolischen Form: d. Kreis um d. Kulturwiss. Bibliothek Warburg",
#     "1433": "\u0098Die\u009c Suche nach der symbolischen Form: d. Kreis um d. kulturwiss. Bibliothek Warburg",
#     "1434": "\u0098Die\u009c Bibliothek der ehemaligen Mainzer Kartause: die Handschriften u. ihre Gesch. ; darstellender Teil",
#     "1435": "Die elektronische Bibliothek. Literatur- und Informationsbeschaffung im Internet. 2., \u00fcberarb. und erw. Aufl.",
#     "1436": "Schreibende Frauen um 1500: Scriptorium und Bibliothek des Dominikanerinnenklosters St. Katharina St. Gallen",
#     "1437": "State-of-the-Art Kryptoverfahren f\u00fcr drahtlose Sensornetze - Eine Krypto-Bibliothek f\u00fcr MantisOS.",
#     "1438": "Einbindung von Prim\u00e4rdaten in Digitale Bibliotheken",
#     "1439": "SMART-Boards in Bibliotheken",
#     "1440": "Von der Hol- zur Bringbibliothek",
#     "1441": "Transfer zwischen Wissenschaft und Bibliothek: Beispiele aus der Praxis des Fachreferats Chemie und Verfahrenstechnik",
#     "1442": "Bibliotheken der Zukunft - Zukunft der Bibliotheken. Die Bibliothek in 10 Jahren - Zukunftsvisionen und Zukunftsstrategien",
#     "1443": "Die Erstellung, Charakterisierung und Nutzung einer DNA-Bibliothek von Gerste in k\u00fcnstlichen Hefechromosomen (YACs)",
#     "1444": "Membra disiecta: Inhalt und Wirkung der Bibliothek des Go\u0308ttinger Professors Lu\u0308der Kulenkamp  ; (1724 - 1794)",
#     "1445": "Die Rolle einer Universit\u00e4tsbibliothek im E-Learning - oder: Auf dem Weg zur Bibliothek 2.0!?",
#     "1446": "Erstellung und Validierung einer kombinierten NIR-Raman-Bibliothek zur Identit\u00e4tskontrolle organischer und anorganischer Substanzen",
#     "1447": "Handschriften der Welser: die Bibliothek der Paul-Wolfgang-Merkelschen-Familienstiftung im Germanischen Nationalmuseum N\u00fcrnberg",
#     "1448": "Gr\u00fcne Bibliotheken: \"Wir m\u00fcssen auf die gesellschaftlichen Ver\u00e4nderungen reagieren\u201c: Interview mit Tim Schumann",
#     "1449": "Mikromanipulation am menschlichen Chromosom 22: Techniken zur Erstellung einer regionspezifischen DNA-Bibliothek (22q12.3-qter)",
#     "1450": "Nutzerevaluation der Virtuellen Fachbibliothek Ethnologie : eine qualitative Usability-Studie",
#     "1451": "How and why to try a blog for staff communication\"",
#     "1452": "B\u00fccherspuren : das Schicksal von Elise und Helene Richter und ihrer Bibliothek im \"Dritten Reich\"",
#     "1453": "PC-gest\u00fctzte, systemtheoretische Modellierung: Entwicklung einer Software-Bibliothek f\u00fcr die psychologische Lehre und Forschung.",
#     "1454": "\u0098Der\u009c Codex Borgia: Untersuchgn zur Ikonographie e. mexikan. Bilderhandschrift d. Vatikan. Bibliothek in Rom",
#     "1455": "Das RFID-Projekt an der Bibliothek der Humboldt-Universit\u00e4t zu Berlin \u2014 Stand und Perspektiven",
#     "1456": "Die Sonderdrucksammlung von Felix Pinkus (1968-1947) in der Bibliothek der Hautklinik der Charit\u00e9",
#     "1457": "Entwicklung einer Modell-Bibliothek zur Simulation von Bahnspannung und T\u00e4nzerbewegung beim Transport von Materialbahnen",
#     "1458": "Membra disiecta: Inhalt und Wirkung der Bibliothek des G\u00f6ttinger Professors L\u00fcder Kulenkamp (1724 - 1794)",
#     "1459": "Die Bibliothek des Petrus Mitte de Caprariis, Pr\u00e4zeptors der Antonier in Memmingen (1439-1479)",
#     "1461": "Membra disiecta: Inhalt und Wirkung der Bibliothek des Go\u0308ttinger Professors Lu\u0308der Kulenkamp (1724 - 1794)",
#     "1462": "Konzeption und prototypische Realisierung einer Portalanwendung zur f\u00f6derierten Suche im Online-Angebot einer Bibliothek.",
#     "1463": "Unterrichtstheorie in Bilddokumenten des 15. bis 17. Jahrhunderts: e. Studie zum Bildtypus der Accipies u. seinen Modifikationen im Bildbestand d. Univ.-Bibliothek Helmstedt u.d. Augusteischen Buchbestandes d. Herzog August Bibliothek in Wolfenb\u00fcttel",
#     "1464": "Bibliographie und Sacherschliessung in der Hand vernetzter Informationsbenutzer",
#     "1465": "Auskunftsdienste der Zentralbibliothek der FH Hannover:\r\nEvaluation derzeitiger und Konzeption neuer Auskunftsdienste",
#     "1466": "HERAUSFORDERUNG BIBLIOTHEK 2.0 : Chancen und Risiken f\u00fcr Verbundkataloge durch die Anreicherung mit Web 2.0-Konzepten",
#     "1467": "Partizipative Entwicklung von Diensten in der Bibliothek 2.0: Methoden und Ergebnisse aus Katalog 2.0-Projekten",
#     "1468": "eXamples of Modern Libraries - Publikation, Dokument und Format (XML - PDF) in der Bibliothek der Zukunft",
#     "1469": "Die Bibliothek des Johann Christian von Boineburg (1622 - 1672): eine Beitrag zur Bibliotheksgeschichte des Polyhistorismus",
#     "1470": "Etablierung einer embryonalen cDNA-Bibliothek und Klonierung eines FGFR-Homologs aus Enchytraeus coronatus (Annelida, Oligochaeta)",
#     "1471": "Vor dem Richterstuhl der Kritik: die Musik in Friedrich Nicolais Allgemeiner Deutscher Bibliothek 1765 - 1806",
#     "1472": "\"Gut ist uns nie gut genug!\": Instrumente zur Qualit\u00e4tsentwicklung und Qualit\u00e4tssicherung f\u00fcr eine ausgezeichnete Bibliothek",
#     "1473": "Mashups und Bibliotheken",
#     "1474": "Science Tracking auf der Spur \u2013 die Rolle von Bibliotheken im Kontext von Reading Analytics bei wissenschaftlichen Verlagen",
#     "1476": "Die Frauenzimmer-Bibliothek des Hamburger Patrioten von 1724 siebzehnhundertvierundzwanzig: zur weibl. Bildung in d. Fr\u00fchaufkl\u00e4rung",
#     "1477": "Die Messen der Santini-Bibliothek zu M\u00fcnster i. W.: (Ein Beitr. z. Gesch. d. Messe)",
#     "1478": "Die Bibliothek des Johann Christian von Boineburg (1622 - 1672): ein Beitrag zur Bibliotheksgeschichte des Polyhistorismus",
#     "1479": "\u0098Die\u009c Bibliothek von Nag Hammadi: einige Probleme des Christentums in A\u0308gypten wa\u0308hrend der ersten Jahrhunderte",
#     "1480": "\"Wohlgelebt! Wohlgestorben?\" Leichenpredigten in der Historischen Bibliothek der Stadt Rudolstadt - H-Soz-u-Kult / Tagungsberichte",
#     "1482": "Schrift, Wissen und Geda\u0308chtnis: das Motiv der Bibliothek als Spiegel des Medienwandels im 20. Jahrhundert",
#     "1484": "Etablierung eines Systems zur Herstellung und Untersuchung einer REMI-Bibliothek des gerstepathogenen Pilzes Pyrenophora teres",
#     "1485": "Totalsynthese des Tyrosinkinase Inhibitors Nakijichinon C und Darstellung einer Bibliothek von Analoga durch kombinatorische Synthese",
#     "1487": "Data Librarian : ein neuer Studienschwerpunkt f\u00fcr wissenschaftliche Bibliotheken und Forschungseinrichtungen",
#     "1488": "Landmark with green credentials: Brighton\u2019s \u201cJubilee Library\u201d",
#     "1489": "\"Environmental awareness is on the rise\": Sustainability in Danish public libraries",
#     "1490": "Informationskompetenz",
#     "1491": "VIAF (Virtual International Authority File): Linking Die Deutsche Bibliothek and Library of Congress Name Authority Files",
#     "1492": "SEREX-Analyse einer Testis-derivierten cDNA-Bibliothek: Identifikation und Charakterisierung des neuen Cancer-Testis Antigens SCP1",
#     "1493": "Das Lexicon plantarum (Handschrift 604 d. M\u00fcnchener Univ.-Bibliothek): Ein Vorl\u00e4ufer d. dt. Kr\u00e4uterbuchinkunabeln ; T. 2",
#     "1494": "Projekt: Semantic Web Entwicklung einer unabh\u00e4nngigen Bibliothek zur Berechnung von Empfehlungen auf Basis des BibSonomy Empfehlungssystems",
#     "1496": "Membra disiecta : Inhalt und Wirkung der Bibliothek des G\u00f6ttinger Professors L\u00fcder Kulenkamp  ; (1724 - 1794) / Annette Pozzo",
#     "1497": "Aufbau und Erprobung einer Bibliothek von UV-Remissionsspektren sowie ihre Anwendung in der systematischen-toxikologischen Analyse",
#     "1498": "Synthese und Screening einer Bibliothek von fl\u00fcssigkristallinen Quaterphenylen: mit kombinatorischen Methoden zum rationalen Design neuer Materialien",
#     "1499": "Die Bibliothek als Missing Link zwischen Smart Citys und Smart Citizen?! Denkanst\u00f6\u00dfe zu einer m\u00f6glichen Beteiligung",
#     "1501": "Die Forschungsbibliothek der Zukunft",
#     "1502": "Neue Aufgaben, neue Arbeitsfelder, neue Strukturen: Zur Zukunft der Wissenschaftlichen Bibliotheken im internationalen Forschungswettbewerb am Beispiel des Embedded Librarian",
#     "1503": "Merkw\u00fcrdige Leute",
#     "1504": "Sustainability hides in libraries: The state of ecological sustainability in libraries",
#     "1505": "Spurensicherung \u2013 Provenienzforschung zur Bibliothek von Agathe Lasch. Ein Projekt an der Universit\u00e4tsbibliothek der Humboldt-Universit\u00e4t zu Berlin",
#     "1506": "\u0098Die\u009c deutsche Jugendliteratur in der zweiten Ha\u0308lfte des 18. Jahrhunderts auf Grund von Nicolais Allgemeiner Deutscher Bibliothek",
#     "1507": "Der Systemcharakter der wissenschaftlichen Bibliothek: Grundlagen und Entwicklungsm\u00f6glichkeiten der wissenschaftlichen Bibliotheken der Bundesrepublik Deutschland aus systemtheoretischer Sicht.",
#     "1508": "Stefan George: Gesamtausgabe der Werke. Faksimile und Volltext (Digitale Bibliothek 99). Berlin: Directmedia Publishing 2004, CD-ROM.",
#     "1509": "Information? Ja! - Abkupfern? Nein!",
#     "1511": "Between Dewey and Dewey: Information Literacy in Germany between a Librarian's and a More Holistiv View",
#     "1513": "Die F\u00fcnfzehn Zeichen in der Handschrift Nr. 215 Nummer zweihundertf\u00fcnfzehn der Gr\u00e4flich-von-Sch\u00f6nborn'schen Bibliothek zu Pommersfelden",
#     "1514": "Entwurf und Implementierung einer VRML Bibliothek fuer ein objektrelationales Datenbanksystem auf der Basis des VRML 2.0 Standards",
#     "1515": "Die deutsche Jugendliteratur in der zweiten H\u00e4lfte des 18. Jahrhunderts auf Grund von Nicolais Allgemeiner Deutscher Bibliothek",
#     "1516": "Der medizinische Teil der Bibliothek des mecklenburgischen Herzogs Johann Albrecht (1525 - 1576): eine Rekonstruktion und medizinhistorische Bewertung",
#     "1517": "Deutsche Bibliotheksstatistik (DBS): Konzept, Umsetzung und Perspektiven f\u00fcr eine umfassende Datenbasis zum Bibliothekswesen in Deutschland: 10 Fragen von Bruno Bauer an Ronald M. Schmidt, Leiter der DBS",
#     "1518": "Von anderen lernen. Bibliothekarische Verbandsinitiativen zur Erreichung der UN-Nachhaltigkeitsziele im deutschsprachigen Raum",
#     "1519": "Die L\u00e4ngere Notiz \u00fcber den Puls im Codex Nr. 222 der Bibliothek des Sankt Nikolaus-Hospitals zu Kues",
# ...
#     "1851": "Eric Tierling",
#     "1852": "Hermannus Pfeiffer",
#     "1854": " ?",
#     "1855": "Ulrich Briefs",
#     "1856": "Peter Hinrichs",
#     "1857": "Abu Bakr Ibn Tufail",
#     "1858": "Franz Ronneberger",
#     "1859": " Aristoteles",
#     "1860": "Immanuel Kant",
#     "1861": "Wolfgang Klafki",
#     "1862": "Philipp Fuchs",
#     "1864": "Dziga Vertov",
#     "1865": "Ren\u00e9 Descartes",
#     "1866": "Ren\u00e9 Descartes",
#     "1867": "Gottfried Wilhelm Leibniz",
#     "1868": "Paul Ricoeur",
#     "1869": "Edmund Husserl",
#     "1872": "Erik Gurgsdies",
#     "1873": "G\u00fcnter Danert",
#     "1874": "Erich Sch\u00e4fer",
#     "1875": "Hermann Funke",
#     "1876": "Rosabeth Moss Kanter",
#     "1877": "Thomas Rothe",
#     "1879": "Eric Tierling",
#     "1880": "Lars Gerschau",
#     "1881": " ?",
#     "1882": "Theodor Ascher",
#     "1883": "Konrad Mellerowicz",
#     "1884": "Rene Descartes",
#     "1886": "Franz Ronneberger",
#     "1888": "J\u00f6rg Goldberg",
#     "1889": "Peter R\u00f6mer",
#     "1891": " ?",
#     "1893": "Christian Schmid",
#     "1894": " Aristoteles",
#     "1895": "Ren\u00e9 Descartes",
#     "1896": "Theodor W. Adorno",
#     "1897": "Uwe Timm",
#     "1898": "Gaston Bachelard",
#     "1899": " ?",
#     "1901": "Walter Baur",
#     "1905": "Pavel Rapo\u00ff\u00e9s",
#     "1906": "Karl Dietrich Bracher",
#     "1908": "James E. Meade",
#     "1909": "Hanns Linhardt",
#     "1910": "Jozef Wilczynski",
#     "1911": "J\u00f6rg Bankmann",
#     "1913": "Susanne Koch",
#     "1915": "Dziga Vertov",
#     "1917": "Walter Benjamin",
#     "1918": "Holm Tetens",
#     "1919": "Gottfried W. Leibniz",
#     "1920": "Gottfried Wilhelm Leibniz",
#     "1922": "Peter Hinrichs",
#     "1923": "Eric Tierling",
#     "1925": "Georg Wilhelm Friedrich Hegel",
#     "1926": "Ren\u00e9 Descartes",
#     "1927": "Erik Hornung",
#     "1928": "Paul Ric\u0153ur",
#     "1929": "Jean Le Rond d' Alembert",
#     "1930": "Melvil Dewey",
#     "1931": "Ben Bachmair",
#     "1932": "Jeremias Gotthelf",
#     "1933": "Ingrid Baumg\u00e4rtner",
#     "1935": "Axel Leijonhufvud",
#     "1936": "Johannes Riedel",
#     "1937": "Eugen Rau",
#     "1938": "J\u00fcrgen R\u00e4uschel",
#     "1939": "Albert Schnettler",
#     "1943": "Jack Hirshleifer",
#     "1945": "Albert Calmes",
#     "1947": " ?",
#     "1948": "Hans Prolingheuer",
#     "1949": " ?",
#     "1950": "Ludwig Wittgenstein",
#     "1951": "Gottfried Wilhelm Leibniz",
#     "1953": "Brigitte Cech",
#     "1954": "Friedrich Wilhelm Joseph von Schelling",
#     "1955": "Georg von Below",
#     "1960": "Ingemar K\u00f6nig",
#     "1963": "Erik Reger",
#     "1964": "Willi Bredel",
#     "1965": "Lucien Febvre",
#     "1966": "Alexander Sinowjew",
#     "1967": "Peter Weingart",
#     "1968": "Carsten K\u00fcther",
#     "1970": "Heike Behle",
#     "1972": "Roman Lutz",
#     "1973": "Leon Mann",
#     "1974": "Frank Niess",
#     "1975": "Friedrich Henzel",
#     "1976": "Erich Kosiol",
#     "1977": "Walter Baumann",
#     "1978": " ?",
#     "1979": "Kenneth Joseph Arrow",
#     "1980": "Max Rudolf Lehmann",
#     "1981": "Franz Ronneberger",
#     "1982": "Michael E. Porter",
#     "1983": "Fritz Peter Knapp",
#     "1984": "Heinz-J\u00fcrgen Axt",
#     "1985": " ?",
#     "1987": "Florian D\u00e4umling",
#     "1988": "Frank Baron",
#     "1989": "Christoph Conrad",
#     "1990": "Richard Rorty",
#     "1992": "J. B. Hofmann",
#     "1995": "Benedict R. O'G. Anderson",
#     "1996": "Annemarie Schimmel",
#     "1997": "Carl von Clausewitz",
#     "1998": "Theodor Wiesengrund Adorno",
#     "1999": "Immanuel Kant"
#   },
#   "num_auth": {
#     "1000": 1,
#     "1001": 2,
#     "1002": 1,
#     "1003": 1,
#     "1004": 2,
#     "1005": 2,
#     "1011": 1,
#     "1012": 1,
#     "1013": 1,
#     "1014": 1,
#     "1015": 1,
#     "1017": 1,
#     "1018": 2,
#     "1019": 1,
#     "1020": 1,
#     "1021": 1,
#     "1022": 1,
#     "1024": 1,
#     "1025": 1,
#     "1026": 1,
#     "1029": 2,
#     "1032": 1,
#     "1035": 1,
#     "1036": 1,
#     "1037": 1,
#     "1038": 1,
#     "1039": 1,
#     "1040": 1,
#     "1041": 1,
#     "1042": 2,
#     "1043": 1,
#     "1044": 1,
#     "1045": 1,
#     "1051": 1,
#     "1052": 1,
#     "1053": 1,
#     "1054": 1,
#     "1055": 1,
#     "1056": 1,
#     "1058": 1,
#     "1059": 1,
#     "1060": 1,
#     "1061": 1,
#     "1062": 1,
#     "1063": 1,
#     "1064": 1,
#     "1065": 2,
#     "1066": 2,
#     "1067": 1,
#     "1068": 2,
#     "1069": 2,
#     "1071": 1,
#     "1072": 1,
#     "1074": 1,
#     "1077": 2,
#     "1080": 1,
#     "1081": 1,
#     "1082": 1,
#     "1083": 1,
#     "1084": 1,
#     "1086": 1,
#     "1087": 2,
#     "1088": 1,
#     "1089": 1,
#     "1092": 1,
#     "1093": 3,
#     "1094": 1,
#     "1095": 1,
#     "1096": 1,
#     "1097": 1,
#     "1098": 1,
#     "1099": 1,
#     "1100": 1,
#     "1102": 1,
#     "1103": 1,
#     "1105": 1,
#     "1110": 1,
#     "1111": 1,
#     "1112": 1,
#     "1113": 1,
#     "1114": 1,
#     "1115": 1,
#     "1116": 3,
#     "1117": 1,
#     "1118": 1,
#     "1120": 1,
#     "1121": 2,
#     "1122": 2,
#     "1123": 1,
#     "1124": 1,
#     "1125": 1,
#     "1126": 1,
#     "1127": 1,
#     "1128": 1,
#     "1129": 1,
#     "1130": 1,
#     "1131": 2,
#     "1132": 1,
#     "1133": 1,
#     "1134": 1,
#     "1137": 1,
#     "1138": 1,
#     "1141": 1,
#     "1142": 1,
#     "1145": 1,
#     "1146": 1,
#     "1148": 1,
#     "1149": 1,
#     "1151": 1,
#     "1152": 1,
#     "1153": 1,
#     "1154": 2,
#     "1156": 1,
#     "1157": 1,
#     "1158": 1,
#     "1159": 1,
#     "1161": 2,
#     "1164": 1,
#     "1165": 1,
#     "1166": 1,
#     "1167": 1,
#     "1170": 1,
#     "1171": 1,
#     "1172": 1,
#     "1173": 1,
#     "1174": 1,
#     "1176": 1,
#     "1177": 1,
#     "1178": 1,
#     "1179": 1,
#     "1180": 1,
#     "1181": 1,
#     "1182": 2,
#     "1183": 1,
#     "1184": 1,
#     "1185": 1,
#     "1186": 1,
#     "1188": 3,
#     "1189": 1,
#     "1190": 1,
#     "1191": 1,
#     "1192": 1,
#     "1194": 2,
#     "1197": 1,
#     "1198": 1,
#     "1199": 3,
#     "1200": 1,
#     "1201": 1,
#     "1202": 1,
#     "1203": 1,
#     "1205": 1,
#     "1206": 1,
#     "1207": 1,
#     "1208": 1,
#     "1209": 1,
#     "1210": 1,
#     "1211": 1,
#     "1212": 1,
#     "1213": 1,
#     "1214": 1,
#     "1215": 1,
#     "1216": 1,
#     "1217": 1,
#     "1218": 1,
#     "1219": 1,
#     "1220": 2,
#     "1221": 1,
#     "1222": 1,
#     "1223": 1,
#     "1224": 1,
#     "1225": 1,
#     "1226": 1,
#     "1227": 1,
#     "1228": 2,
#     "1229": 1,
#     "1230": 1,
#     "1231": 1,
#     "1232": 1,
#     "1233": 1,
#     "1234": 1,
#     "1235": 1,
#     "1236": 1,
#     "1237": 1,
#     "1238": 1,
#     "1239": 2,
#     "1240": 1,
#     "1241": 1,
#     "1242": 1,
#     "1243": 1,
#     "1244": 1,
#     "1245": 1,
#     "1246": 1,
#     "1247": 1,
#     "1248": 1,
#     "1249": 1,
#     "1250": 1,
#     "1251": 3,
#     "1252": 2,
#     "1253": 1,
#     "1254": 1,
#     "1256": 1,
#     "1257": 2,
#     "1258": 1,
#     "1259": 1,
#     "1260": 1,
#     "1261": 2,
#     "1262": 1,
#     "1263": 2,
#     "1264": 1,
#     "1265": 1,
#     "1266": 1,
#     "1267": 4,
#     "1268": 1,
#     "1269": 2,
#     "1270": 1,
#     "1271": 1,
#     "1272": 1,
#     "1274": 2,
#     "1275": 1,
#     "1276": 4,
#     "1278": 1,
#     "1279": 1,
#     "1280": 1,
#     "1283": 1,
#     "1286": 1,
#     "1287": 1,
#     "1288": 1,
#     "1289": 9,
#     "1290": 3,
#     "1291": 1,
#     "1293": 3,
#     "1294": 1,
#     "1295": 1,
#     "1296": 1,
#     "1297": 1,
#     "1298": 2,
#     "1299": 1,
#     "1300": 3,
#     "1302": 1,
#     "1303": 1,
#     "1304": 1,
#     "1305": 2,
#     "1306": 1,
#     "1307": 1,
#     "1308": 1,
#     "1309": 1,
#     "1310": 1,
#     "1311": 1,
#     "1312": 1,
#     "1313": 1,
#     "1314": 1,
#     "1315": 1,
#     "1317": 1,
#     "1318": 1,
#     "1319": 1,
#     "1320": 1,
#     "1321": 1,
#     "1323": 1,
#     "1324": 1,
#     "1325": 1,
#     "1326": 1,
#     "1327": 1,
#     "1329": 1,
#     "1330": 2,
#     "1331": 1,
#     "1332": 1,
#     "1333": 1,
#     "1334": 2,
#     "1335": 1,
#     "1336": 1,
#     "1338": 1,
#     "1339": 1,
#     "1340": 1,
#     "1341": 3,
#     "1342": 1,
#     "1343": 2,
#     "1344": 1,
#     "1345": 1,
#     "1346": 1,
#     "1347": 1,
#     "1348": 1,
#     "1349": 1,
#     "1351": 1,
#     "1352": 1,
#     "1354": 1,
#     "1355": 1,
#     "1356": 1,
#     "1357": 2,
#     "1358": 1,
#     "1359": 1,
#     "1360": 1,
#     "1361": 1,
#     "1362": 1,
#     "1363": 1,
#     "1364": 1,
#     "1365": 1,
#     "1366": 1,
#     "1367": 1,
#     "1369": 1,
#     "1370": 1,
#     "1371": 1,
#     "1372": 1,
#     "1373": 1,
#     "1374": 1,
#     "1375": 2,
#     "1377": 1,
#     "1378": 1,
#     "1379": 1,
#     "1380": 1,
#     "1381": 1,
#     "1382": 1,
#     "1383": 1,
#     "1384": 1,
#     "1386": 1,
#     "1387": 1,
#     "1388": 1,
#     "1389": 1,
#     "1390": 1,
#     "1391": 1,
#     "1392": 1,
#     "1393": 2,
#     "1394": 1,
#     "1395": 2,
#     "1396": 1,
#     "1397": 1,
#     "1398": 1,
#     "1399": 1,
#     "1401": 1,
#     "1402": 1,
#     "1403": 1,
#     "1404": 1,
#     "1405": 1,
#     "1406": 1,
#     "1407": 2,
#     "1408": 1,
#     "1409": 1,
#     "1410": 1,
#     "1411": 1,
#     "1412": 1,
#     "1414": 1,
#     "1417": 2,
#     "1419": 1,
#     "1420": 1,
#     "1421": 1,
#     "1422": 1,
#     "1424": 1,
#     "1425": 1,
#     "1429": 1,
#     "1430": 1,
#     "1431": 1,
#     "1432": 1,
#     "1433": 1,
#     "1434": 1,
#     "1435": 1,
#     "1436": 1,
#     "1437": 2,
#     "1438": 2,
#     "1439": 3,
#     "1440": 1,
#     "1441": 1,
#     "1442": 1,
#     "1443": 1,
#     "1444": 1,
#     "1445": 1,
#     "1446": 1,
#     "1447": 1,
#     "1448": 1,
#     "1449": 1,
#     "1450": 1,
#     "1451": 1,
#     "1452": 1,
#     "1453": 1,
#     "1454": 1,
#     "1455": 2,
#     "1456": 1,
#     "1457": 1,
#     "1458": 1,
#     "1459": 1,
#     "1461": 1,
#     "1462": 1,
#     "1463": 1,
#     "1464": 1,
#     "1465": 2,
#     "1466": 1,
#     "1467": 1,
#     "1468": 1,
#     "1469": 1,
#     "1470": 1,
#     "1471": 1,
#     "1472": 1,
#     "1473": 3,
#     "1474": 1,
#     "1476": 1,
#     "1477": 1,
#     "1478": 1,
#     "1479": 1,
#     "1480": 1,
#     "1482": 1,
#     "1484": 1,
#     "1485": 1,
#     "1487": 4,
#     "1488": 1,
#     "1489": 1,
#     "1490": 1,
#     "1491": 4,
#     "1492": 1,
#     "1493": 1,
#     "1494": 1,
#     "1496": 1,
#     "1497": 1,
#     "1498": 1,
#     "1499": 1,
#     "1501": 3,
#     "1502": 6,
#     "1503": 1,
#     "1504": 1,
#     "1505": 2,
#     "1506": 1,
#     "1507": 1,
#     "1508": 1,
#     "1509": 2,
#     "1511": 1,
#     "1513": 1,
#     "1514": 2,
#     "1515": 1,
#     "1516": 1,
#     "1517": 2,
#     "1518": 1,
#     "1519": 1,
#     "1520": 1,
#     "1521": 1,
#     "1522": 1,
#     "1523": 2,
#     "1524": 1,
#     "1525": 5,
#     "1526": 1,
#     "1527": 1,
#     "1528": 2,
#     "1529": 3,
#     "1530": 2,
#     "1531": 1,
#     "1532": 1,
#     "1533": 2,
#     "1534": 2,
#     "1535": 1,
#     "1538": 1,
#     "1539": 2,
#     "1540": 1,
#     "1541": 1,
#     "1542": 1,
#     "1543": 1,
#     "1544": 1,
#     "1545": 1,
#     "1546": 1,
#     "1547": 1,
#     "1548": 1,
#     "1549": 1,
#     "1550": 1,
#     "1551": 1,
#     "1552": 2,
#     "1554": 1,
#     "1555": 1,
#     "1556": 1,
#     "1557": 1,
#     "1558": 1,
#     "1559": 1,
#     "1560": 1,
#     "1561": 1,
#     "1562": 1,
#     "1563": 1,
#     "1564": 1,
#     "1565": 1,
#     "1566": 1,
#     "1567": 1,
#     "1568": 1,
#     "1569": 1,
#     "1570": 1,
#     "1571": 1,
#     "1572": 4,
#     "1573": 1,
#     "1574": 1,
#     "1575": 1,
#     "1576": 1,
#     "1577": 1,
#     "1578": 1,
#     "1579": 1,
#     "1580": 1,
#     "1581": 1,
#     "1582": 1,
#     "1583": 1,
#     "1584": 1,
#     "1585": 1,
#     "1586": 1,
#     "1587": 1,
#     "1588": 1,
#     "1589": 1,
#     "1590": 1,
#     "1591": 1,
#     "1592": 1,
#     "1594": 1,
#     "1595": 1,
#     "1596": 1,
#     "1597": 1,
#     "1598": 1,
#     "1599": 1,
#     "1600": 1,
#     "1602": 1,
#     "1604": 1,
#     "1606": 3,
#     "1607": 1,
#     "1609": 1,
#     "1610": 1,
#     "1611": 1,
#     "1612": 1,
#     "1613": 1,
#     "1614": 1,
#     "1615": 1,
#     "1616": 2,
#     "1617": 1,
#     "1618": 1,
#     "1619": 6,
#     "1620": 7,
#     "1621": 1,
#     "1622": 1,
#     "1623": 1,
#     "1624": 2,
#     "1625": 1,
#     "1626": 1,
#     "1627": 1,
#     "1628": 2,
#     "1629": 1,
#     "1630": 1,
#     "1633": 1,
#     "1634": 1,
#     "1635": 1,
#     "1636": 1,
#     "1637": 2,
#     "1638": 1,
#     "1639": 1,
#     "1641": 1,
#     "1642": 1,
#     "1643": 1,
#     "1644": 1,
#     "1645": 2,
#     "1646": 1,
#     "1648": 2,
#     "1649": 1,
#     "1650": 2,
#     "1651": 2,
#     "1652": 1,
#     "1653": 2,
#     "1654": 2,
#     "1655": 1,
#     "1656": 1,
#     "1657": 1,
#     "1658": 1,
#     "1659": 1,
#     "1660": 1,
#     "1661": 1,
#     "1662": 1,
#     "1663": 1,
#     "1664": 1,
#     "1665": 3,
#     "1666": 1,
#     "1667": 1,
#     "1668": 1,
#     "1669": 1,
#     "1670": 1,
#     "1671": 1,
#     "1672": 1,
#     "1674": 1,
#     "1675": 1,
#     "1677": 2,
#     "1678": 1,
#     "1679": 1,
#     "1680": 1,
#     "1681": 2,
#     "1682": 1,
#     "1683": 1,
#     "1684": 1,
#     "1685": 1,
#     "1686": 1,
#     "1687": 3,
#     "1689": 1,
#     "1690": 1,
#     "1691": 1,
#     "1693": 1,
#     "1694": 1,
#     "1695": 1,
#     "1697": 1,
#     "1698": 1,
#     "1699": 1,
#     "1700": 2,
#     "1701": 1,
#     "1702": 3,
#     "1703": 3,
#     "1704": 1,
#     "1705": 1,
#     "1706": 1,
#     "1707": 1,
#     "1708": 1,
#     "1709": 1,
#     "1710": 1,
#     "1711": 1,
#     "1712": 1,
#     "1713": 1,
#     "1714": 1,
#     "1715": 2,
#     "1717": 2,
#     "1718": 1,
#     "1719": 1,
#     "1720": 2,
#     "1721": 1,
#     "1722": 1,
#     "1723": 4,
#     "1725": 1,
#     "1726": 2,
#     "1727": 1,
#     "1728": 1,
#     "1730": 1,
#     "1731": 1,
#     "1732": 1,
#     "1733": 1,
#     "1734": 1,
#     "1735": 1,
#     "1736": 1,
#     "1738": 2,
#     "1739": 1,
#     "1740": 1,
#     "1741": 2,
#     "1742": 2,
#     "1744": 1,
#     "1745": 1,
#     "1747": 1,
#     "1748": 1,
#     "1749": 1,
#     "1750": 1,
#     "1751": 1,
#     "1752": 1,
#     "1753": 1,
#     "1754": 1,
#     "1755": 1,
#     "1756": 1,
#     "1757": 1,
#     "1758": 1,
#     "1759": 1,
#     "1760": 1,
#     "1762": 1,
#     "1763": 1,
#     "1764": 1,
#     "1765": 1,
#     "1766": 1,
#     "1767": 1,
#     "1769": 1,
#     "1770": 1,
#     "1772": 1,
#     "1773": 1,
#     "1774": 1,
#     "1775": 1,
#     "1776": 1,
#     "1777": 2,
#     "1779": 1,
#     "1780": 1,
#     "1781": 1,
#     "1782": 1,
#     "1783": 2,
#     "1784": 1,
#     "1785": 2,
#     "1786": 1,
#     "1787": 2,
#     "1788": 1,
#     "1789": 1,
#     "1790": 1,
#     "1791": 1,
#     "1792": 4,
#     "1793": 1,
#     "1795": 1,
#     "1796": 1,
#     "1797": 1,
#     "1798": 1,
#     "1800": 1,
#     "1801": 1,
#     "1802": 1,
#     "1803": 1,
#     "1804": 1,
#     "1806": 1,
#     "1807": 1,
#     "1808": 1,
#     "1809": 1,
#     "1810": 1,
#     "1811": 1,
#     "1812": 1,
#     "1813": 1,
#     "1814": 1,
#     "1815": 1,
#     "1816": 3,
#     "1817": 1,
#     "1818": 3,
#     "1819": 1,
#     "1820": 1,
#     "1821": 3,
#     "1822": 1,
#     "1823": 2,
#     "1824": 1,
#     "1826": 1,
#     "1827": 2,
#     "1828": 1,
#     "1829": 1,
#     "1831": 1,
#     "1832": 1,
#     "1833": 3,
#     "1834": 1,
#     "1836": 1,
#     "1838": 1,
#     "1840": 1,
#     "1841": 1,
#     "1843": 2,
#     "1844": 1,
#     "1845": 1,
#     "1847": 1,
#     "1848": 1,
#     "1849": 1,
#     "1850": 1,
#     "1851": 1,
#     "1852": 1,
#     "1854": 1,
#     "1855": 1,
#     "1856": 1,
#     "1857": 1,
#     "1858": 1,
#     "1859": 1,
#     "1860": 1,
#     "1861": 1,
#     "1862": 1,
#     "1864": 1,
#     "1865": 1,
#     "1866": 1,
#     "1867": 1,
#     "1868": 1,
#     "1869": 1,
#     "1872": 2,
#     "1873": 1,
#     "1874": 1,
#     "1875": 2,
#     "1876": 1,
#     "1877": 1,
#     "1879": 1,
#     "1880": 1,
#     "1881": 1,
#     "1882": 1,
#     "1883": 1,
#     "1884": 1,
#     "1886": 1,
#     "1888": 1,
#     "1889": 1,
#     "1891": 1,
#     "1893": 1,
#     "1894": 2,
#     "1895": 1,
#     "1896": 1,
#     "1897": 1,
#     "1898": 1,
#     "1899": 1,
#     "1901": 1,
#     "1905": 1,
#     "1906": 1,
#     "1908": 1,
#     "1909": 1,
#     "1910": 1,
#     "1911": 1,
#     "1913": 3,
#     "1915": 1,
#     "1917": 3,
#     "1918": 1,
#     "1919": 1,
#     "1920": 1,
#     "1922": 2,
#     "1923": 1,
#     "1925": 1,
#     "1926": 1,
#     "1927": 1,
#     "1928": 1,
#     "1929": 1,
#     "1930": 7,
#     "1931": 1,
#     "1932": 1,
#     "1933": 1,
#     "1935": 1,
#     "1936": 1,
#     "1937": 1,
#     "1938": 1,
#     "1939": 1,
#     "1943": 1,
#     "1945": 1,
#     "1947": 1,
#     "1948": 1,
#     "1949": 1,
#     "1950": 1,
#     "1951": 1,
#     "1953": 1,
#     "1954": 2,
#     "1955": 1,
#     "1960": 1,
#     "1963": 1,
#     "1964": 1,
#     "1965": 1,
#     "1966": 1,
#     "1967": 3,
#     "1968": 1,
#     "1970": 1,
#     "1972": 1,
#     "1973": 1,
#     "1974": 1,
#     "1975": 1,
#     "1976": 1,
#     "1977": 1,
#     "1978": 1,
#     "1979": 1,
#     "1980": 1,
#     "1981": 1,
#     "1982": 1,
#     "1983": 1,
#     "1984": 1,
#     "1985": 1,
#     "1987": 2,
#     "1988": 1,
#     "1989": 1,
#     "1990": 1,
#     "1992": 1,
#     "1995": 1,
#     "1996": 1,
#     "1997": 1,
#     "1998": 1,
#     "1999": 1
#   }
# }

# %% [markdown]
# #### Ich hatte in Fabians Repositorium das Problem, dass ich das Notebook zbiw-data-librarian-module2-1.ipynb nicht direkt aufrufen konnte. Über den Download ging es. Die beiden anderen Notebooks konnte ich problemlos direkt öffnen. Soll das so sein? Woran liegt das?

# %% [markdown]
# Antwort: ganz einfach, die Datei ist zu groß um von GitHub dargestellt zu werden!

# %% [markdown]
# ### Weitere Dateiformate
# Pandas ist in der Lage, noch eine Vielzahl anderer Dateiformate zu erzeugen (und einzulesen). Dazu gehören: [Excel](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_excel.html#pandas.DataFrame.to_excel), [XML](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_xml.html) und viele weitere. Eine vollständige Übersicht findet sich [hier](https://pandas.pydata.org/docs/reference/io.html).

# %% [markdown]
# ## Ressourcen zu Pandas
# - [offizieller User Guide](https://pandas.pydata.org/docs/user_guide/index.html#user-guide)
# - [offizielle API](https://pandas.pydata.org/docs/reference/index.html#api) mit detaillierten Informationen zu allen Mothoden
# - [W3 Schools Pandas Tutorial](https://www.w3schools.com/python/pandas/default.asp) mit vielen Übungen und Quizes, sowie detaillierten Erläuterungen und Beispielen
# - [Pandas Cheat Sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf) – eine kompakte Übersicht vieler oft genutzter Funktionen
